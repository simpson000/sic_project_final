# %%
import numpy as np
import pandas as pd 
import re
import joblib 
import matplotlib.pyplot as plt
import seaborn as sns

from tqdm import tqdm
from sklearn.preprocessing import StandardScaler

from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
import sklearn.metrics as mt
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import (
    export_graphviz,
    DecisionTreeClassifier,
    DecisionTreeRegressor
    )
    ## check


from sklearn.ensemble import(
    RandomForestClassifier, ## check
    VotingClassifier,
    GradientBoostingClassifier,
    RandomForestRegressor
    )
from sklearn.metrics import(
    accuracy_score,
    confusion_matrix,
    ConfusionMatrixDisplay, 
    recall_score,
    precision_score,
    mean_squared_error,
    mean_absolute_error,
    r2_score
    )     ##check
from sklearn.model_selection import (
    train_test_split,
    KFold ,
    StratifiedShuffleSplit,  ## check
    cross_val_score,     ##check
    RandomizedSearchCV
    )
# Out:
# C:\Users\siim2\AppData\Local\Temp\ipykernel_5220\1062761202.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
keywords = ["auto","construct","capital_market","chemicals","equipment",
            "transport","semi","bank","steel",
            "telecom","staples","discretionary","kospi"]

# %%
dfs = {}  # 빈 딕셔너리 생성
column_names_per_keyword = {}

# 각 키워드에 해당하는 데이터프레임을 dfs 딕셔너리에 추가
for keyword in keywords:
    dfs[keyword] = pd.read_excel(r"total_raw_0.3ver.xlsx", sheet_name=keyword, header=0, index_col=0)
    column_names_per_keyword[keyword] = dfs[keyword].columns.tolist()

    print(f"Compile {keyword}")

# 각 데이터프레임의 인덱스를 날짜 형식으로 변환한 후 문자열로 변경
for keyword, df in dfs.items():
    df.index = pd.to_datetime(df.index)
    df.index = df.index.strftime('%Y-%m-%d')

# 첫 2개 행을 출력
for keyword, df in dfs.items():
    print(f"Top 2 rows of {keyword}:")
    print(df.head(2))
    print(column_names_per_keyword[keyword])

# 첫 번째 데이터프레임의 인덱스를 df_index에 복사하여 초기화
df_index_auto = list(dfs.values())[0]
df_index_construct = list(dfs.values())[1]
df_index_capital_market = list(dfs.values())[2]
df_index_chemicals = list(dfs.values())[3]
df_index_equipment = list(dfs.values())[4]
df_index_transport = list(dfs.values())[5]
df_index_semi = list(dfs.values())[6]
df_index_bank = list(dfs.values())[7]
df_index_steel = list(dfs.values())[8]
df_index_telecom = list(dfs.values())[9]
df_index_staples = list(dfs.values())[10]
df_index_discretionary = list(dfs.values())[11]
df_index_kospi = list(dfs.values())[12]
# Out:
# Compile auto
# Compile construct
# Compile capital_market
# Compile chemicals
# Compile equipment
# Compile transport
# Compile semi
# Compile bank
# Compile steel
# Compile telecom
# Compile staples
# Compile discretionary
# Compile kospi
# Top 2 rows of auto:
#              auto    WTI  DGS2  DGS10  TIPS    VIX    PPI    per    pbr  \
# date
# 2010-04-01  S_buy  84.53  1.05   3.89  1.61  17.47  172.2  24.13  24.13
# 2010-04-05  S_buy  86.36  1.18   4.01  1.70  17.02  172.2  24.22  24.22
#
#                원달러  ...   구리선물_60  중국고정자산투자(yoy%)_60  중국 PMI_60   금 선물_60  \
# date                ...
# 2010-04-01  1131.3  ...  0.000842          -0.003191  -0.001859 -0.000108
# 2010-04-05  1126.0  ...  0.001063          -0.003258  -0.001785 -0.000062
#
#             달러 인덱스_60  중국 소매판매_60  중국 산업 생산_60  MSCI_EMER_60  US_auto_60  \
# date
# 2010-04-01   0.000870    0.006153    -0.007687      0.000181   -0.001737
# 2010-04-05   0.000855    0.006087    -0.007304      0.000369   -0.001560
#
#             export_auto_60
# date
# 2010-04-01       -0.007820
# 2010-04-05       -0.007609
#
# [2 rows x 88 columns]
# ['auto', 'WTI', 'DGS2', 'DGS10', 'TIPS', 'VIX', 'PPI', 'per', 'pbr', '원달러', '원엔', '3년물 ', '10년물 ', 'treasury_10_3_diff', 'T10Y2Y', 'usa_cpi', 'us_e_infla', 'yield_gap(%)', 'cpi', 'export', '구리선물', '중국고정자산투자(yoy%)', '중국 PMI', '금 선물', '달러 인덱스', '중국 소매판매', '중국 산업 생산', 'MSCI_EMER', 'US_auto', 'export_auto', 'WTI_20', 'DGS2_20', 'DGS10_20', 'TIPS_20', 'VIX_20', 'PPI_20', 'per_20', 'pbr_20', '원달러_20', '원엔_20', '3년물 _20', '10년물 _20', 'treasury_10_3_diff_20', 'T10Y2Y_20', 'usa_cpi_20', 'us_e_infla_20', 'yield_gap(%)_20', 'cpi_20', 'export_20', '구리선물_20', '중국고정자산투자(yoy%)_20', '중국 PMI_20', '금 선물_20', '달러 인덱스_20', '중국 소매판매_20', '중국 산업 생산_20', 'MSCI_EMER_20', 'US_auto_20', 'export_auto_20', 'WTI_60', 'DGS2_60', 'DGS10_60', 'TIPS_60', 'VIX_60', 'PPI_60', 'per_60', 'pbr_60', '원달러_60', '원엔_60', '3년물 _60', '10년물 _60', 'treasury_10_3_diff_60', 'T10Y2Y_60', 'usa_cpi_60', 'us_e_infla_60', 'yield_gap(%)_60', 'cpi_60', 'export_60', '구리선물_60', '중국고정자산투자(yoy%)_60', '중국 PMI_60', '금 선물_60', '달러 인덱스_60', '중국 소매판매_60', '중국 산업 생산_60', 'MSCI_EMER_60', 'US_auto_60', 'export_auto_60']
# Top 2 rows of construct:
#            construct    WTI  DGS2  DGS10  TIPS    VIX    PPI    per    pbr  \
# date
# 2010-04-01      sell  84.53  1.05   3.89  1.61  17.47  172.2  24.13  24.13
# 2010-04-05      sell  86.36  1.18   4.01  1.70  17.02  172.2  24.22  24.22
#
#                원달러  ...   구리선물_60  중국고정자산투자(yoy%)_60  중국 PMI_60   금 선물_60  \
# date                ...
# 2010-04-01  1131.3  ...  0.000842          -0.003191  -0.001859 -0.000108
# 2010-04-05  1126.0  ...  0.001063          -0.003258  -0.001785 -0.000062
#
#             달러 인덱스_60  중국 소매판매_60  중국 산업 생산_60  MSCI_EMER_60     매매가격지수_60  \
# date
# 2010-04-01   0.000870    0.006153    -0.007687      0.000181 -3.265909e-18
# 2010-04-05   0.000855    0.006087    -0.007304      0.000369 -3.265909e-18
#
#             아파트매매거래량_60
# date
# 2010-04-01     0.006943
# 2010-04-05     0.006711
#
# [2 rows x 88 columns]
# ['construct', 'WTI', 'DGS2', 'DGS10', 'TIPS', 'VIX', 'PPI', 'per', 'pbr', '원달러', '원엔', '3년물 ', '10년물 ', 'treasury_10_3_diff', 'T10Y2Y', 'usa_cpi', 'us_e_infla', 'yield_gap(%)', 'cpi', 'export', '구리선물', '중국고정자산투자(yoy%)', '중국 PMI', '금 선물', '달러 인덱스', '중국 소매판매', '중국 산업 생산', 'MSCI_EMER', '매매가격지수', '아파트매매거래량', 'WTI_20', 'DGS2_20', 'DGS10_20', 'TIPS_20', 'VIX_20', 'PPI_20', 'per_20', 'pbr_20', '원달러_20', '원엔_20', '3년물 _20', '10년물 _20', 'treasury_10_3_diff_20', 'T10Y2Y_20', 'usa_cpi_20', 'us_e_infla_20', 'yield_gap(%)_20', 'cpi_20', 'export_20', '구리선물_20', '중국고정자산투자(yoy%)_20', '중국 PMI_20', '금 선물_20', '달러 인덱스_20', '중국 소매판매_20', '중국 산업 생산_20', 'MSCI_EMER_20', '매매가격지수_20', '아파트매매거래량_20', 'WTI_60', 'DGS2_60', 'DGS10_60', 'TIPS_60', 'VIX_60', 'PPI_60', 'per_60', 'pbr_60', '원달러_60', '원엔_60', '3년물 _60', '10년물 _60', 'treasury_10_3_diff_60', 'T10Y2Y_60', 'usa_cpi_60', 'us_e_infla_60', 'yield_gap(%)_60', 'cpi_60', 'export_60', '구리선물_60', '중국고정자산투자(yoy%)_60', '중국 PMI_60', '금 선물_60', '달러 인덱스_60', '중국 소매판매_60', '중국 산업 생산_60', 'MSCI_EMER_60', '매매가격지수_60', '아파트매매거래량_60']
# Top 2 rows of capital_market:
#            capital_market    WTI  DGS2  DGS10  TIPS    VIX    PPI    per  \
# date
# 2010-04-01           sell  84.53  1.05   3.89  1.61  17.47  172.2  24.13
# 2010-04-05           sell  86.36  1.18   4.01  1.70  17.02  172.2  24.22
#
#               pbr     원달러  ...   구리선물_60  중국고정자산투자(yoy%)_60  중국 PMI_60  \
# date                       ...
# 2010-04-01  24.13  1131.3  ...  0.000842          -0.003191  -0.001859
# 2010-04-05  24.22  1126.0  ...  0.001063          -0.003258  -0.001785
#
#              금 선물_60  달러 인덱스_60  중국 소매판매_60  중국 산업 생산_60  MSCI_EMER_60  \
# date
# 2010-04-01 -0.000108   0.000870    0.006153    -0.007687      0.000181
# 2010-04-05 -0.000062   0.000855    0.006087    -0.007304      0.000369
#
#             증권 배당 수익률_60  코스피+코스닥 거래량_60
# date
# 2010-04-01      0.001074       -0.003238
# 2010-04-05      0.000955       -0.003512
#
# [2 rows x 88 columns]
# ['capital_market', 'WTI', 'DGS2', 'DGS10', 'TIPS', 'VIX', 'PPI', 'per', 'pbr', '원달러', '원엔', '3년물 ', '10년물 ', 'treasury_10_3_diff', 'T10Y2Y', 'usa_cpi', 'us_e_infla', 'yield_gap(%)', 'cpi', 'export', '구리선물', '중국고정자산투자(yoy%)', '중국 PMI', '금 선물', '달러 인덱스', '중국 소매판매', '중국 산업 생산', 'MSCI_EMER', '증권 배당 수익률', '코스피+코스닥 거래량', 'WTI_20', 'DGS2_20', 'DGS10_20', 'TIPS_20', 'VIX_20', 'PPI_20', 'per_20', 'pbr_20', '원달러_20', '원엔_20', '3년물 _20', '10년물 _20', 'treasury_10_3_diff_20', 'T10Y2Y_20', 'usa_cpi_20', 'us_e_infla_20', 'yield_gap(%)_20', 'cpi_20', 'export_20', '구리선물_20', '중국고정자산투자(yoy%)_20', '중국 PMI_20', '금 선물_20', '달러 인덱스_20', '중국 소매판매_20', '중국 산업 생산_20', 'MSCI_EMER_20', '증권 배당 수익률_20', '코스피+코스닥 거래량_20', 'WTI_60', 'DGS2_60', 'DGS10_60', 'TIPS_60', 'VIX_60', 'PPI_60', 'per_60', 'pbr_60', '원달러_60', '원엔_60', '3년물 _60', '10년물 _60', 'treasury_10_3_diff_60', 'T10Y2Y_60', 'usa_cpi_60', 'us_e_infla_60', 'yield_gap(%)_60', 'cpi_60', 'export_60', '구리선물_60', '중국고정자산투자(yoy%)_60', '중국 PMI_60', '금 선물_60', '달러 인덱스_60', '중국 소매판매_60', '중국 산업 생산_60', 'MSCI_EMER_60', '증권 배당 수익률_60', '코스피+코스닥 거래량_60']
# Top 2 rows of chemicals:
#            chemicals    WTI  DGS2  DGS10  TIPS    VIX    PPI    per    pbr  \
# date
# 2010-04-01     S_buy  84.53  1.05   3.89  1.61  17.47  172.2  24.13  24.13
# 2010-04-05     S_buy  86.36  1.18   4.01  1.70  17.02  172.2  24.22  24.22
#
#                원달러  ...   구리선물_60  중국고정자산투자(yoy%)_60  중국 PMI_60   금 선물_60  \
# date                ...
# 2010-04-01  1131.3  ...  0.000842          -0.003191  -0.001859 -0.000108
# 2010-04-05  1126.0  ...  0.001063          -0.003258  -0.001785 -0.000062
#
#             달러 인덱스_60  중국 소매판매_60  중국 산업 생산_60  MSCI_EMER_60  lc_price_60  \
# date
# 2010-04-01   0.000870    0.006153    -0.007687      0.000181     0.000260
# 2010-04-05   0.000855    0.006087    -0.007304      0.000369     0.000271
#
#             naphtha_price_60
# date
# 2010-04-01          0.000091
# 2010-04-05          0.000207
#
# [2 rows x 88 columns]
# ['chemicals', 'WTI', 'DGS2', 'DGS10', 'TIPS', 'VIX', 'PPI', 'per', 'pbr', '원달러', '원엔', '3년물 ', '10년물 ', 'treasury_10_3_diff', 'T10Y2Y', 'usa_cpi', 'us_e_infla', 'yield_gap(%)', 'cpi', 'export', '구리선물', '중국고정자산투자(yoy%)', '중국 PMI', '금 선물', '달러 인덱스', '중국 소매판매', '중국 산업 생산', 'MSCI_EMER', 'lc_price', 'naphtha_price', 'WTI_20', 'DGS2_20', 'DGS10_20', 'TIPS_20', 'VIX_20', 'PPI_20', 'per_20', 'pbr_20', '원달러_20', '원엔_20', '3년물 _20', '10년물 _20', 'treasury_10_3_diff_20', 'T10Y2Y_20', 'usa_cpi_20', 'us_e_infla_20', 'yield_gap(%)_20', 'cpi_20', 'export_20', '구리선물_20', '중국고정자산투자(yoy%)_20', '중국 PMI_20', '금 선물_20', '달러 인덱스_20', '중국 소매판매_20', '중국 산업 생산_20', 'MSCI_EMER_20', 'lc_price_20', 'naphtha_price_20', 'WTI_60', 'DGS2_60', 'DGS10_60', 'TIPS_60', 'VIX_60', 'PPI_60', 'per_60', 'pbr_60', '원달러_60', '원엔_60', '3년물 _60', '10년물 _60', 'treasury_10_3_diff_60', 'T10Y2Y_60', 'usa_cpi_60', 'us_e_infla_60', 'yield_gap(%)_60', 'cpi_60', 'export_60', '구리선물_60', '중국고정자산투자(yoy%)_60', '중국 PMI_60', '금 선물_60', '달러 인덱스_60', '중국 소매판매_60', '중국 산업 생산_60', 'MSCI_EMER_60', 'lc_price_60', 'naphtha_price_60']
# Top 2 rows of equipment:
#            equipment    WTI  DGS2  DGS10  TIPS    VIX    PPI    per    pbr  \
# date
# 2010-04-01     S_buy  84.53  1.05   3.89  1.61  17.47  172.2  24.13  24.13
# 2010-04-05     S_buy  86.36  1.18   4.01  1.70  17.02  172.2  24.22  24.22
#
#                원달러  ...   구리선물_60  중국고정자산투자(yoy%)_60  중국 PMI_60   금 선물_60  \
# date                ...
# 2010-04-01  1131.3  ...  0.000842          -0.003191  -0.001859 -0.000108
# 2010-04-05  1126.0  ...  0.001063          -0.003258  -0.001785 -0.000062
#
#             달러 인덱스_60  중국 소매판매_60  중국 산업 생산_60  MSCI_EMER_60  기계수주경상금액_60  \
# date
# 2010-04-01   0.000870    0.006153    -0.007687      0.000181     0.005828
# 2010-04-05   0.000855    0.006087    -0.007304      0.000369     0.005371
#
#             BSI 제조업경기실사지수_60
# date
# 2010-04-01          0.001719
# 2010-04-05          0.001749
#
# [2 rows x 88 columns]
# ['equipment', 'WTI', 'DGS2', 'DGS10', 'TIPS', 'VIX', 'PPI', 'per', 'pbr', '원달러', '원엔', '3년물 ', '10년물 ', 'treasury_10_3_diff', 'T10Y2Y', 'usa_cpi', 'us_e_infla', 'yield_gap(%)', 'cpi', 'export', '구리선물', '중국고정자산투자(yoy%)', '중국 PMI', '금 선물', '달러 인덱스', '중국 소매판매', '중국 산업 생산', 'MSCI_EMER', '기계수주경상금액', 'BSI 제조업경기실사지수', 'WTI_20', 'DGS2_20', 'DGS10_20', 'TIPS_20', 'VIX_20', 'PPI_20', 'per_20', 'pbr_20', '원달러_20', '원엔_20', '3년물 _20', '10년물 _20', 'treasury_10_3_diff_20', 'T10Y2Y_20', 'usa_cpi_20', 'us_e_infla_20', 'yield_gap(%)_20', 'cpi_20', 'export_20', '구리선물_20', '중국고정자산투자(yoy%)_20', '중국 PMI_20', '금 선물_20', '달러 인덱스_20', '중국 소매판매_20', '중국 산업 생산_20', 'MSCI_EMER_20', '기계수주경상금액_20', 'BSI 제조업경기실사지수_20', 'WTI_60', 'DGS2_60', 'DGS10_60', 'TIPS_60', 'VIX_60', 'PPI_60', 'per_60', 'pbr_60', '원달러_60', '원엔_60', '3년물 _60', '10년물 _60', 'treasury_10_3_diff_60', 'T10Y2Y_60', 'usa_cpi_60', 'us_e_infla_60', 'yield_gap(%)_60', 'cpi_60', 'export_60', '구리선물_60', '중국고정자산투자(yoy%)_60', '중국 PMI_60', '금 선물_60', '달러 인덱스_60', '중국 소매판매_60', '중국 산업 생산_60', 'MSCI_EMER_60', '기계수주경상금액_60', 'BSI 제조업경기실사지수_60']
# Top 2 rows of transport:
#            transport    WTI  DGS2  DGS10  TIPS    VIX    PPI    per    pbr  \
# date
# 2010-04-01       buy  84.53  1.05   3.89  1.61  17.47  172.2  24.13  24.13
# 2010-04-05       buy  86.36  1.18   4.01  1.70  17.02  172.2  24.22  24.22
#
#                원달러  ...   구리선물_60  중국고정자산투자(yoy%)_60  중국 PMI_60   금 선물_60  \
# date                ...
# 2010-04-01  1131.3  ...  0.000842          -0.003191  -0.001859 -0.000108
# 2010-04-05  1126.0  ...  0.001063          -0.003258  -0.001785 -0.000062
#
#             달러 인덱스_60  중국 소매판매_60  중국 산업 생산_60  MSCI_EMER_60   발틱운임_60  \
# date
# 2010-04-01   0.000870    0.006153    -0.007687      0.000181  0.000709
# 2010-04-05   0.000855    0.006087    -0.007304      0.000369  0.000821
#
#              scfi_60
# date
# 2010-04-01  0.004156
# 2010-04-05  0.003920
#
# [2 rows x 88 columns]
# ['transport', 'WTI', 'DGS2', 'DGS10', 'TIPS', 'VIX', 'PPI', 'per', 'pbr', '원달러', '원엔', '3년물 ', '10년물 ', 'treasury_10_3_diff', 'T10Y2Y', 'usa_cpi', 'us_e_infla', 'yield_gap(%)', 'cpi', 'export', '구리선물', '중국고정자산투자(yoy%)', '중국 PMI', '금 선물', '달러 인덱스', '중국 소매판매', '중국 산업 생산', 'MSCI_EMER', '발틱운임', 'scfi', 'WTI_20', 'DGS2_20', 'DGS10_20', 'TIPS_20', 'VIX_20', 'PPI_20', 'per_20', 'pbr_20', '원달러_20', '원엔_20', '3년물 _20', '10년물 _20', 'treasury_10_3_diff_20', 'T10Y2Y_20', 'usa_cpi_20', 'us_e_infla_20', 'yield_gap(%)_20', 'cpi_20', 'export_20', '구리선물_20', '중국고정자산투자(yoy%)_20', '중국 PMI_20', '금 선물_20', '달러 인덱스_20', '중국 소매판매_20', '중국 산업 생산_20', 'MSCI_EMER_20', '발틱운임_20', 'scfi_20', 'WTI_60', 'DGS2_60', 'DGS10_60', 'TIPS_60', 'VIX_60', 'PPI_60', 'per_60', 'pbr_60', '원달러_60', '원엔_60', '3년물 _60', '10년물 _60', 'treasury_10_3_diff_60', 'T10Y2Y_60', 'usa_cpi_60', 'us_e_infla_60', 'yield_gap(%)_60', 'cpi_60', 'export_60', '구리선물_60', '중국고정자산투자(yoy%)_60', '중국 PMI_60', '금 선물_60', '달러 인덱스_60', '중국 소매판매_60', '중국 산업 생산_60', 'MSCI_EMER_60', '발틱운임_60', 'scfi_60']
# Top 2 rows of semi:
#              semi    WTI  DGS2  DGS10  TIPS    VIX    PPI    per    pbr  \
# date
# 2010-04-01  S_buy  84.53  1.05   3.89  1.61  17.47  172.2  24.13  24.13
# 2010-04-05    buy  86.36  1.18   4.01  1.70  17.02  172.2  24.22  24.22
#
#                원달러  ...   구리선물_60  중국고정자산투자(yoy%)_60  중국 PMI_60   금 선물_60  \
# date                ...
# 2010-04-01  1131.3  ...  0.000842          -0.003191  -0.001859 -0.000108
# 2010-04-05  1126.0  ...  0.001063          -0.003258  -0.001785 -0.000062
#
#             달러 인덱스_60  중국 소매판매_60  중국 산업 생산_60  MSCI_EMER_60    SOX_60  \
# date
# 2010-04-01   0.000870    0.006153    -0.007687      0.000181  0.000914
# 2010-04-05   0.000855    0.006087    -0.007304      0.000369  0.001153
#
#             메모리 수출금액_60
# date
# 2010-04-01    -0.000189
# 2010-04-05    -0.000207
#
# [2 rows x 88 columns]
# ['semi', 'WTI', 'DGS2', 'DGS10', 'TIPS', 'VIX', 'PPI', 'per', 'pbr', '원달러', '원엔', '3년물 ', '10년물 ', 'treasury_10_3_diff', 'T10Y2Y', 'usa_cpi', 'us_e_infla', 'yield_gap(%)', 'cpi', 'export', '구리선물', '중국고정자산투자(yoy%)', '중국 PMI', '금 선물', '달러 인덱스', '중국 소매판매', '중국 산업 생산', 'MSCI_EMER', 'SOX', '메모리 수출금액', 'WTI_20', 'DGS2_20', 'DGS10_20', 'TIPS_20', 'VIX_20', 'PPI_20', 'per_20', 'pbr_20', '원달러_20', '원엔_20', '3년물 _20', '10년물 _20', 'treasury_10_3_diff_20', 'T10Y2Y_20', 'usa_cpi_20', 'us_e_infla_20', 'yield_gap(%)_20', 'cpi_20', 'export_20', '구리선물_20', '중국고정자산투자(yoy%)_20', '중국 PMI_20', '금 선물_20', '달러 인덱스_20', '중국 소매판매_20', '중국 산업 생산_20', 'MSCI_EMER_20', 'SOX_20', '메모리 수출금액_20', 'WTI_60', 'DGS2_60', 'DGS10_60', 'TIPS_60', 'VIX_60', 'PPI_60', 'per_60', 'pbr_60', '원달러_60', '원엔_60', '3년물 _60', '10년물 _60', 'treasury_10_3_diff_60', 'T10Y2Y_60', 'usa_cpi_60', 'us_e_infla_60', 'yield_gap(%)_60', 'cpi_60', 'export_60', '구리선물_60', '중국고정자산투자(yoy%)_60', '중국 PMI_60', '금 선물_60', '달러 인덱스_60', '중국 소매판매_60', '중국 산업 생산_60', 'MSCI_EMER_60', 'SOX_60', '메모리 수출금액_60']
# Top 2 rows of bank:
#            bank    WTI  DGS2  DGS10  TIPS    VIX    PPI    per    pbr     원달러  \
# date
# 2010-04-01  buy  84.53  1.05   3.89  1.61  17.47  172.2  24.13  24.13  1131.3
# 2010-04-05  buy  86.36  1.18   4.01  1.70  17.02  172.2  24.22  24.22  1126.0
#
#             ...   구리선물_60  중국고정자산투자(yoy%)_60  중국 PMI_60   금 선물_60  달러 인덱스_60  \
# date        ...
# 2010-04-01  ...  0.000842          -0.003191  -0.001859 -0.000108   0.000870
# 2010-04-05  ...  0.001063          -0.003258  -0.001785 -0.000062   0.000855
#
#             중국 소매판매_60  중국 산업 생산_60  MSCI_EMER_60  bank_dividend_60  \
# date
# 2010-04-01    0.006153    -0.007687      0.000181         -0.000169
# 2010-04-05    0.006087    -0.007304      0.000369         -0.000336
#
#             call_rate_60
# date
# 2010-04-01      0.000064
# 2010-04-05      0.000050
#
# [2 rows x 88 columns]
# ['bank', 'WTI', 'DGS2', 'DGS10', 'TIPS', 'VIX', 'PPI', 'per', 'pbr', '원달러', '원엔', '3년물 ', '10년물 ', 'treasury_10_3_diff', 'T10Y2Y', 'usa_cpi', 'us_e_infla', 'yield_gap(%)', 'cpi', 'export', '구리선물', '중국고정자산투자(yoy%)', '중국 PMI', '금 선물', '달러 인덱스', '중국 소매판매', '중국 산업 생산', 'MSCI_EMER', 'bank_dividend', 'call_rate', 'WTI_20', 'DGS2_20', 'DGS10_20', 'TIPS_20', 'VIX_20', 'PPI_20', 'per_20', 'pbr_20', '원달러_20', '원엔_20', '3년물 _20', '10년물 _20', 'treasury_10_3_diff_20', 'T10Y2Y_20', 'usa_cpi_20', 'us_e_infla_20', 'yield_gap(%)_20', 'cpi_20', 'export_20', '구리선물_20', '중국고정자산투자(yoy%)_20', '중국 PMI_20', '금 선물_20', '달러 인덱스_20', '중국 소매판매_20', '중국 산업 생산_20', 'MSCI_EMER_20', 'bank_dividend_20', 'call_rate_20', 'WTI_60', 'DGS2_60', 'DGS10_60', 'TIPS_60', 'VIX_60', 'PPI_60', 'per_60', 'pbr_60', '원달러_60', '원엔_60', '3년물 _60', '10년물 _60', 'treasury_10_3_diff_60', 'T10Y2Y_60', 'usa_cpi_60', 'us_e_infla_60', 'yield_gap(%)_60', 'cpi_60', 'export_60', '구리선물_60', '중국고정자산투자(yoy%)_60', '중국 PMI_60', '금 선물_60', '달러 인덱스_60', '중국 소매판매_60', '중국 산업 생산_60', 'MSCI_EMER_60', 'bank_dividend_60', 'call_rate_60']
# Top 2 rows of steel:
#            steel    WTI  DGS2  DGS10  TIPS    VIX    PPI    per    pbr  \
# date
# 2010-04-01  sell  84.53  1.05   3.89  1.61  17.47  172.2  24.13  24.13
# 2010-04-05  sell  86.36  1.18   4.01  1.70  17.02  172.2  24.22  24.22
#
#                원달러  ...   구리선물_60  중국고정자산투자(yoy%)_60  중국 PMI_60   금 선물_60  \
# date                ...
# 2010-04-01  1131.3  ...  0.000842          -0.003191  -0.001859 -0.000108
# 2010-04-05  1126.0  ...  0.001063          -0.003258  -0.001785 -0.000062
#
#             달러 인덱스_60  중국 소매판매_60  중국 산업 생산_60  MSCI_EMER_60  철광석 가격_60  \
# date
# 2010-04-01   0.000870    0.006153    -0.007687      0.000181   0.007185
# 2010-04-05   0.000855    0.006087    -0.007304      0.000369   0.005671
#
#             미국 철강 코일 선물_60
# date
# 2010-04-01        0.003060
# 2010-04-05        0.003142
#
# [2 rows x 88 columns]
# ['steel', 'WTI', 'DGS2', 'DGS10', 'TIPS', 'VIX', 'PPI', 'per', 'pbr', '원달러', '원엔', '3년물 ', '10년물 ', 'treasury_10_3_diff', 'T10Y2Y', 'usa_cpi', 'us_e_infla', 'yield_gap(%)', 'cpi', 'export', '구리선물', '중국고정자산투자(yoy%)', '중국 PMI', '금 선물', '달러 인덱스', '중국 소매판매', '중국 산업 생산', 'MSCI_EMER', '철광석 가격', '미국 철강 코일 선물', 'WTI_20', 'DGS2_20', 'DGS10_20', 'TIPS_20', 'VIX_20', 'PPI_20', 'per_20', 'pbr_20', '원달러_20', '원엔_20', '3년물 _20', '10년물 _20', 'treasury_10_3_diff_20', 'T10Y2Y_20', 'usa_cpi_20', 'us_e_infla_20', 'yield_gap(%)_20', 'cpi_20', 'export_20', '구리선물_20', '중국고정자산투자(yoy%)_20', '중국 PMI_20', '금 선물_20', '달러 인덱스_20', '중국 소매판매_20', '중국 산업 생산_20', 'MSCI_EMER_20', '철광석 가격_20', '미국 철강 코일 선물_20', 'WTI_60', 'DGS2_60', 'DGS10_60', 'TIPS_60', 'VIX_60', 'PPI_60', 'per_60', 'pbr_60', '원달러_60', '원엔_60', '3년물 _60', '10년물 _60', 'treasury_10_3_diff_60', 'T10Y2Y_60', 'usa_cpi_60', 'us_e_infla_60', 'yield_gap(%)_60', 'cpi_60', 'export_60', '구리선물_60', '중국고정자산투자(yoy%)_60', '중국 PMI_60', '금 선물_60', '달러 인덱스_60', '중국 소매판매_60', '중국 산업 생산_60', 'MSCI_EMER_60', '철광석 가격_60', '미국 철강 코일 선물_60']
# Top 2 rows of telecom:
#            telecom    WTI  DGS2  DGS10  TIPS    VIX    PPI    per    pbr  \
# date
# 2010-04-01   S_buy  84.53  1.05   3.89  1.61  17.47  172.2  24.13  24.13
# 2010-04-05   S_buy  86.36  1.18   4.01  1.70  17.02  172.2  24.22  24.22
#
#                원달러  ...   구리선물_60  중국고정자산투자(yoy%)_60  중국 PMI_60   금 선물_60  \
# date                ...
# 2010-04-01  1131.3  ...  0.000842          -0.003191  -0.001859 -0.000108
# 2010-04-05  1126.0  ...  0.001063          -0.003258  -0.001785 -0.000062
#
#             달러 인덱스_60  중국 소매판매_60  중국 산업 생산_60  MSCI_EMER_60   통신배당_60  \
# date
# 2010-04-01   0.000870    0.006153    -0.007687      0.000181  0.002829
# 2010-04-05   0.000855    0.006087    -0.007304      0.000369  0.002899
#
#             IT산업별/월별 수출 현황 중 통신기기 소계_60
# date
# 2010-04-01                    -0.001122
# 2010-04-05                    -0.000808
#
# [2 rows x 88 columns]
# ['telecom', 'WTI', 'DGS2', 'DGS10', 'TIPS', 'VIX', 'PPI', 'per', 'pbr', '원달러', '원엔', '3년물 ', '10년물 ', 'treasury_10_3_diff', 'T10Y2Y', 'usa_cpi', 'us_e_infla', 'yield_gap(%)', 'cpi', 'export', '구리선물', '중국고정자산투자(yoy%)', '중국 PMI', '금 선물', '달러 인덱스', '중국 소매판매', '중국 산업 생산', 'MSCI_EMER', '통신배당', 'IT산업별/월별 수출 현황 중 통신기기 소계', 'WTI_20', 'DGS2_20', 'DGS10_20', 'TIPS_20', 'VIX_20', 'PPI_20', 'per_20', 'pbr_20', '원달러_20', '원엔_20', '3년물 _20', '10년물 _20', 'treasury_10_3_diff_20', 'T10Y2Y_20', 'usa_cpi_20', 'us_e_infla_20', 'yield_gap(%)_20', 'cpi_20', 'export_20', '구리선물_20', '중국고정자산투자(yoy%)_20', '중국 PMI_20', '금 선물_20', '달러 인덱스_20', '중국 소매판매_20', '중국 산업 생산_20', 'MSCI_EMER_20', '통신배당_20', 'IT산업별/월별 수출 현황 중 통신기기 소계_20', 'WTI_60', 'DGS2_60', 'DGS10_60', 'TIPS_60', 'VIX_60', 'PPI_60', 'per_60', 'pbr_60', '원달러_60', '원엔_60', '3년물 _60', '10년물 _60', 'treasury_10_3_diff_60', 'T10Y2Y_60', 'usa_cpi_60', 'us_e_infla_60', 'yield_gap(%)_60', 'cpi_60', 'export_60', '구리선물_60', '중국고정자산투자(yoy%)_60', '중국 PMI_60', '금 선물_60', '달러 인덱스_60', '중국 소매판매_60', '중국 산업 생산_60', 'MSCI_EMER_60', '통신배당_60', 'IT산업별/월별 수출 현황 중 통신기기 소계_60']
# Top 2 rows of staples:
#            staples    WTI  DGS2  DGS10  TIPS    VIX    PPI    per    pbr  \
# date
# 2010-04-01     buy  84.53  1.05   3.89  1.61  17.47  172.2  24.13  24.13
# 2010-04-05    sell  86.36  1.18   4.01  1.70  17.02  172.2  24.22  24.22
#
#                원달러  ...   구리선물_60  중국고정자산투자(yoy%)_60  중국 PMI_60   금 선물_60  \
# date                ...
# 2010-04-01  1131.3  ...  0.000842          -0.003191  -0.001859 -0.000108
# 2010-04-05  1126.0  ...  0.001063          -0.003258  -0.001785 -0.000062
#
#             달러 인덱스_60  중국 소매판매_60  중국 산업 생산_60  MSCI_EMER_60  미 소맥 선물 _60  \
# date
# 2010-04-01   0.000870    0.006153    -0.007687      0.000181    -0.002022
# 2010-04-05   0.000855    0.006087    -0.007304      0.000369    -0.001980
#
#             미 대두 선물 _60
# date
# 2010-04-01    -0.000598
# 2010-04-05    -0.000451
#
# [2 rows x 88 columns]
# ['staples', 'WTI', 'DGS2', 'DGS10', 'TIPS', 'VIX', 'PPI', 'per', 'pbr', '원달러', '원엔', '3년물 ', '10년물 ', 'treasury_10_3_diff', 'T10Y2Y', 'usa_cpi', 'us_e_infla', 'yield_gap(%)', 'cpi', 'export', '구리선물', '중국고정자산투자(yoy%)', '중국 PMI', '금 선물', '달러 인덱스', '중국 소매판매', '중국 산업 생산', 'MSCI_EMER', '미 소맥 선물 ', '미 대두 선물 ', 'WTI_20', 'DGS2_20', 'DGS10_20', 'TIPS_20', 'VIX_20', 'PPI_20', 'per_20', 'pbr_20', '원달러_20', '원엔_20', '3년물 _20', '10년물 _20', 'treasury_10_3_diff_20', 'T10Y2Y_20', 'usa_cpi_20', 'us_e_infla_20', 'yield_gap(%)_20', 'cpi_20', 'export_20', '구리선물_20', '중국고정자산투자(yoy%)_20', '중국 PMI_20', '금 선물_20', '달러 인덱스_20', '중국 소매판매_20', '중국 산업 생산_20', 'MSCI_EMER_20', '미 소맥 선물 _20', '미 대두 선물 _20', 'WTI_60', 'DGS2_60', 'DGS10_60', 'TIPS_60', 'VIX_60', 'PPI_60', 'per_60', 'pbr_60', '원달러_60', '원엔_60', '3년물 _60', '10년물 _60', 'treasury_10_3_diff_60', 'T10Y2Y_60', 'usa_cpi_60', 'us_e_infla_60', 'yield_gap(%)_60', 'cpi_60', 'export_60', '구리선물_60', '중국고정자산투자(yoy%)_60', '중국 PMI_60', '금 선물_60', '달러 인덱스_60', '중국 소매판매_60', '중국 산업 생산_60', 'MSCI_EMER_60', '미 소맥 선물 _60', '미 대두 선물 _60']
# Top 2 rows of discretionary:
#            discretionary    WTI  DGS2  DGS10  TIPS    VIX    PPI    per  \
# date
# 2010-04-01          sell  84.53  1.05   3.89  1.61  17.47  172.2  24.13
# 2010-04-05          sell  86.36  1.18   4.01  1.70  17.02  172.2  24.22
#
#               pbr     원달러  ...   구리선물_60  중국고정자산투자(yoy%)_60  중국 PMI_60  \
# date                       ...
# 2010-04-01  24.13  1131.3  ...  0.000842          -0.003191  -0.001859
# 2010-04-05  24.22  1126.0  ...  0.001063          -0.003258  -0.001785
#
#              금 선물_60  달러 인덱스_60  중국 소매판매_60  중국 산업 생산_60  MSCI_EMER_60  \
# date
# 2010-04-01 -0.000108   0.000870    0.006153    -0.007687      0.000181
# 2010-04-05 -0.000062   0.000855    0.006087    -0.007304      0.000369
#
#             항공 여객_60  소비자심리지수_60
# date
# 2010-04-01  0.001114   -0.000482
# 2010-04-05  0.001299   -0.000473
#
# [2 rows x 88 columns]
# ['discretionary', 'WTI', 'DGS2', 'DGS10', 'TIPS', 'VIX', 'PPI', 'per', 'pbr', '원달러', '원엔', '3년물 ', '10년물 ', 'treasury_10_3_diff', 'T10Y2Y', 'usa_cpi', 'us_e_infla', 'yield_gap(%)', 'cpi', 'export', '구리선물', '중국고정자산투자(yoy%)', '중국 PMI', '금 선물', '달러 인덱스', '중국 소매판매', '중국 산업 생산', 'MSCI_EMER', '항공 여객', '소비자심리지수', 'WTI_20', 'DGS2_20', 'DGS10_20', 'TIPS_20', 'VIX_20', 'PPI_20', 'per_20', 'pbr_20', '원달러_20', '원엔_20', '3년물 _20', '10년물 _20', 'treasury_10_3_diff_20', 'T10Y2Y_20', 'usa_cpi_20', 'us_e_infla_20', 'yield_gap(%)_20', 'cpi_20', 'export_20', '구리선물_20', '중국고정자산투자(yoy%)_20', '중국 PMI_20', '금 선물_20', '달러 인덱스_20', '중국 소매판매_20', '중국 산업 생산_20', 'MSCI_EMER_20', '항공 여객_20', '소비자심리지수_20', 'WTI_60', 'DGS2_60', 'DGS10_60', 'TIPS_60', 'VIX_60', 'PPI_60', 'per_60', 'pbr_60', '원달러_60', '원엔_60', '3년물 _60', '10년물 _60', 'treasury_10_3_diff_60', 'T10Y2Y_60', 'usa_cpi_60', 'us_e_infla_60', 'yield_gap(%)_60', 'cpi_60', 'export_60', '구리선물_60', '중국고정자산투자(yoy%)_60', '중국 PMI_60', '금 선물_60', '달러 인덱스_60', '중국 소매판매_60', '중국 산업 생산_60', 'MSCI_EMER_60', '항공 여객_60', '소비자심리지수_60']
# Top 2 rows of kospi:
#            kospi    WTI  DGS2  DGS10  TIPS    VIX    PPI    per    pbr  \
# date
# 2010-04-01   buy  84.53  1.05   3.89  1.61  17.47  172.2  24.13  24.13
# 2010-04-05  sell  86.36  1.18   4.01  1.70  17.02  172.2  24.22  24.22
#
#                원달러  ...    cpi_60  export_60   구리선물_60  중국고정자산투자(yoy%)_60  \
# date                ...
# 2010-04-01  1131.3  ...  0.000667  -0.003721  0.000842          -0.003191
# 2010-04-05  1126.0  ...  0.000195  -0.004392  0.001063          -0.003258
#
#             중국 PMI_60   금 선물_60  달러 인덱스_60  중국 소매판매_60  중국 산업 생산_60  \
# date
# 2010-04-01  -0.001859 -0.000108   0.000870    0.006153    -0.007687
# 2010-04-05  -0.001785 -0.000062   0.000855    0.006087    -0.007304
#
#             MSCI_EMER_60
# date
# 2010-04-01      0.000181
# 2010-04-05      0.000369
#
# [2 rows x 82 columns]
# ['kospi', 'WTI', 'DGS2', 'DGS10', 'TIPS', 'VIX', 'PPI', 'per', 'pbr', '원달러', '원엔', '3년물 ', '10년물 ', 'treasury_10_3_diff', 'T10Y2Y', 'usa_cpi', 'us_e_infla', 'yield_gap(%)', 'cpi', 'export', '구리선물', '중국고정자산투자(yoy%)', '중국 PMI', '금 선물', '달러 인덱스', '중국 소매판매', '중국 산업 생산', 'MSCI_EMER', 'WTI_20', 'DGS2_20', 'DGS10_20', 'TIPS_20', 'VIX_20', 'PPI_20', 'per_20', 'pbr_20', '원달러_20', '원엔_20', '3년물 _20', '10년물 _20', 'treasury_10_3_diff_20', 'T10Y2Y_20', 'usa_cpi_20', 'us_e_infla_20', 'yield_gap(%)_20', 'cpi_20', 'export_20', '구리선물_20', '중국고정자산투자(yoy%)_20', '중국 PMI_20', '금 선물_20', '달러 인덱스_20', '중국 소매판매_20', '중국 산업 생산_20', 'MSCI_EMER_20', 'WTI_60', 'DGS2_60', 'DGS10_60', 'TIPS_60', 'VIX_60', 'PPI_60', 'per_60', 'pbr_60', '원달러_60', '원엔_60', '3년물 _60', '10년물 _60', 'treasury_10_3_diff_60', 'T10Y2Y_60', 'usa_cpi_60', 'us_e_infla_60', 'yield_gap(%)_60', 'cpi_60', 'export_60', '구리선물_60', '중국고정자산투자(yoy%)_60', '중국 PMI_60', '금 선물_60', '달러 인덱스_60', '중국 소매판매_60', '중국 산업 생산_60', 'MSCI_EMER_60']

# %%
# 각 데이터프레임의 열 이름 출력
for keyword, column_names in column_names_per_keyword.items():
    print(f"Column names for {keyword}: {column_names}")
# Out:
# Column names for auto: ['auto', 'WTI', 'DGS2', 'DGS10', 'TIPS', 'VIX', 'PPI', 'per', 'pbr', '원달러', '원엔', '3년물 ', '10년물 ', 'treasury_10_3_diff', 'T10Y2Y', 'usa_cpi', 'us_e_infla', 'yield_gap(%)', 'cpi', 'export', '구리선물', '중국고정자산투자(yoy%)', '중국 PMI', '금 선물', '달러 인덱스', '중국 소매판매', '중국 산업 생산', 'MSCI_EMER', 'US_auto', 'export_auto', 'WTI_20', 'DGS2_20', 'DGS10_20', 'TIPS_20', 'VIX_20', 'PPI_20', 'per_20', 'pbr_20', '원달러_20', '원엔_20', '3년물 _20', '10년물 _20', 'treasury_10_3_diff_20', 'T10Y2Y_20', 'usa_cpi_20', 'us_e_infla_20', 'yield_gap(%)_20', 'cpi_20', 'export_20', '구리선물_20', '중국고정자산투자(yoy%)_20', '중국 PMI_20', '금 선물_20', '달러 인덱스_20', '중국 소매판매_20', '중국 산업 생산_20', 'MSCI_EMER_20', 'US_auto_20', 'export_auto_20', 'WTI_60', 'DGS2_60', 'DGS10_60', 'TIPS_60', 'VIX_60', 'PPI_60', 'per_60', 'pbr_60', '원달러_60', '원엔_60', '3년물 _60', '10년물 _60', 'treasury_10_3_diff_60', 'T10Y2Y_60', 'usa_cpi_60', 'us_e_infla_60', 'yield_gap(%)_60', 'cpi_60', 'export_60', '구리선물_60', '중국고정자산투자(yoy%)_60', '중국 PMI_60', '금 선물_60', '달러 인덱스_60', '중국 소매판매_60', '중국 산업 생산_60', 'MSCI_EMER_60', 'US_auto_60', 'export_auto_60']
# Column names for construct: ['construct', 'WTI', 'DGS2', 'DGS10', 'TIPS', 'VIX', 'PPI', 'per', 'pbr', '원달러', '원엔', '3년물 ', '10년물 ', 'treasury_10_3_diff', 'T10Y2Y', 'usa_cpi', 'us_e_infla', 'yield_gap(%)', 'cpi', 'export', '구리선물', '중국고정자산투자(yoy%)', '중국 PMI', '금 선물', '달러 인덱스', '중국 소매판매', '중국 산업 생산', 'MSCI_EMER', '매매가격지수', '아파트매매거래량', 'WTI_20', 'DGS2_20', 'DGS10_20', 'TIPS_20', 'VIX_20', 'PPI_20', 'per_20', 'pbr_20', '원달러_20', '원엔_20', '3년물 _20', '10년물 _20', 'treasury_10_3_diff_20', 'T10Y2Y_20', 'usa_cpi_20', 'us_e_infla_20', 'yield_gap(%)_20', 'cpi_20', 'export_20', '구리선물_20', '중국고정자산투자(yoy%)_20', '중국 PMI_20', '금 선물_20', '달러 인덱스_20', '중국 소매판매_20', '중국 산업 생산_20', 'MSCI_EMER_20', '매매가격지수_20', '아파트매매거래량_20', 'WTI_60', 'DGS2_60', 'DGS10_60', 'TIPS_60', 'VIX_60', 'PPI_60', 'per_60', 'pbr_60', '원달러_60', '원엔_60', '3년물 _60', '10년물 _60', 'treasury_10_3_diff_60', 'T10Y2Y_60', 'usa_cpi_60', 'us_e_infla_60', 'yield_gap(%)_60', 'cpi_60', 'export_60', '구리선물_60', '중국고정자산투자(yoy%)_60', '중국 PMI_60', '금 선물_60', '달러 인덱스_60', '중국 소매판매_60', '중국 산업 생산_60', 'MSCI_EMER_60', '매매가격지수_60', '아파트매매거래량_60']
# Column names for capital_market: ['capital_market', 'WTI', 'DGS2', 'DGS10', 'TIPS', 'VIX', 'PPI', 'per', 'pbr', '원달러', '원엔', '3년물 ', '10년물 ', 'treasury_10_3_diff', 'T10Y2Y', 'usa_cpi', 'us_e_infla', 'yield_gap(%)', 'cpi', 'export', '구리선물', '중국고정자산투자(yoy%)', '중국 PMI', '금 선물', '달러 인덱스', '중국 소매판매', '중국 산업 생산', 'MSCI_EMER', '증권 배당 수익률', '코스피+코스닥 거래량', 'WTI_20', 'DGS2_20', 'DGS10_20', 'TIPS_20', 'VIX_20', 'PPI_20', 'per_20', 'pbr_20', '원달러_20', '원엔_20', '3년물 _20', '10년물 _20', 'treasury_10_3_diff_20', 'T10Y2Y_20', 'usa_cpi_20', 'us_e_infla_20', 'yield_gap(%)_20', 'cpi_20', 'export_20', '구리선물_20', '중국고정자산투자(yoy%)_20', '중국 PMI_20', '금 선물_20', '달러 인덱스_20', '중국 소매판매_20', '중국 산업 생산_20', 'MSCI_EMER_20', '증권 배당 수익률_20', '코스피+코스닥 거래량_20', 'WTI_60', 'DGS2_60', 'DGS10_60', 'TIPS_60', 'VIX_60', 'PPI_60', 'per_60', 'pbr_60', '원달러_60', '원엔_60', '3년물 _60', '10년물 _60', 'treasury_10_3_diff_60', 'T10Y2Y_60', 'usa_cpi_60', 'us_e_infla_60', 'yield_gap(%)_60', 'cpi_60', 'export_60', '구리선물_60', '중국고정자산투자(yoy%)_60', '중국 PMI_60', '금 선물_60', '달러 인덱스_60', '중국 소매판매_60', '중국 산업 생산_60', 'MSCI_EMER_60', '증권 배당 수익률_60', '코스피+코스닥 거래량_60']
# Column names for chemicals: ['chemicals', 'WTI', 'DGS2', 'DGS10', 'TIPS', 'VIX', 'PPI', 'per', 'pbr', '원달러', '원엔', '3년물 ', '10년물 ', 'treasury_10_3_diff', 'T10Y2Y', 'usa_cpi', 'us_e_infla', 'yield_gap(%)', 'cpi', 'export', '구리선물', '중국고정자산투자(yoy%)', '중국 PMI', '금 선물', '달러 인덱스', '중국 소매판매', '중국 산업 생산', 'MSCI_EMER', 'lc_price', 'naphtha_price', 'WTI_20', 'DGS2_20', 'DGS10_20', 'TIPS_20', 'VIX_20', 'PPI_20', 'per_20', 'pbr_20', '원달러_20', '원엔_20', '3년물 _20', '10년물 _20', 'treasury_10_3_diff_20', 'T10Y2Y_20', 'usa_cpi_20', 'us_e_infla_20', 'yield_gap(%)_20', 'cpi_20', 'export_20', '구리선물_20', '중국고정자산투자(yoy%)_20', '중국 PMI_20', '금 선물_20', '달러 인덱스_20', '중국 소매판매_20', '중국 산업 생산_20', 'MSCI_EMER_20', 'lc_price_20', 'naphtha_price_20', 'WTI_60', 'DGS2_60', 'DGS10_60', 'TIPS_60', 'VIX_60', 'PPI_60', 'per_60', 'pbr_60', '원달러_60', '원엔_60', '3년물 _60', '10년물 _60', 'treasury_10_3_diff_60', 'T10Y2Y_60', 'usa_cpi_60', 'us_e_infla_60', 'yield_gap(%)_60', 'cpi_60', 'export_60', '구리선물_60', '중국고정자산투자(yoy%)_60', '중국 PMI_60', '금 선물_60', '달러 인덱스_60', '중국 소매판매_60', '중국 산업 생산_60', 'MSCI_EMER_60', 'lc_price_60', 'naphtha_price_60']
# Column names for equipment: ['equipment', 'WTI', 'DGS2', 'DGS10', 'TIPS', 'VIX', 'PPI', 'per', 'pbr', '원달러', '원엔', '3년물 ', '10년물 ', 'treasury_10_3_diff', 'T10Y2Y', 'usa_cpi', 'us_e_infla', 'yield_gap(%)', 'cpi', 'export', '구리선물', '중국고정자산투자(yoy%)', '중국 PMI', '금 선물', '달러 인덱스', '중국 소매판매', '중국 산업 생산', 'MSCI_EMER', '기계수주경상금액', 'BSI 제조업경기실사지수', 'WTI_20', 'DGS2_20', 'DGS10_20', 'TIPS_20', 'VIX_20', 'PPI_20', 'per_20', 'pbr_20', '원달러_20', '원엔_20', '3년물 _20', '10년물 _20', 'treasury_10_3_diff_20', 'T10Y2Y_20', 'usa_cpi_20', 'us_e_infla_20', 'yield_gap(%)_20', 'cpi_20', 'export_20', '구리선물_20', '중국고정자산투자(yoy%)_20', '중국 PMI_20', '금 선물_20', '달러 인덱스_20', '중국 소매판매_20', '중국 산업 생산_20', 'MSCI_EMER_20', '기계수주경상금액_20', 'BSI 제조업경기실사지수_20', 'WTI_60', 'DGS2_60', 'DGS10_60', 'TIPS_60', 'VIX_60', 'PPI_60', 'per_60', 'pbr_60', '원달러_60', '원엔_60', '3년물 _60', '10년물 _60', 'treasury_10_3_diff_60', 'T10Y2Y_60', 'usa_cpi_60', 'us_e_infla_60', 'yield_gap(%)_60', 'cpi_60', 'export_60', '구리선물_60', '중국고정자산투자(yoy%)_60', '중국 PMI_60', '금 선물_60', '달러 인덱스_60', '중국 소매판매_60', '중국 산업 생산_60', 'MSCI_EMER_60', '기계수주경상금액_60', 'BSI 제조업경기실사지수_60']
# Column names for transport: ['transport', 'WTI', 'DGS2', 'DGS10', 'TIPS', 'VIX', 'PPI', 'per', 'pbr', '원달러', '원엔', '3년물 ', '10년물 ', 'treasury_10_3_diff', 'T10Y2Y', 'usa_cpi', 'us_e_infla', 'yield_gap(%)', 'cpi', 'export', '구리선물', '중국고정자산투자(yoy%)', '중국 PMI', '금 선물', '달러 인덱스', '중국 소매판매', '중국 산업 생산', 'MSCI_EMER', '발틱운임', 'scfi', 'WTI_20', 'DGS2_20', 'DGS10_20', 'TIPS_20', 'VIX_20', 'PPI_20', 'per_20', 'pbr_20', '원달러_20', '원엔_20', '3년물 _20', '10년물 _20', 'treasury_10_3_diff_20', 'T10Y2Y_20', 'usa_cpi_20', 'us_e_infla_20', 'yield_gap(%)_20', 'cpi_20', 'export_20', '구리선물_20', '중국고정자산투자(yoy%)_20', '중국 PMI_20', '금 선물_20', '달러 인덱스_20', '중국 소매판매_20', '중국 산업 생산_20', 'MSCI_EMER_20', '발틱운임_20', 'scfi_20', 'WTI_60', 'DGS2_60', 'DGS10_60', 'TIPS_60', 'VIX_60', 'PPI_60', 'per_60', 'pbr_60', '원달러_60', '원엔_60', '3년물 _60', '10년물 _60', 'treasury_10_3_diff_60', 'T10Y2Y_60', 'usa_cpi_60', 'us_e_infla_60', 'yield_gap(%)_60', 'cpi_60', 'export_60', '구리선물_60', '중국고정자산투자(yoy%)_60', '중국 PMI_60', '금 선물_60', '달러 인덱스_60', '중국 소매판매_60', '중국 산업 생산_60', 'MSCI_EMER_60', '발틱운임_60', 'scfi_60']
# Column names for semi: ['semi', 'WTI', 'DGS2', 'DGS10', 'TIPS', 'VIX', 'PPI', 'per', 'pbr', '원달러', '원엔', '3년물 ', '10년물 ', 'treasury_10_3_diff', 'T10Y2Y', 'usa_cpi', 'us_e_infla', 'yield_gap(%)', 'cpi', 'export', '구리선물', '중국고정자산투자(yoy%)', '중국 PMI', '금 선물', '달러 인덱스', '중국 소매판매', '중국 산업 생산', 'MSCI_EMER', 'SOX', '메모리 수출금액', 'WTI_20', 'DGS2_20', 'DGS10_20', 'TIPS_20', 'VIX_20', 'PPI_20', 'per_20', 'pbr_20', '원달러_20', '원엔_20', '3년물 _20', '10년물 _20', 'treasury_10_3_diff_20', 'T10Y2Y_20', 'usa_cpi_20', 'us_e_infla_20', 'yield_gap(%)_20', 'cpi_20', 'export_20', '구리선물_20', '중국고정자산투자(yoy%)_20', '중국 PMI_20', '금 선물_20', '달러 인덱스_20', '중국 소매판매_20', '중국 산업 생산_20', 'MSCI_EMER_20', 'SOX_20', '메모리 수출금액_20', 'WTI_60', 'DGS2_60', 'DGS10_60', 'TIPS_60', 'VIX_60', 'PPI_60', 'per_60', 'pbr_60', '원달러_60', '원엔_60', '3년물 _60', '10년물 _60', 'treasury_10_3_diff_60', 'T10Y2Y_60', 'usa_cpi_60', 'us_e_infla_60', 'yield_gap(%)_60', 'cpi_60', 'export_60', '구리선물_60', '중국고정자산투자(yoy%)_60', '중국 PMI_60', '금 선물_60', '달러 인덱스_60', '중국 소매판매_60', '중국 산업 생산_60', 'MSCI_EMER_60', 'SOX_60', '메모리 수출금액_60']
# Column names for bank: ['bank', 'WTI', 'DGS2', 'DGS10', 'TIPS', 'VIX', 'PPI', 'per', 'pbr', '원달러', '원엔', '3년물 ', '10년물 ', 'treasury_10_3_diff', 'T10Y2Y', 'usa_cpi', 'us_e_infla', 'yield_gap(%)', 'cpi', 'export', '구리선물', '중국고정자산투자(yoy%)', '중국 PMI', '금 선물', '달러 인덱스', '중국 소매판매', '중국 산업 생산', 'MSCI_EMER', 'bank_dividend', 'call_rate', 'WTI_20', 'DGS2_20', 'DGS10_20', 'TIPS_20', 'VIX_20', 'PPI_20', 'per_20', 'pbr_20', '원달러_20', '원엔_20', '3년물 _20', '10년물 _20', 'treasury_10_3_diff_20', 'T10Y2Y_20', 'usa_cpi_20', 'us_e_infla_20', 'yield_gap(%)_20', 'cpi_20', 'export_20', '구리선물_20', '중국고정자산투자(yoy%)_20', '중국 PMI_20', '금 선물_20', '달러 인덱스_20', '중국 소매판매_20', '중국 산업 생산_20', 'MSCI_EMER_20', 'bank_dividend_20', 'call_rate_20', 'WTI_60', 'DGS2_60', 'DGS10_60', 'TIPS_60', 'VIX_60', 'PPI_60', 'per_60', 'pbr_60', '원달러_60', '원엔_60', '3년물 _60', '10년물 _60', 'treasury_10_3_diff_60', 'T10Y2Y_60', 'usa_cpi_60', 'us_e_infla_60', 'yield_gap(%)_60', 'cpi_60', 'export_60', '구리선물_60', '중국고정자산투자(yoy%)_60', '중국 PMI_60', '금 선물_60', '달러 인덱스_60', '중국 소매판매_60', '중국 산업 생산_60', 'MSCI_EMER_60', 'bank_dividend_60', 'call_rate_60']
# Column names for steel: ['steel', 'WTI', 'DGS2', 'DGS10', 'TIPS', 'VIX', 'PPI', 'per', 'pbr', '원달러', '원엔', '3년물 ', '10년물 ', 'treasury_10_3_diff', 'T10Y2Y', 'usa_cpi', 'us_e_infla', 'yield_gap(%)', 'cpi', 'export', '구리선물', '중국고정자산투자(yoy%)', '중국 PMI', '금 선물', '달러 인덱스', '중국 소매판매', '중국 산업 생산', 'MSCI_EMER', '철광석 가격', '미국 철강 코일 선물', 'WTI_20', 'DGS2_20', 'DGS10_20', 'TIPS_20', 'VIX_20', 'PPI_20', 'per_20', 'pbr_20', '원달러_20', '원엔_20', '3년물 _20', '10년물 _20', 'treasury_10_3_diff_20', 'T10Y2Y_20', 'usa_cpi_20', 'us_e_infla_20', 'yield_gap(%)_20', 'cpi_20', 'export_20', '구리선물_20', '중국고정자산투자(yoy%)_20', '중국 PMI_20', '금 선물_20', '달러 인덱스_20', '중국 소매판매_20', '중국 산업 생산_20', 'MSCI_EMER_20', '철광석 가격_20', '미국 철강 코일 선물_20', 'WTI_60', 'DGS2_60', 'DGS10_60', 'TIPS_60', 'VIX_60', 'PPI_60', 'per_60', 'pbr_60', '원달러_60', '원엔_60', '3년물 _60', '10년물 _60', 'treasury_10_3_diff_60', 'T10Y2Y_60', 'usa_cpi_60', 'us_e_infla_60', 'yield_gap(%)_60', 'cpi_60', 'export_60', '구리선물_60', '중국고정자산투자(yoy%)_60', '중국 PMI_60', '금 선물_60', '달러 인덱스_60', '중국 소매판매_60', '중국 산업 생산_60', 'MSCI_EMER_60', '철광석 가격_60', '미국 철강 코일 선물_60']
# Column names for telecom: ['telecom', 'WTI', 'DGS2', 'DGS10', 'TIPS', 'VIX', 'PPI', 'per', 'pbr', '원달러', '원엔', '3년물 ', '10년물 ', 'treasury_10_3_diff', 'T10Y2Y', 'usa_cpi', 'us_e_infla', 'yield_gap(%)', 'cpi', 'export', '구리선물', '중국고정자산투자(yoy%)', '중국 PMI', '금 선물', '달러 인덱스', '중국 소매판매', '중국 산업 생산', 'MSCI_EMER', '통신배당', 'IT산업별/월별 수출 현황 중 통신기기 소계', 'WTI_20', 'DGS2_20', 'DGS10_20', 'TIPS_20', 'VIX_20', 'PPI_20', 'per_20', 'pbr_20', '원달러_20', '원엔_20', '3년물 _20', '10년물 _20', 'treasury_10_3_diff_20', 'T10Y2Y_20', 'usa_cpi_20', 'us_e_infla_20', 'yield_gap(%)_20', 'cpi_20', 'export_20', '구리선물_20', '중국고정자산투자(yoy%)_20', '중국 PMI_20', '금 선물_20', '달러 인덱스_20', '중국 소매판매_20', '중국 산업 생산_20', 'MSCI_EMER_20', '통신배당_20', 'IT산업별/월별 수출 현황 중 통신기기 소계_20', 'WTI_60', 'DGS2_60', 'DGS10_60', 'TIPS_60', 'VIX_60', 'PPI_60', 'per_60', 'pbr_60', '원달러_60', '원엔_60', '3년물 _60', '10년물 _60', 'treasury_10_3_diff_60', 'T10Y2Y_60', 'usa_cpi_60', 'us_e_infla_60', 'yield_gap(%)_60', 'cpi_60', 'export_60', '구리선물_60', '중국고정자산투자(yoy%)_60', '중국 PMI_60', '금 선물_60', '달러 인덱스_60', '중국 소매판매_60', '중국 산업 생산_60', 'MSCI_EMER_60', '통신배당_60', 'IT산업별/월별 수출 현황 중 통신기기 소계_60']
# Column names for staples: ['staples', 'WTI', 'DGS2', 'DGS10', 'TIPS', 'VIX', 'PPI', 'per', 'pbr', '원달러', '원엔', '3년물 ', '10년물 ', 'treasury_10_3_diff', 'T10Y2Y', 'usa_cpi', 'us_e_infla', 'yield_gap(%)', 'cpi', 'export', '구리선물', '중국고정자산투자(yoy%)', '중국 PMI', '금 선물', '달러 인덱스', '중국 소매판매', '중국 산업 생산', 'MSCI_EMER', '미 소맥 선물 ', '미 대두 선물 ', 'WTI_20', 'DGS2_20', 'DGS10_20', 'TIPS_20', 'VIX_20', 'PPI_20', 'per_20', 'pbr_20', '원달러_20', '원엔_20', '3년물 _20', '10년물 _20', 'treasury_10_3_diff_20', 'T10Y2Y_20', 'usa_cpi_20', 'us_e_infla_20', 'yield_gap(%)_20', 'cpi_20', 'export_20', '구리선물_20', '중국고정자산투자(yoy%)_20', '중국 PMI_20', '금 선물_20', '달러 인덱스_20', '중국 소매판매_20', '중국 산업 생산_20', 'MSCI_EMER_20', '미 소맥 선물 _20', '미 대두 선물 _20', 'WTI_60', 'DGS2_60', 'DGS10_60', 'TIPS_60', 'VIX_60', 'PPI_60', 'per_60', 'pbr_60', '원달러_60', '원엔_60', '3년물 _60', '10년물 _60', 'treasury_10_3_diff_60', 'T10Y2Y_60', 'usa_cpi_60', 'us_e_infla_60', 'yield_gap(%)_60', 'cpi_60', 'export_60', '구리선물_60', '중국고정자산투자(yoy%)_60', '중국 PMI_60', '금 선물_60', '달러 인덱스_60', '중국 소매판매_60', '중국 산업 생산_60', 'MSCI_EMER_60', '미 소맥 선물 _60', '미 대두 선물 _60']
# Column names for discretionary: ['discretionary', 'WTI', 'DGS2', 'DGS10', 'TIPS', 'VIX', 'PPI', 'per', 'pbr', '원달러', '원엔', '3년물 ', '10년물 ', 'treasury_10_3_diff', 'T10Y2Y', 'usa_cpi', 'us_e_infla', 'yield_gap(%)', 'cpi', 'export', '구리선물', '중국고정자산투자(yoy%)', '중국 PMI', '금 선물', '달러 인덱스', '중국 소매판매', '중국 산업 생산', 'MSCI_EMER', '항공 여객', '소비자심리지수', 'WTI_20', 'DGS2_20', 'DGS10_20', 'TIPS_20', 'VIX_20', 'PPI_20', 'per_20', 'pbr_20', '원달러_20', '원엔_20', '3년물 _20', '10년물 _20', 'treasury_10_3_diff_20', 'T10Y2Y_20', 'usa_cpi_20', 'us_e_infla_20', 'yield_gap(%)_20', 'cpi_20', 'export_20', '구리선물_20', '중국고정자산투자(yoy%)_20', '중국 PMI_20', '금 선물_20', '달러 인덱스_20', '중국 소매판매_20', '중국 산업 생산_20', 'MSCI_EMER_20', '항공 여객_20', '소비자심리지수_20', 'WTI_60', 'DGS2_60', 'DGS10_60', 'TIPS_60', 'VIX_60', 'PPI_60', 'per_60', 'pbr_60', '원달러_60', '원엔_60', '3년물 _60', '10년물 _60', 'treasury_10_3_diff_60', 'T10Y2Y_60', 'usa_cpi_60', 'us_e_infla_60', 'yield_gap(%)_60', 'cpi_60', 'export_60', '구리선물_60', '중국고정자산투자(yoy%)_60', '중국 PMI_60', '금 선물_60', '달러 인덱스_60', '중국 소매판매_60', '중국 산업 생산_60', 'MSCI_EMER_60', '항공 여객_60', '소비자심리지수_60']
# Column names for kospi: ['kospi', 'WTI', 'DGS2', 'DGS10', 'TIPS', 'VIX', 'PPI', 'per', 'pbr', '원달러', '원엔', '3년물 ', '10년물 ', 'treasury_10_3_diff', 'T10Y2Y', 'usa_cpi', 'us_e_infla', 'yield_gap(%)', 'cpi', 'export', '구리선물', '중국고정자산투자(yoy%)', '중국 PMI', '금 선물', '달러 인덱스', '중국 소매판매', '중국 산업 생산', 'MSCI_EMER', 'WTI_20', 'DGS2_20', 'DGS10_20', 'TIPS_20', 'VIX_20', 'PPI_20', 'per_20', 'pbr_20', '원달러_20', '원엔_20', '3년물 _20', '10년물 _20', 'treasury_10_3_diff_20', 'T10Y2Y_20', 'usa_cpi_20', 'us_e_infla_20', 'yield_gap(%)_20', 'cpi_20', 'export_20', '구리선물_20', '중국고정자산투자(yoy%)_20', '중국 PMI_20', '금 선물_20', '달러 인덱스_20', '중국 소매판매_20', '중국 산업 생산_20', 'MSCI_EMER_20', 'WTI_60', 'DGS2_60', 'DGS10_60', 'TIPS_60', 'VIX_60', 'PPI_60', 'per_60', 'pbr_60', '원달러_60', '원엔_60', '3년물 _60', '10년물 _60', 'treasury_10_3_diff_60', 'T10Y2Y_60', 'usa_cpi_60', 'us_e_infla_60', 'yield_gap(%)_60', 'cpi_60', 'export_60', '구리선물_60', '중국고정자산투자(yoy%)_60', '중국 PMI_60', '금 선물_60', '달러 인덱스_60', '중국 소매판매_60', '중국 산업 생산_60', 'MSCI_EMER_60']

# %%
print(len(df_index_kospi.columns))
print(len(df_index_discretionary.columns))
# Out:
# 82
# 88

# %%
# 첫 2개 행을 출력
for keyword, df in dfs.items():
    print(f"Top 2 rows of {keyword}:")
    print(df.head(2))
    print(f"Column names for {keyword}: {column_names_per_keyword[keyword]}")
# Out:
# Top 2 rows of auto:
#              auto    WTI  DGS2  DGS10  TIPS    VIX    PPI    per    pbr  \
# date
# 2010-04-01  S_buy  84.53  1.05   3.89  1.61  17.47  172.2  24.13  24.13
# 2010-04-05  S_buy  86.36  1.18   4.01  1.70  17.02  172.2  24.22  24.22
#
#                원달러  ...   구리선물_60  중국고정자산투자(yoy%)_60  중국 PMI_60   금 선물_60  \
# date                ...
# 2010-04-01  1131.3  ...  0.000842          -0.003191  -0.001859 -0.000108
# 2010-04-05  1126.0  ...  0.001063          -0.003258  -0.001785 -0.000062
#
#             달러 인덱스_60  중국 소매판매_60  중국 산업 생산_60  MSCI_EMER_60  US_auto_60  \
# date
# 2010-04-01   0.000870    0.006153    -0.007687      0.000181   -0.001737
# 2010-04-05   0.000855    0.006087    -0.007304      0.000369   -0.001560
#
#             export_auto_60
# date
# 2010-04-01       -0.007820
# 2010-04-05       -0.007609
#
# [2 rows x 88 columns]
# Column names for auto: ['auto', 'WTI', 'DGS2', 'DGS10', 'TIPS', 'VIX', 'PPI', 'per', 'pbr', '원달러', '원엔', '3년물 ', '10년물 ', 'treasury_10_3_diff', 'T10Y2Y', 'usa_cpi', 'us_e_infla', 'yield_gap(%)', 'cpi', 'export', '구리선물', '중국고정자산투자(yoy%)', '중국 PMI', '금 선물', '달러 인덱스', '중국 소매판매', '중국 산업 생산', 'MSCI_EMER', 'US_auto', 'export_auto', 'WTI_20', 'DGS2_20', 'DGS10_20', 'TIPS_20', 'VIX_20', 'PPI_20', 'per_20', 'pbr_20', '원달러_20', '원엔_20', '3년물 _20', '10년물 _20', 'treasury_10_3_diff_20', 'T10Y2Y_20', 'usa_cpi_20', 'us_e_infla_20', 'yield_gap(%)_20', 'cpi_20', 'export_20', '구리선물_20', '중국고정자산투자(yoy%)_20', '중국 PMI_20', '금 선물_20', '달러 인덱스_20', '중국 소매판매_20', '중국 산업 생산_20', 'MSCI_EMER_20', 'US_auto_20', 'export_auto_20', 'WTI_60', 'DGS2_60', 'DGS10_60', 'TIPS_60', 'VIX_60', 'PPI_60', 'per_60', 'pbr_60', '원달러_60', '원엔_60', '3년물 _60', '10년물 _60', 'treasury_10_3_diff_60', 'T10Y2Y_60', 'usa_cpi_60', 'us_e_infla_60', 'yield_gap(%)_60', 'cpi_60', 'export_60', '구리선물_60', '중국고정자산투자(yoy%)_60', '중국 PMI_60', '금 선물_60', '달러 인덱스_60', '중국 소매판매_60', '중국 산업 생산_60', 'MSCI_EMER_60', 'US_auto_60', 'export_auto_60']
# Top 2 rows of construct:
#            construct    WTI  DGS2  DGS10  TIPS    VIX    PPI    per    pbr  \
# date
# 2010-04-01      sell  84.53  1.05   3.89  1.61  17.47  172.2  24.13  24.13
# 2010-04-05      sell  86.36  1.18   4.01  1.70  17.02  172.2  24.22  24.22
#
#                원달러  ...   구리선물_60  중국고정자산투자(yoy%)_60  중국 PMI_60   금 선물_60  \
# date                ...
# 2010-04-01  1131.3  ...  0.000842          -0.003191  -0.001859 -0.000108
# 2010-04-05  1126.0  ...  0.001063          -0.003258  -0.001785 -0.000062
#
#             달러 인덱스_60  중국 소매판매_60  중국 산업 생산_60  MSCI_EMER_60     매매가격지수_60  \
# date
# 2010-04-01   0.000870    0.006153    -0.007687      0.000181 -3.265909e-18
# 2010-04-05   0.000855    0.006087    -0.007304      0.000369 -3.265909e-18
#
#             아파트매매거래량_60
# date
# 2010-04-01     0.006943
# 2010-04-05     0.006711
#
# [2 rows x 88 columns]
# Column names for construct: ['construct', 'WTI', 'DGS2', 'DGS10', 'TIPS', 'VIX', 'PPI', 'per', 'pbr', '원달러', '원엔', '3년물 ', '10년물 ', 'treasury_10_3_diff', 'T10Y2Y', 'usa_cpi', 'us_e_infla', 'yield_gap(%)', 'cpi', 'export', '구리선물', '중국고정자산투자(yoy%)', '중국 PMI', '금 선물', '달러 인덱스', '중국 소매판매', '중국 산업 생산', 'MSCI_EMER', '매매가격지수', '아파트매매거래량', 'WTI_20', 'DGS2_20', 'DGS10_20', 'TIPS_20', 'VIX_20', 'PPI_20', 'per_20', 'pbr_20', '원달러_20', '원엔_20', '3년물 _20', '10년물 _20', 'treasury_10_3_diff_20', 'T10Y2Y_20', 'usa_cpi_20', 'us_e_infla_20', 'yield_gap(%)_20', 'cpi_20', 'export_20', '구리선물_20', '중국고정자산투자(yoy%)_20', '중국 PMI_20', '금 선물_20', '달러 인덱스_20', '중국 소매판매_20', '중국 산업 생산_20', 'MSCI_EMER_20', '매매가격지수_20', '아파트매매거래량_20', 'WTI_60', 'DGS2_60', 'DGS10_60', 'TIPS_60', 'VIX_60', 'PPI_60', 'per_60', 'pbr_60', '원달러_60', '원엔_60', '3년물 _60', '10년물 _60', 'treasury_10_3_diff_60', 'T10Y2Y_60', 'usa_cpi_60', 'us_e_infla_60', 'yield_gap(%)_60', 'cpi_60', 'export_60', '구리선물_60', '중국고정자산투자(yoy%)_60', '중국 PMI_60', '금 선물_60', '달러 인덱스_60', '중국 소매판매_60', '중국 산업 생산_60', 'MSCI_EMER_60', '매매가격지수_60', '아파트매매거래량_60']
# Top 2 rows of capital_market:
#            capital_market    WTI  DGS2  DGS10  TIPS    VIX    PPI    per  \
# date
# 2010-04-01           sell  84.53  1.05   3.89  1.61  17.47  172.2  24.13
# 2010-04-05           sell  86.36  1.18   4.01  1.70  17.02  172.2  24.22
#
#               pbr     원달러  ...   구리선물_60  중국고정자산투자(yoy%)_60  중국 PMI_60  \
# date                       ...
# 2010-04-01  24.13  1131.3  ...  0.000842          -0.003191  -0.001859
# 2010-04-05  24.22  1126.0  ...  0.001063          -0.003258  -0.001785
#
#              금 선물_60  달러 인덱스_60  중국 소매판매_60  중국 산업 생산_60  MSCI_EMER_60  \
# date
# 2010-04-01 -0.000108   0.000870    0.006153    -0.007687      0.000181
# 2010-04-05 -0.000062   0.000855    0.006087    -0.007304      0.000369
#
#             증권 배당 수익률_60  코스피+코스닥 거래량_60
# date
# 2010-04-01      0.001074       -0.003238
# 2010-04-05      0.000955       -0.003512
#
# [2 rows x 88 columns]
# Column names for capital_market: ['capital_market', 'WTI', 'DGS2', 'DGS10', 'TIPS', 'VIX', 'PPI', 'per', 'pbr', '원달러', '원엔', '3년물 ', '10년물 ', 'treasury_10_3_diff', 'T10Y2Y', 'usa_cpi', 'us_e_infla', 'yield_gap(%)', 'cpi', 'export', '구리선물', '중국고정자산투자(yoy%)', '중국 PMI', '금 선물', '달러 인덱스', '중국 소매판매', '중국 산업 생산', 'MSCI_EMER', '증권 배당 수익률', '코스피+코스닥 거래량', 'WTI_20', 'DGS2_20', 'DGS10_20', 'TIPS_20', 'VIX_20', 'PPI_20', 'per_20', 'pbr_20', '원달러_20', '원엔_20', '3년물 _20', '10년물 _20', 'treasury_10_3_diff_20', 'T10Y2Y_20', 'usa_cpi_20', 'us_e_infla_20', 'yield_gap(%)_20', 'cpi_20', 'export_20', '구리선물_20', '중국고정자산투자(yoy%)_20', '중국 PMI_20', '금 선물_20', '달러 인덱스_20', '중국 소매판매_20', '중국 산업 생산_20', 'MSCI_EMER_20', '증권 배당 수익률_20', '코스피+코스닥 거래량_20', 'WTI_60', 'DGS2_60', 'DGS10_60', 'TIPS_60', 'VIX_60', 'PPI_60', 'per_60', 'pbr_60', '원달러_60', '원엔_60', '3년물 _60', '10년물 _60', 'treasury_10_3_diff_60', 'T10Y2Y_60', 'usa_cpi_60', 'us_e_infla_60', 'yield_gap(%)_60', 'cpi_60', 'export_60', '구리선물_60', '중국고정자산투자(yoy%)_60', '중국 PMI_60', '금 선물_60', '달러 인덱스_60', '중국 소매판매_60', '중국 산업 생산_60', 'MSCI_EMER_60', '증권 배당 수익률_60', '코스피+코스닥 거래량_60']
# Top 2 rows of chemicals:
#            chemicals    WTI  DGS2  DGS10  TIPS    VIX    PPI    per    pbr  \
# date
# 2010-04-01     S_buy  84.53  1.05   3.89  1.61  17.47  172.2  24.13  24.13
# 2010-04-05     S_buy  86.36  1.18   4.01  1.70  17.02  172.2  24.22  24.22
#
#                원달러  ...   구리선물_60  중국고정자산투자(yoy%)_60  중국 PMI_60   금 선물_60  \
# date                ...
# 2010-04-01  1131.3  ...  0.000842          -0.003191  -0.001859 -0.000108
# 2010-04-05  1126.0  ...  0.001063          -0.003258  -0.001785 -0.000062
#
#             달러 인덱스_60  중국 소매판매_60  중국 산업 생산_60  MSCI_EMER_60  lc_price_60  \
# date
# 2010-04-01   0.000870    0.006153    -0.007687      0.000181     0.000260
# 2010-04-05   0.000855    0.006087    -0.007304      0.000369     0.000271
#
#             naphtha_price_60
# date
# 2010-04-01          0.000091
# 2010-04-05          0.000207
#
# [2 rows x 88 columns]
# Column names for chemicals: ['chemicals', 'WTI', 'DGS2', 'DGS10', 'TIPS', 'VIX', 'PPI', 'per', 'pbr', '원달러', '원엔', '3년물 ', '10년물 ', 'treasury_10_3_diff', 'T10Y2Y', 'usa_cpi', 'us_e_infla', 'yield_gap(%)', 'cpi', 'export', '구리선물', '중국고정자산투자(yoy%)', '중국 PMI', '금 선물', '달러 인덱스', '중국 소매판매', '중국 산업 생산', 'MSCI_EMER', 'lc_price', 'naphtha_price', 'WTI_20', 'DGS2_20', 'DGS10_20', 'TIPS_20', 'VIX_20', 'PPI_20', 'per_20', 'pbr_20', '원달러_20', '원엔_20', '3년물 _20', '10년물 _20', 'treasury_10_3_diff_20', 'T10Y2Y_20', 'usa_cpi_20', 'us_e_infla_20', 'yield_gap(%)_20', 'cpi_20', 'export_20', '구리선물_20', '중국고정자산투자(yoy%)_20', '중국 PMI_20', '금 선물_20', '달러 인덱스_20', '중국 소매판매_20', '중국 산업 생산_20', 'MSCI_EMER_20', 'lc_price_20', 'naphtha_price_20', 'WTI_60', 'DGS2_60', 'DGS10_60', 'TIPS_60', 'VIX_60', 'PPI_60', 'per_60', 'pbr_60', '원달러_60', '원엔_60', '3년물 _60', '10년물 _60', 'treasury_10_3_diff_60', 'T10Y2Y_60', 'usa_cpi_60', 'us_e_infla_60', 'yield_gap(%)_60', 'cpi_60', 'export_60', '구리선물_60', '중국고정자산투자(yoy%)_60', '중국 PMI_60', '금 선물_60', '달러 인덱스_60', '중국 소매판매_60', '중국 산업 생산_60', 'MSCI_EMER_60', 'lc_price_60', 'naphtha_price_60']
# Top 2 rows of equipment:
#            equipment    WTI  DGS2  DGS10  TIPS    VIX    PPI    per    pbr  \
# date
# 2010-04-01     S_buy  84.53  1.05   3.89  1.61  17.47  172.2  24.13  24.13
# 2010-04-05     S_buy  86.36  1.18   4.01  1.70  17.02  172.2  24.22  24.22
#
#                원달러  ...   구리선물_60  중국고정자산투자(yoy%)_60  중국 PMI_60   금 선물_60  \
# date                ...
# 2010-04-01  1131.3  ...  0.000842          -0.003191  -0.001859 -0.000108
# 2010-04-05  1126.0  ...  0.001063          -0.003258  -0.001785 -0.000062
#
#             달러 인덱스_60  중국 소매판매_60  중국 산업 생산_60  MSCI_EMER_60  기계수주경상금액_60  \
# date
# 2010-04-01   0.000870    0.006153    -0.007687      0.000181     0.005828
# 2010-04-05   0.000855    0.006087    -0.007304      0.000369     0.005371
#
#             BSI 제조업경기실사지수_60
# date
# 2010-04-01          0.001719
# 2010-04-05          0.001749
#
# [2 rows x 88 columns]
# Column names for equipment: ['equipment', 'WTI', 'DGS2', 'DGS10', 'TIPS', 'VIX', 'PPI', 'per', 'pbr', '원달러', '원엔', '3년물 ', '10년물 ', 'treasury_10_3_diff', 'T10Y2Y', 'usa_cpi', 'us_e_infla', 'yield_gap(%)', 'cpi', 'export', '구리선물', '중국고정자산투자(yoy%)', '중국 PMI', '금 선물', '달러 인덱스', '중국 소매판매', '중국 산업 생산', 'MSCI_EMER', '기계수주경상금액', 'BSI 제조업경기실사지수', 'WTI_20', 'DGS2_20', 'DGS10_20', 'TIPS_20', 'VIX_20', 'PPI_20', 'per_20', 'pbr_20', '원달러_20', '원엔_20', '3년물 _20', '10년물 _20', 'treasury_10_3_diff_20', 'T10Y2Y_20', 'usa_cpi_20', 'us_e_infla_20', 'yield_gap(%)_20', 'cpi_20', 'export_20', '구리선물_20', '중국고정자산투자(yoy%)_20', '중국 PMI_20', '금 선물_20', '달러 인덱스_20', '중국 소매판매_20', '중국 산업 생산_20', 'MSCI_EMER_20', '기계수주경상금액_20', 'BSI 제조업경기실사지수_20', 'WTI_60', 'DGS2_60', 'DGS10_60', 'TIPS_60', 'VIX_60', 'PPI_60', 'per_60', 'pbr_60', '원달러_60', '원엔_60', '3년물 _60', '10년물 _60', 'treasury_10_3_diff_60', 'T10Y2Y_60', 'usa_cpi_60', 'us_e_infla_60', 'yield_gap(%)_60', 'cpi_60', 'export_60', '구리선물_60', '중국고정자산투자(yoy%)_60', '중국 PMI_60', '금 선물_60', '달러 인덱스_60', '중국 소매판매_60', '중국 산업 생산_60', 'MSCI_EMER_60', '기계수주경상금액_60', 'BSI 제조업경기실사지수_60']
# Top 2 rows of transport:
#            transport    WTI  DGS2  DGS10  TIPS    VIX    PPI    per    pbr  \
# date
# 2010-04-01       buy  84.53  1.05   3.89  1.61  17.47  172.2  24.13  24.13
# 2010-04-05       buy  86.36  1.18   4.01  1.70  17.02  172.2  24.22  24.22
#
#                원달러  ...   구리선물_60  중국고정자산투자(yoy%)_60  중국 PMI_60   금 선물_60  \
# date                ...
# 2010-04-01  1131.3  ...  0.000842          -0.003191  -0.001859 -0.000108
# 2010-04-05  1126.0  ...  0.001063          -0.003258  -0.001785 -0.000062
#
#             달러 인덱스_60  중국 소매판매_60  중국 산업 생산_60  MSCI_EMER_60   발틱운임_60  \
# date
# 2010-04-01   0.000870    0.006153    -0.007687      0.000181  0.000709
# 2010-04-05   0.000855    0.006087    -0.007304      0.000369  0.000821
#
#              scfi_60
# date
# 2010-04-01  0.004156
# 2010-04-05  0.003920
#
# [2 rows x 88 columns]
# Column names for transport: ['transport', 'WTI', 'DGS2', 'DGS10', 'TIPS', 'VIX', 'PPI', 'per', 'pbr', '원달러', '원엔', '3년물 ', '10년물 ', 'treasury_10_3_diff', 'T10Y2Y', 'usa_cpi', 'us_e_infla', 'yield_gap(%)', 'cpi', 'export', '구리선물', '중국고정자산투자(yoy%)', '중국 PMI', '금 선물', '달러 인덱스', '중국 소매판매', '중국 산업 생산', 'MSCI_EMER', '발틱운임', 'scfi', 'WTI_20', 'DGS2_20', 'DGS10_20', 'TIPS_20', 'VIX_20', 'PPI_20', 'per_20', 'pbr_20', '원달러_20', '원엔_20', '3년물 _20', '10년물 _20', 'treasury_10_3_diff_20', 'T10Y2Y_20', 'usa_cpi_20', 'us_e_infla_20', 'yield_gap(%)_20', 'cpi_20', 'export_20', '구리선물_20', '중국고정자산투자(yoy%)_20', '중국 PMI_20', '금 선물_20', '달러 인덱스_20', '중국 소매판매_20', '중국 산업 생산_20', 'MSCI_EMER_20', '발틱운임_20', 'scfi_20', 'WTI_60', 'DGS2_60', 'DGS10_60', 'TIPS_60', 'VIX_60', 'PPI_60', 'per_60', 'pbr_60', '원달러_60', '원엔_60', '3년물 _60', '10년물 _60', 'treasury_10_3_diff_60', 'T10Y2Y_60', 'usa_cpi_60', 'us_e_infla_60', 'yield_gap(%)_60', 'cpi_60', 'export_60', '구리선물_60', '중국고정자산투자(yoy%)_60', '중국 PMI_60', '금 선물_60', '달러 인덱스_60', '중국 소매판매_60', '중국 산업 생산_60', 'MSCI_EMER_60', '발틱운임_60', 'scfi_60']
# Top 2 rows of semi:
#              semi    WTI  DGS2  DGS10  TIPS    VIX    PPI    per    pbr  \
# date
# 2010-04-01  S_buy  84.53  1.05   3.89  1.61  17.47  172.2  24.13  24.13
# 2010-04-05    buy  86.36  1.18   4.01  1.70  17.02  172.2  24.22  24.22
#
#                원달러  ...   구리선물_60  중국고정자산투자(yoy%)_60  중국 PMI_60   금 선물_60  \
# date                ...
# 2010-04-01  1131.3  ...  0.000842          -0.003191  -0.001859 -0.000108
# 2010-04-05  1126.0  ...  0.001063          -0.003258  -0.001785 -0.000062
#
#             달러 인덱스_60  중국 소매판매_60  중국 산업 생산_60  MSCI_EMER_60    SOX_60  \
# date
# 2010-04-01   0.000870    0.006153    -0.007687      0.000181  0.000914
# 2010-04-05   0.000855    0.006087    -0.007304      0.000369  0.001153
#
#             메모리 수출금액_60
# date
# 2010-04-01    -0.000189
# 2010-04-05    -0.000207
#
# [2 rows x 88 columns]
# Column names for semi: ['semi', 'WTI', 'DGS2', 'DGS10', 'TIPS', 'VIX', 'PPI', 'per', 'pbr', '원달러', '원엔', '3년물 ', '10년물 ', 'treasury_10_3_diff', 'T10Y2Y', 'usa_cpi', 'us_e_infla', 'yield_gap(%)', 'cpi', 'export', '구리선물', '중국고정자산투자(yoy%)', '중국 PMI', '금 선물', '달러 인덱스', '중국 소매판매', '중국 산업 생산', 'MSCI_EMER', 'SOX', '메모리 수출금액', 'WTI_20', 'DGS2_20', 'DGS10_20', 'TIPS_20', 'VIX_20', 'PPI_20', 'per_20', 'pbr_20', '원달러_20', '원엔_20', '3년물 _20', '10년물 _20', 'treasury_10_3_diff_20', 'T10Y2Y_20', 'usa_cpi_20', 'us_e_infla_20', 'yield_gap(%)_20', 'cpi_20', 'export_20', '구리선물_20', '중국고정자산투자(yoy%)_20', '중국 PMI_20', '금 선물_20', '달러 인덱스_20', '중국 소매판매_20', '중국 산업 생산_20', 'MSCI_EMER_20', 'SOX_20', '메모리 수출금액_20', 'WTI_60', 'DGS2_60', 'DGS10_60', 'TIPS_60', 'VIX_60', 'PPI_60', 'per_60', 'pbr_60', '원달러_60', '원엔_60', '3년물 _60', '10년물 _60', 'treasury_10_3_diff_60', 'T10Y2Y_60', 'usa_cpi_60', 'us_e_infla_60', 'yield_gap(%)_60', 'cpi_60', 'export_60', '구리선물_60', '중국고정자산투자(yoy%)_60', '중국 PMI_60', '금 선물_60', '달러 인덱스_60', '중국 소매판매_60', '중국 산업 생산_60', 'MSCI_EMER_60', 'SOX_60', '메모리 수출금액_60']
# Top 2 rows of bank:
#            bank    WTI  DGS2  DGS10  TIPS    VIX    PPI    per    pbr     원달러  \
# date
# 2010-04-01  buy  84.53  1.05   3.89  1.61  17.47  172.2  24.13  24.13  1131.3
# 2010-04-05  buy  86.36  1.18   4.01  1.70  17.02  172.2  24.22  24.22  1126.0
#
#             ...   구리선물_60  중국고정자산투자(yoy%)_60  중국 PMI_60   금 선물_60  달러 인덱스_60  \
# date        ...
# 2010-04-01  ...  0.000842          -0.003191  -0.001859 -0.000108   0.000870
# 2010-04-05  ...  0.001063          -0.003258  -0.001785 -0.000062   0.000855
#
#             중국 소매판매_60  중국 산업 생산_60  MSCI_EMER_60  bank_dividend_60  \
# date
# 2010-04-01    0.006153    -0.007687      0.000181         -0.000169
# 2010-04-05    0.006087    -0.007304      0.000369         -0.000336
#
#             call_rate_60
# date
# 2010-04-01      0.000064
# 2010-04-05      0.000050
#
# [2 rows x 88 columns]
# Column names for bank: ['bank', 'WTI', 'DGS2', 'DGS10', 'TIPS', 'VIX', 'PPI', 'per', 'pbr', '원달러', '원엔', '3년물 ', '10년물 ', 'treasury_10_3_diff', 'T10Y2Y', 'usa_cpi', 'us_e_infla', 'yield_gap(%)', 'cpi', 'export', '구리선물', '중국고정자산투자(yoy%)', '중국 PMI', '금 선물', '달러 인덱스', '중국 소매판매', '중국 산업 생산', 'MSCI_EMER', 'bank_dividend', 'call_rate', 'WTI_20', 'DGS2_20', 'DGS10_20', 'TIPS_20', 'VIX_20', 'PPI_20', 'per_20', 'pbr_20', '원달러_20', '원엔_20', '3년물 _20', '10년물 _20', 'treasury_10_3_diff_20', 'T10Y2Y_20', 'usa_cpi_20', 'us_e_infla_20', 'yield_gap(%)_20', 'cpi_20', 'export_20', '구리선물_20', '중국고정자산투자(yoy%)_20', '중국 PMI_20', '금 선물_20', '달러 인덱스_20', '중국 소매판매_20', '중국 산업 생산_20', 'MSCI_EMER_20', 'bank_dividend_20', 'call_rate_20', 'WTI_60', 'DGS2_60', 'DGS10_60', 'TIPS_60', 'VIX_60', 'PPI_60', 'per_60', 'pbr_60', '원달러_60', '원엔_60', '3년물 _60', '10년물 _60', 'treasury_10_3_diff_60', 'T10Y2Y_60', 'usa_cpi_60', 'us_e_infla_60', 'yield_gap(%)_60', 'cpi_60', 'export_60', '구리선물_60', '중국고정자산투자(yoy%)_60', '중국 PMI_60', '금 선물_60', '달러 인덱스_60', '중국 소매판매_60', '중국 산업 생산_60', 'MSCI_EMER_60', 'bank_dividend_60', 'call_rate_60']
# Top 2 rows of steel:
#            steel    WTI  DGS2  DGS10  TIPS    VIX    PPI    per    pbr  \
# date
# 2010-04-01  sell  84.53  1.05   3.89  1.61  17.47  172.2  24.13  24.13
# 2010-04-05  sell  86.36  1.18   4.01  1.70  17.02  172.2  24.22  24.22
#
#                원달러  ...   구리선물_60  중국고정자산투자(yoy%)_60  중국 PMI_60   금 선물_60  \
# date                ...
# 2010-04-01  1131.3  ...  0.000842          -0.003191  -0.001859 -0.000108
# 2010-04-05  1126.0  ...  0.001063          -0.003258  -0.001785 -0.000062
#
#             달러 인덱스_60  중국 소매판매_60  중국 산업 생산_60  MSCI_EMER_60  철광석 가격_60  \
# date
# 2010-04-01   0.000870    0.006153    -0.007687      0.000181   0.007185
# 2010-04-05   0.000855    0.006087    -0.007304      0.000369   0.005671
#
#             미국 철강 코일 선물_60
# date
# 2010-04-01        0.003060
# 2010-04-05        0.003142
#
# [2 rows x 88 columns]
# Column names for steel: ['steel', 'WTI', 'DGS2', 'DGS10', 'TIPS', 'VIX', 'PPI', 'per', 'pbr', '원달러', '원엔', '3년물 ', '10년물 ', 'treasury_10_3_diff', 'T10Y2Y', 'usa_cpi', 'us_e_infla', 'yield_gap(%)', 'cpi', 'export', '구리선물', '중국고정자산투자(yoy%)', '중국 PMI', '금 선물', '달러 인덱스', '중국 소매판매', '중국 산업 생산', 'MSCI_EMER', '철광석 가격', '미국 철강 코일 선물', 'WTI_20', 'DGS2_20', 'DGS10_20', 'TIPS_20', 'VIX_20', 'PPI_20', 'per_20', 'pbr_20', '원달러_20', '원엔_20', '3년물 _20', '10년물 _20', 'treasury_10_3_diff_20', 'T10Y2Y_20', 'usa_cpi_20', 'us_e_infla_20', 'yield_gap(%)_20', 'cpi_20', 'export_20', '구리선물_20', '중국고정자산투자(yoy%)_20', '중국 PMI_20', '금 선물_20', '달러 인덱스_20', '중국 소매판매_20', '중국 산업 생산_20', 'MSCI_EMER_20', '철광석 가격_20', '미국 철강 코일 선물_20', 'WTI_60', 'DGS2_60', 'DGS10_60', 'TIPS_60', 'VIX_60', 'PPI_60', 'per_60', 'pbr_60', '원달러_60', '원엔_60', '3년물 _60', '10년물 _60', 'treasury_10_3_diff_60', 'T10Y2Y_60', 'usa_cpi_60', 'us_e_infla_60', 'yield_gap(%)_60', 'cpi_60', 'export_60', '구리선물_60', '중국고정자산투자(yoy%)_60', '중국 PMI_60', '금 선물_60', '달러 인덱스_60', '중국 소매판매_60', '중국 산업 생산_60', 'MSCI_EMER_60', '철광석 가격_60', '미국 철강 코일 선물_60']
# Top 2 rows of telecom:
#            telecom    WTI  DGS2  DGS10  TIPS    VIX    PPI    per    pbr  \
# date
# 2010-04-01   S_buy  84.53  1.05   3.89  1.61  17.47  172.2  24.13  24.13
# 2010-04-05   S_buy  86.36  1.18   4.01  1.70  17.02  172.2  24.22  24.22
#
#                원달러  ...   구리선물_60  중국고정자산투자(yoy%)_60  중국 PMI_60   금 선물_60  \
# date                ...
# 2010-04-01  1131.3  ...  0.000842          -0.003191  -0.001859 -0.000108
# 2010-04-05  1126.0  ...  0.001063          -0.003258  -0.001785 -0.000062
#
#             달러 인덱스_60  중국 소매판매_60  중국 산업 생산_60  MSCI_EMER_60   통신배당_60  \
# date
# 2010-04-01   0.000870    0.006153    -0.007687      0.000181  0.002829
# 2010-04-05   0.000855    0.006087    -0.007304      0.000369  0.002899
#
#             IT산업별/월별 수출 현황 중 통신기기 소계_60
# date
# 2010-04-01                    -0.001122
# 2010-04-05                    -0.000808
#
# [2 rows x 88 columns]
# Column names for telecom: ['telecom', 'WTI', 'DGS2', 'DGS10', 'TIPS', 'VIX', 'PPI', 'per', 'pbr', '원달러', '원엔', '3년물 ', '10년물 ', 'treasury_10_3_diff', 'T10Y2Y', 'usa_cpi', 'us_e_infla', 'yield_gap(%)', 'cpi', 'export', '구리선물', '중국고정자산투자(yoy%)', '중국 PMI', '금 선물', '달러 인덱스', '중국 소매판매', '중국 산업 생산', 'MSCI_EMER', '통신배당', 'IT산업별/월별 수출 현황 중 통신기기 소계', 'WTI_20', 'DGS2_20', 'DGS10_20', 'TIPS_20', 'VIX_20', 'PPI_20', 'per_20', 'pbr_20', '원달러_20', '원엔_20', '3년물 _20', '10년물 _20', 'treasury_10_3_diff_20', 'T10Y2Y_20', 'usa_cpi_20', 'us_e_infla_20', 'yield_gap(%)_20', 'cpi_20', 'export_20', '구리선물_20', '중국고정자산투자(yoy%)_20', '중국 PMI_20', '금 선물_20', '달러 인덱스_20', '중국 소매판매_20', '중국 산업 생산_20', 'MSCI_EMER_20', '통신배당_20', 'IT산업별/월별 수출 현황 중 통신기기 소계_20', 'WTI_60', 'DGS2_60', 'DGS10_60', 'TIPS_60', 'VIX_60', 'PPI_60', 'per_60', 'pbr_60', '원달러_60', '원엔_60', '3년물 _60', '10년물 _60', 'treasury_10_3_diff_60', 'T10Y2Y_60', 'usa_cpi_60', 'us_e_infla_60', 'yield_gap(%)_60', 'cpi_60', 'export_60', '구리선물_60', '중국고정자산투자(yoy%)_60', '중국 PMI_60', '금 선물_60', '달러 인덱스_60', '중국 소매판매_60', '중국 산업 생산_60', 'MSCI_EMER_60', '통신배당_60', 'IT산업별/월별 수출 현황 중 통신기기 소계_60']
# Top 2 rows of staples:
#            staples    WTI  DGS2  DGS10  TIPS    VIX    PPI    per    pbr  \
# date
# 2010-04-01     buy  84.53  1.05   3.89  1.61  17.47  172.2  24.13  24.13
# 2010-04-05    sell  86.36  1.18   4.01  1.70  17.02  172.2  24.22  24.22
#
#                원달러  ...   구리선물_60  중국고정자산투자(yoy%)_60  중국 PMI_60   금 선물_60  \
# date                ...
# 2010-04-01  1131.3  ...  0.000842          -0.003191  -0.001859 -0.000108
# 2010-04-05  1126.0  ...  0.001063          -0.003258  -0.001785 -0.000062
#
#             달러 인덱스_60  중국 소매판매_60  중국 산업 생산_60  MSCI_EMER_60  미 소맥 선물 _60  \
# date
# 2010-04-01   0.000870    0.006153    -0.007687      0.000181    -0.002022
# 2010-04-05   0.000855    0.006087    -0.007304      0.000369    -0.001980
#
#             미 대두 선물 _60
# date
# 2010-04-01    -0.000598
# 2010-04-05    -0.000451
#
# [2 rows x 88 columns]
# Column names for staples: ['staples', 'WTI', 'DGS2', 'DGS10', 'TIPS', 'VIX', 'PPI', 'per', 'pbr', '원달러', '원엔', '3년물 ', '10년물 ', 'treasury_10_3_diff', 'T10Y2Y', 'usa_cpi', 'us_e_infla', 'yield_gap(%)', 'cpi', 'export', '구리선물', '중국고정자산투자(yoy%)', '중국 PMI', '금 선물', '달러 인덱스', '중국 소매판매', '중국 산업 생산', 'MSCI_EMER', '미 소맥 선물 ', '미 대두 선물 ', 'WTI_20', 'DGS2_20', 'DGS10_20', 'TIPS_20', 'VIX_20', 'PPI_20', 'per_20', 'pbr_20', '원달러_20', '원엔_20', '3년물 _20', '10년물 _20', 'treasury_10_3_diff_20', 'T10Y2Y_20', 'usa_cpi_20', 'us_e_infla_20', 'yield_gap(%)_20', 'cpi_20', 'export_20', '구리선물_20', '중국고정자산투자(yoy%)_20', '중국 PMI_20', '금 선물_20', '달러 인덱스_20', '중국 소매판매_20', '중국 산업 생산_20', 'MSCI_EMER_20', '미 소맥 선물 _20', '미 대두 선물 _20', 'WTI_60', 'DGS2_60', 'DGS10_60', 'TIPS_60', 'VIX_60', 'PPI_60', 'per_60', 'pbr_60', '원달러_60', '원엔_60', '3년물 _60', '10년물 _60', 'treasury_10_3_diff_60', 'T10Y2Y_60', 'usa_cpi_60', 'us_e_infla_60', 'yield_gap(%)_60', 'cpi_60', 'export_60', '구리선물_60', '중국고정자산투자(yoy%)_60', '중국 PMI_60', '금 선물_60', '달러 인덱스_60', '중국 소매판매_60', '중국 산업 생산_60', 'MSCI_EMER_60', '미 소맥 선물 _60', '미 대두 선물 _60']
# Top 2 rows of discretionary:
#            discretionary    WTI  DGS2  DGS10  TIPS    VIX    PPI    per  \
# date
# 2010-04-01          sell  84.53  1.05   3.89  1.61  17.47  172.2  24.13
# 2010-04-05          sell  86.36  1.18   4.01  1.70  17.02  172.2  24.22
#
#               pbr     원달러  ...   구리선물_60  중국고정자산투자(yoy%)_60  중국 PMI_60  \
# date                       ...
# 2010-04-01  24.13  1131.3  ...  0.000842          -0.003191  -0.001859
# 2010-04-05  24.22  1126.0  ...  0.001063          -0.003258  -0.001785
#
#              금 선물_60  달러 인덱스_60  중국 소매판매_60  중국 산업 생산_60  MSCI_EMER_60  \
# date
# 2010-04-01 -0.000108   0.000870    0.006153    -0.007687      0.000181
# 2010-04-05 -0.000062   0.000855    0.006087    -0.007304      0.000369
#
#             항공 여객_60  소비자심리지수_60
# date
# 2010-04-01  0.001114   -0.000482
# 2010-04-05  0.001299   -0.000473
#
# [2 rows x 88 columns]
# Column names for discretionary: ['discretionary', 'WTI', 'DGS2', 'DGS10', 'TIPS', 'VIX', 'PPI', 'per', 'pbr', '원달러', '원엔', '3년물 ', '10년물 ', 'treasury_10_3_diff', 'T10Y2Y', 'usa_cpi', 'us_e_infla', 'yield_gap(%)', 'cpi', 'export', '구리선물', '중국고정자산투자(yoy%)', '중국 PMI', '금 선물', '달러 인덱스', '중국 소매판매', '중국 산업 생산', 'MSCI_EMER', '항공 여객', '소비자심리지수', 'WTI_20', 'DGS2_20', 'DGS10_20', 'TIPS_20', 'VIX_20', 'PPI_20', 'per_20', 'pbr_20', '원달러_20', '원엔_20', '3년물 _20', '10년물 _20', 'treasury_10_3_diff_20', 'T10Y2Y_20', 'usa_cpi_20', 'us_e_infla_20', 'yield_gap(%)_20', 'cpi_20', 'export_20', '구리선물_20', '중국고정자산투자(yoy%)_20', '중국 PMI_20', '금 선물_20', '달러 인덱스_20', '중국 소매판매_20', '중국 산업 생산_20', 'MSCI_EMER_20', '항공 여객_20', '소비자심리지수_20', 'WTI_60', 'DGS2_60', 'DGS10_60', 'TIPS_60', 'VIX_60', 'PPI_60', 'per_60', 'pbr_60', '원달러_60', '원엔_60', '3년물 _60', '10년물 _60', 'treasury_10_3_diff_60', 'T10Y2Y_60', 'usa_cpi_60', 'us_e_infla_60', 'yield_gap(%)_60', 'cpi_60', 'export_60', '구리선물_60', '중국고정자산투자(yoy%)_60', '중국 PMI_60', '금 선물_60', '달러 인덱스_60', '중국 소매판매_60', '중국 산업 생산_60', 'MSCI_EMER_60', '항공 여객_60', '소비자심리지수_60']
# Top 2 rows of kospi:
#            kospi    WTI  DGS2  DGS10  TIPS    VIX    PPI    per    pbr  \
# date
# 2010-04-01   buy  84.53  1.05   3.89  1.61  17.47  172.2  24.13  24.13
# 2010-04-05  sell  86.36  1.18   4.01  1.70  17.02  172.2  24.22  24.22
#
#                원달러  ...    cpi_60  export_60   구리선물_60  중국고정자산투자(yoy%)_60  \
# date                ...
# 2010-04-01  1131.3  ...  0.000667  -0.003721  0.000842          -0.003191
# 2010-04-05  1126.0  ...  0.000195  -0.004392  0.001063          -0.003258
#
#             중국 PMI_60   금 선물_60  달러 인덱스_60  중국 소매판매_60  중국 산업 생산_60  \
# date
# 2010-04-01  -0.001859 -0.000108   0.000870    0.006153    -0.007687
# 2010-04-05  -0.001785 -0.000062   0.000855    0.006087    -0.007304
#
#             MSCI_EMER_60
# date
# 2010-04-01      0.000181
# 2010-04-05      0.000369
#
# [2 rows x 82 columns]
# Column names for kospi: ['kospi', 'WTI', 'DGS2', 'DGS10', 'TIPS', 'VIX', 'PPI', 'per', 'pbr', '원달러', '원엔', '3년물 ', '10년물 ', 'treasury_10_3_diff', 'T10Y2Y', 'usa_cpi', 'us_e_infla', 'yield_gap(%)', 'cpi', 'export', '구리선물', '중국고정자산투자(yoy%)', '중국 PMI', '금 선물', '달러 인덱스', '중국 소매판매', '중국 산업 생산', 'MSCI_EMER', 'WTI_20', 'DGS2_20', 'DGS10_20', 'TIPS_20', 'VIX_20', 'PPI_20', 'per_20', 'pbr_20', '원달러_20', '원엔_20', '3년물 _20', '10년물 _20', 'treasury_10_3_diff_20', 'T10Y2Y_20', 'usa_cpi_20', 'us_e_infla_20', 'yield_gap(%)_20', 'cpi_20', 'export_20', '구리선물_20', '중국고정자산투자(yoy%)_20', '중국 PMI_20', '금 선물_20', '달러 인덱스_20', '중국 소매판매_20', '중국 산업 생산_20', 'MSCI_EMER_20', 'WTI_60', 'DGS2_60', 'DGS10_60', 'TIPS_60', 'VIX_60', 'PPI_60', 'per_60', 'pbr_60', '원달러_60', '원엔_60', '3년물 _60', '10년물 _60', 'treasury_10_3_diff_60', 'T10Y2Y_60', 'usa_cpi_60', 'us_e_infla_60', 'yield_gap(%)_60', 'cpi_60', 'export_60', '구리선물_60', '중국고정자산투자(yoy%)_60', '중국 PMI_60', '금 선물_60', '달러 인덱스_60', '중국 소매판매_60', '중국 산업 생산_60', 'MSCI_EMER_60']

# %%
df_index_telecom.head(2)
# Out:
#            telecom    WTI  DGS2  DGS10  TIPS    VIX    PPI    per    pbr  \
# date
# 2010-04-01   S_buy  84.53  1.05   3.89  1.61  17.47  172.2  24.13  24.13
# 2010-04-05   S_buy  86.36  1.18   4.01  1.70  17.02  172.2  24.22  24.22
#
#                원달러  ...   구리선물_60  중국고정자산투자(yoy%)_60  중국 PMI_60   금 선물_60  \
# date                ...
# 2010-04-01  1131.3  ...  0.000842          -0.003191  -0.001859 -0.000108
# 2010-04-05  1126.0  ...  0.001063          -0.003258  -0.001785 -0.000062
#
#             달러 인덱스_60  중국 소매판매_60  중국 산업 생산_60  MSCI_EMER_60   통신배당_60  \
# date
# 2010-04-01   0.000870    0.006153    -0.007687      0.000181  0.002829
# 2010-04-05   0.000855    0.006087    -0.007304      0.000369  0.002899
#
#             IT산업별/월별 수출 현황 중 통신기기 소계_60
# date
# 2010-04-01                    -0.001122
# 2010-04-05                    -0.000808
#
# [2 rows x 88 columns]

# %%
for keyword, df in dfs.items():
    df.head(2).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, 2010-04-01 to 2010-04-05
# Data columns (total 88 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   auto                   2 non-null      object
#  1   WTI                    2 non-null      float64
#  2   DGS2                   2 non-null      float64
#  3   DGS10                  2 non-null      float64
#  4   TIPS                   2 non-null      float64
#  5   VIX                    2 non-null      float64
#  6   PPI                    2 non-null      float64
#  7   per                    2 non-null      float64
#  8   pbr                    2 non-null      float64
#  9   원달러                    2 non-null      float64
#  10  원엔                     2 non-null      float64
#  11  3년물                    2 non-null      float64
#  12  10년물                   2 non-null      float64
#  13  treasury_10_3_diff     2 non-null      float64
#  14  T10Y2Y                 2 non-null      float64
#  15  usa_cpi                2 non-null      float64
#  16  us_e_infla             2 non-null      float64
#  17  yield_gap(%)           2 non-null      float64
#  18  cpi                    2 non-null      float64
#  19  export                 2 non-null      float64
#  20  구리선물                   2 non-null      float64
#  21  중국고정자산투자(yoy%)         2 non-null      float64
#  22  중국 PMI                 2 non-null      float64
#  23  금 선물                   2 non-null      float64
#  24  달러 인덱스                 2 non-null      float64
#  25  중국 소매판매                2 non-null      float64
#  26  중국 산업 생산               2 non-null      float64
#  27  MSCI_EMER              2 non-null      float64
#  28  US_auto                2 non-null      float64
#  29  export_auto            2 non-null      int64
#  30  WTI_20                 2 non-null      float64
#  31  DGS2_20                2 non-null      float64
#  32  DGS10_20               2 non-null      float64
#  33  TIPS_20                2 non-null      float64
#  34  VIX_20                 2 non-null      float64
#  35  PPI_20                 2 non-null      float64
#  36  per_20                 2 non-null      float64
#  37  pbr_20                 2 non-null      float64
#  38  원달러_20                 2 non-null      float64
#  39  원엔_20                  2 non-null      float64
#  40  3년물 _20                2 non-null      float64
#  41  10년물 _20               2 non-null      float64
#  42  treasury_10_3_diff_20  2 non-null      float64
#  43  T10Y2Y_20              2 non-null      float64
#  44  usa_cpi_20             2 non-null      float64
#  45  us_e_infla_20          2 non-null      float64
#  46  yield_gap(%)_20        2 non-null      float64
#  47  cpi_20                 2 non-null      float64
#  48  export_20              2 non-null      float64
#  49  구리선물_20                2 non-null      float64
#  50  중국고정자산투자(yoy%)_20      2 non-null      float64
#  51  중국 PMI_20              2 non-null      float64
#  52  금 선물_20                2 non-null      float64
#  53  달러 인덱스_20              2 non-null      float64
#  54  중국 소매판매_20             2 non-null      float64
#  55  중국 산업 생산_20            2 non-null      float64
#  56  MSCI_EMER_20           2 non-null      float64
#  57  US_auto_20             2 non-null      float64
#  58  export_auto_20         2 non-null      float64
#  59  WTI_60                 2 non-null      float64
#  60  DGS2_60                2 non-null      float64
#  61  DGS10_60               2 non-null      float64
#  62  TIPS_60                2 non-null      float64
#  63  VIX_60                 2 non-null      float64
#  64  PPI_60                 2 non-null      float64
#  65  per_60                 2 non-null      float64
#  66  pbr_60                 2 non-null      float64
#  67  원달러_60                 2 non-null      float64
#  68  원엔_60                  2 non-null      float64
#  69  3년물 _60                2 non-null      float64
#  70  10년물 _60               2 non-null      float64
#  71  treasury_10_3_diff_60  2 non-null      float64
#  72  T10Y2Y_60              2 non-null      float64
#  73  usa_cpi_60             2 non-null      float64
#  74  us_e_infla_60          2 non-null      float64
#  75  yield_gap(%)_60        2 non-null      float64
#  76  cpi_60                 2 non-null      float64
#  77  export_60              2 non-null      float64
#  78  구리선물_60                2 non-null      float64
#  79  중국고정자산투자(yoy%)_60      2 non-null      float64
#  80  중국 PMI_60              2 non-null      float64
#  81  금 선물_60                2 non-null      float64
#  82  달러 인덱스_60              2 non-null      float64
#  83  중국 소매판매_60             2 non-null      float64
#  84  중국 산업 생산_60            2 non-null      float64
#  85  MSCI_EMER_60           2 non-null      float64
#  86  US_auto_60             2 non-null      float64
#  87  export_auto_60         2 non-null      float64
# dtypes: float64(86), int64(1), object(1)
# memory usage: 1.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, 2010-04-01 to 2010-04-05
# Data columns (total 88 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   construct              2 non-null      object
#  1   WTI                    2 non-null      float64
#  2   DGS2                   2 non-null      float64
#  3   DGS10                  2 non-null      float64
#  4   TIPS                   2 non-null      float64
#  5   VIX                    2 non-null      float64
#  6   PPI                    2 non-null      float64
#  7   per                    2 non-null      float64
#  8   pbr                    2 non-null      float64
#  9   원달러                    2 non-null      float64
#  10  원엔                     2 non-null      float64
#  11  3년물                    2 non-null      float64
#  12  10년물                   2 non-null      float64
#  13  treasury_10_3_diff     2 non-null      float64
#  14  T10Y2Y                 2 non-null      float64
#  15  usa_cpi                2 non-null      float64
#  16  us_e_infla             2 non-null      float64
#  17  yield_gap(%)           2 non-null      float64
#  18  cpi                    2 non-null      float64
#  19  export                 2 non-null      float64
#  20  구리선물                   2 non-null      float64
#  21  중국고정자산투자(yoy%)         2 non-null      float64
#  22  중국 PMI                 2 non-null      float64
#  23  금 선물                   2 non-null      float64
#  24  달러 인덱스                 2 non-null      float64
#  25  중국 소매판매                2 non-null      float64
#  26  중국 산업 생산               2 non-null      float64
#  27  MSCI_EMER              2 non-null      float64
#  28  매매가격지수                 2 non-null      float64
#  29  아파트매매거래량               2 non-null      float64
#  30  WTI_20                 2 non-null      float64
#  31  DGS2_20                2 non-null      float64
#  32  DGS10_20               2 non-null      float64
#  33  TIPS_20                2 non-null      float64
#  34  VIX_20                 2 non-null      float64
#  35  PPI_20                 2 non-null      float64
#  36  per_20                 2 non-null      float64
#  37  pbr_20                 2 non-null      float64
#  38  원달러_20                 2 non-null      float64
#  39  원엔_20                  2 non-null      float64
#  40  3년물 _20                2 non-null      float64
#  41  10년물 _20               2 non-null      float64
#  42  treasury_10_3_diff_20  2 non-null      float64
#  43  T10Y2Y_20              2 non-null      float64
#  44  usa_cpi_20             2 non-null      float64
#  45  us_e_infla_20          2 non-null      float64
#  46  yield_gap(%)_20        2 non-null      float64
#  47  cpi_20                 2 non-null      float64
#  48  export_20              2 non-null      float64
#  49  구리선물_20                2 non-null      float64
#  50  중국고정자산투자(yoy%)_20      2 non-null      float64
#  51  중국 PMI_20              2 non-null      float64
#  52  금 선물_20                2 non-null      float64
#  53  달러 인덱스_20              2 non-null      float64
#  54  중국 소매판매_20             2 non-null      float64
#  55  중국 산업 생산_20            2 non-null      float64
#  56  MSCI_EMER_20           2 non-null      float64
#  57  매매가격지수_20              2 non-null      float64
#  58  아파트매매거래량_20            2 non-null      float64
#  59  WTI_60                 2 non-null      float64
#  60  DGS2_60                2 non-null      float64
#  61  DGS10_60               2 non-null      float64
#  62  TIPS_60                2 non-null      float64
#  63  VIX_60                 2 non-null      float64
#  64  PPI_60                 2 non-null      float64
#  65  per_60                 2 non-null      float64
#  66  pbr_60                 2 non-null      float64
#  67  원달러_60                 2 non-null      float64
#  68  원엔_60                  2 non-null      float64
#  69  3년물 _60                2 non-null      float64
#  70  10년물 _60               2 non-null      float64
#  71  treasury_10_3_diff_60  2 non-null      float64
#  72  T10Y2Y_60              2 non-null      float64
#  73  usa_cpi_60             2 non-null      float64
#  74  us_e_infla_60          2 non-null      float64
#  75  yield_gap(%)_60        2 non-null      float64
#  76  cpi_60                 2 non-null      float64
#  77  export_60              2 non-null      float64
#  78  구리선물_60                2 non-null      float64
#  79  중국고정자산투자(yoy%)_60      2 non-null      float64
#  80  중국 PMI_60              2 non-null      float64
#  81  금 선물_60                2 non-null      float64
#  82  달러 인덱스_60              2 non-null      float64
#  83  중국 소매판매_60             2 non-null      float64
#  84  중국 산업 생산_60            2 non-null      float64
#  85  MSCI_EMER_60           2 non-null      float64
#  86  매매가격지수_60              2 non-null      float64
#  87  아파트매매거래량_60            2 non-null      float64
# dtypes: float64(87), object(1)
# memory usage: 1.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, 2010-04-01 to 2010-04-05
# Data columns (total 88 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   capital_market         2 non-null      object
#  1   WTI                    2 non-null      float64
#  2   DGS2                   2 non-null      float64
#  3   DGS10                  2 non-null      float64
#  4   TIPS                   2 non-null      float64
#  5   VIX                    2 non-null      float64
#  6   PPI                    2 non-null      float64
#  7   per                    2 non-null      float64
#  8   pbr                    2 non-null      float64
#  9   원달러                    2 non-null      float64
#  10  원엔                     2 non-null      float64
#  11  3년물                    2 non-null      float64
#  12  10년물                   2 non-null      float64
#  13  treasury_10_3_diff     2 non-null      float64
#  14  T10Y2Y                 2 non-null      float64
#  15  usa_cpi                2 non-null      float64
#  16  us_e_infla             2 non-null      float64
#  17  yield_gap(%)           2 non-null      float64
#  18  cpi                    2 non-null      float64
#  19  export                 2 non-null      float64
#  20  구리선물                   2 non-null      float64
#  21  중국고정자산투자(yoy%)         2 non-null      float64
#  22  중국 PMI                 2 non-null      float64
#  23  금 선물                   2 non-null      float64
#  24  달러 인덱스                 2 non-null      float64
#  25  중국 소매판매                2 non-null      float64
#  26  중국 산업 생산               2 non-null      float64
#  27  MSCI_EMER              2 non-null      float64
#  28  증권 배당 수익률              2 non-null      float64
#  29  코스피+코스닥 거래량            2 non-null      int64
#  30  WTI_20                 2 non-null      float64
#  31  DGS2_20                2 non-null      float64
#  32  DGS10_20               2 non-null      float64
#  33  TIPS_20                2 non-null      float64
#  34  VIX_20                 2 non-null      float64
#  35  PPI_20                 2 non-null      float64
#  36  per_20                 2 non-null      float64
#  37  pbr_20                 2 non-null      float64
#  38  원달러_20                 2 non-null      float64
#  39  원엔_20                  2 non-null      float64
#  40  3년물 _20                2 non-null      float64
#  41  10년물 _20               2 non-null      float64
#  42  treasury_10_3_diff_20  2 non-null      float64
#  43  T10Y2Y_20              2 non-null      float64
#  44  usa_cpi_20             2 non-null      float64
#  45  us_e_infla_20          2 non-null      float64
#  46  yield_gap(%)_20        2 non-null      float64
#  47  cpi_20                 2 non-null      float64
#  48  export_20              2 non-null      float64
#  49  구리선물_20                2 non-null      float64
#  50  중국고정자산투자(yoy%)_20      2 non-null      float64
#  51  중국 PMI_20              2 non-null      float64
#  52  금 선물_20                2 non-null      float64
#  53  달러 인덱스_20              2 non-null      float64
#  54  중국 소매판매_20             2 non-null      float64
#  55  중국 산업 생산_20            2 non-null      float64
#  56  MSCI_EMER_20           2 non-null      float64
#  57  증권 배당 수익률_20           2 non-null      float64
#  58  코스피+코스닥 거래량_20         2 non-null      float64
#  59  WTI_60                 2 non-null      float64
#  60  DGS2_60                2 non-null      float64
#  61  DGS10_60               2 non-null      float64
#  62  TIPS_60                2 non-null      float64
#  63  VIX_60                 2 non-null      float64
#  64  PPI_60                 2 non-null      float64
#  65  per_60                 2 non-null      float64
#  66  pbr_60                 2 non-null      float64
#  67  원달러_60                 2 non-null      float64
#  68  원엔_60                  2 non-null      float64
#  69  3년물 _60                2 non-null      float64
#  70  10년물 _60               2 non-null      float64
#  71  treasury_10_3_diff_60  2 non-null      float64
#  72  T10Y2Y_60              2 non-null      float64
#  73  usa_cpi_60             2 non-null      float64
#  74  us_e_infla_60          2 non-null      float64
#  75  yield_gap(%)_60        2 non-null      float64
#  76  cpi_60                 2 non-null      float64
#  77  export_60              2 non-null      float64
#  78  구리선물_60                2 non-null      float64
#  79  중국고정자산투자(yoy%)_60      2 non-null      float64
#  80  중국 PMI_60              2 non-null      float64
#  81  금 선물_60                2 non-null      float64
#  82  달러 인덱스_60              2 non-null      float64
#  83  중국 소매판매_60             2 non-null      float64
#  84  중국 산업 생산_60            2 non-null      float64
#  85  MSCI_EMER_60           2 non-null      float64
#  86  증권 배당 수익률_60           2 non-null      float64
#  87  코스피+코스닥 거래량_60         2 non-null      float64
# dtypes: float64(86), int64(1), object(1)
# memory usage: 1.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, 2010-04-01 to 2010-04-05
# Data columns (total 88 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   chemicals              2 non-null      object
#  1   WTI                    2 non-null      float64
#  2   DGS2                   2 non-null      float64
#  3   DGS10                  2 non-null      float64
#  4   TIPS                   2 non-null      float64
#  5   VIX                    2 non-null      float64
#  6   PPI                    2 non-null      float64
#  7   per                    2 non-null      float64
#  8   pbr                    2 non-null      float64
#  9   원달러                    2 non-null      float64
#  10  원엔                     2 non-null      float64
#  11  3년물                    2 non-null      float64
#  12  10년물                   2 non-null      float64
#  13  treasury_10_3_diff     2 non-null      float64
#  14  T10Y2Y                 2 non-null      float64
#  15  usa_cpi                2 non-null      float64
#  16  us_e_infla             2 non-null      float64
#  17  yield_gap(%)           2 non-null      float64
#  18  cpi                    2 non-null      float64
#  19  export                 2 non-null      float64
#  20  구리선물                   2 non-null      float64
#  21  중국고정자산투자(yoy%)         2 non-null      float64
#  22  중국 PMI                 2 non-null      float64
#  23  금 선물                   2 non-null      float64
#  24  달러 인덱스                 2 non-null      float64
#  25  중국 소매판매                2 non-null      float64
#  26  중국 산업 생산               2 non-null      float64
#  27  MSCI_EMER              2 non-null      float64
#  28  lc_price               2 non-null      float64
#  29  naphtha_price          2 non-null      float64
#  30  WTI_20                 2 non-null      float64
#  31  DGS2_20                2 non-null      float64
#  32  DGS10_20               2 non-null      float64
#  33  TIPS_20                2 non-null      float64
#  34  VIX_20                 2 non-null      float64
#  35  PPI_20                 2 non-null      float64
#  36  per_20                 2 non-null      float64
#  37  pbr_20                 2 non-null      float64
#  38  원달러_20                 2 non-null      float64
#  39  원엔_20                  2 non-null      float64
#  40  3년물 _20                2 non-null      float64
#  41  10년물 _20               2 non-null      float64
#  42  treasury_10_3_diff_20  2 non-null      float64
#  43  T10Y2Y_20              2 non-null      float64
#  44  usa_cpi_20             2 non-null      float64
#  45  us_e_infla_20          2 non-null      float64
#  46  yield_gap(%)_20        2 non-null      float64
#  47  cpi_20                 2 non-null      float64
#  48  export_20              2 non-null      float64
#  49  구리선물_20                2 non-null      float64
#  50  중국고정자산투자(yoy%)_20      2 non-null      float64
#  51  중국 PMI_20              2 non-null      float64
#  52  금 선물_20                2 non-null      float64
#  53  달러 인덱스_20              2 non-null      float64
#  54  중국 소매판매_20             2 non-null      float64
#  55  중국 산업 생산_20            2 non-null      float64
#  56  MSCI_EMER_20           2 non-null      float64
#  57  lc_price_20            2 non-null      float64
#  58  naphtha_price_20       2 non-null      float64
#  59  WTI_60                 2 non-null      float64
#  60  DGS2_60                2 non-null      float64
#  61  DGS10_60               2 non-null      float64
#  62  TIPS_60                2 non-null      float64
#  63  VIX_60                 2 non-null      float64
#  64  PPI_60                 2 non-null      float64
#  65  per_60                 2 non-null      float64
#  66  pbr_60                 2 non-null      float64
#  67  원달러_60                 2 non-null      float64
#  68  원엔_60                  2 non-null      float64
#  69  3년물 _60                2 non-null      float64
#  70  10년물 _60               2 non-null      float64
#  71  treasury_10_3_diff_60  2 non-null      float64
#  72  T10Y2Y_60              2 non-null      float64
#  73  usa_cpi_60             2 non-null      float64
#  74  us_e_infla_60          2 non-null      float64
#  75  yield_gap(%)_60        2 non-null      float64
#  76  cpi_60                 2 non-null      float64
#  77  export_60              2 non-null      float64
#  78  구리선물_60                2 non-null      float64
#  79  중국고정자산투자(yoy%)_60      2 non-null      float64
#  80  중국 PMI_60              2 non-null      float64
#  81  금 선물_60                2 non-null      float64
#  82  달러 인덱스_60              2 non-null      float64
#  83  중국 소매판매_60             2 non-null      float64
#  84  중국 산업 생산_60            2 non-null      float64
#  85  MSCI_EMER_60           2 non-null      float64
#  86  lc_price_60            2 non-null      float64
#  87  naphtha_price_60       2 non-null      float64
# dtypes: float64(87), object(1)
# memory usage: 1.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, 2010-04-01 to 2010-04-05
# Data columns (total 88 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   equipment              2 non-null      object
#  1   WTI                    2 non-null      float64
#  2   DGS2                   2 non-null      float64
#  3   DGS10                  2 non-null      float64
#  4   TIPS                   2 non-null      float64
#  5   VIX                    2 non-null      float64
#  6   PPI                    2 non-null      float64
#  7   per                    2 non-null      float64
#  8   pbr                    2 non-null      float64
#  9   원달러                    2 non-null      float64
#  10  원엔                     2 non-null      float64
#  11  3년물                    2 non-null      float64
#  12  10년물                   2 non-null      float64
#  13  treasury_10_3_diff     2 non-null      float64
#  14  T10Y2Y                 2 non-null      float64
#  15  usa_cpi                2 non-null      float64
#  16  us_e_infla             2 non-null      float64
#  17  yield_gap(%)           2 non-null      float64
#  18  cpi                    2 non-null      float64
#  19  export                 2 non-null      float64
#  20  구리선물                   2 non-null      float64
#  21  중국고정자산투자(yoy%)         2 non-null      float64
#  22  중국 PMI                 2 non-null      float64
#  23  금 선물                   2 non-null      float64
#  24  달러 인덱스                 2 non-null      float64
#  25  중국 소매판매                2 non-null      float64
#  26  중국 산업 생산               2 non-null      float64
#  27  MSCI_EMER              2 non-null      float64
#  28  기계수주경상금액               2 non-null      int64
#  29  BSI 제조업경기실사지수          2 non-null      int64
#  30  WTI_20                 2 non-null      float64
#  31  DGS2_20                2 non-null      float64
#  32  DGS10_20               2 non-null      float64
#  33  TIPS_20                2 non-null      float64
#  34  VIX_20                 2 non-null      float64
#  35  PPI_20                 2 non-null      float64
#  36  per_20                 2 non-null      float64
#  37  pbr_20                 2 non-null      float64
#  38  원달러_20                 2 non-null      float64
#  39  원엔_20                  2 non-null      float64
#  40  3년물 _20                2 non-null      float64
#  41  10년물 _20               2 non-null      float64
#  42  treasury_10_3_diff_20  2 non-null      float64
#  43  T10Y2Y_20              2 non-null      float64
#  44  usa_cpi_20             2 non-null      float64
#  45  us_e_infla_20          2 non-null      float64
#  46  yield_gap(%)_20        2 non-null      float64
#  47  cpi_20                 2 non-null      float64
#  48  export_20              2 non-null      float64
#  49  구리선물_20                2 non-null      float64
#  50  중국고정자산투자(yoy%)_20      2 non-null      float64
#  51  중국 PMI_20              2 non-null      float64
#  52  금 선물_20                2 non-null      float64
#  53  달러 인덱스_20              2 non-null      float64
#  54  중국 소매판매_20             2 non-null      float64
#  55  중국 산업 생산_20            2 non-null      float64
#  56  MSCI_EMER_20           2 non-null      float64
#  57  기계수주경상금액_20            2 non-null      float64
#  58  BSI 제조업경기실사지수_20       2 non-null      float64
#  59  WTI_60                 2 non-null      float64
#  60  DGS2_60                2 non-null      float64
#  61  DGS10_60               2 non-null      float64
#  62  TIPS_60                2 non-null      float64
#  63  VIX_60                 2 non-null      float64
#  64  PPI_60                 2 non-null      float64
#  65  per_60                 2 non-null      float64
#  66  pbr_60                 2 non-null      float64
#  67  원달러_60                 2 non-null      float64
#  68  원엔_60                  2 non-null      float64
#  69  3년물 _60                2 non-null      float64
#  70  10년물 _60               2 non-null      float64
#  71  treasury_10_3_diff_60  2 non-null      float64
#  72  T10Y2Y_60              2 non-null      float64
#  73  usa_cpi_60             2 non-null      float64
#  74  us_e_infla_60          2 non-null      float64
#  75  yield_gap(%)_60        2 non-null      float64
#  76  cpi_60                 2 non-null      float64
#  77  export_60              2 non-null      float64
#  78  구리선물_60                2 non-null      float64
#  79  중국고정자산투자(yoy%)_60      2 non-null      float64
#  80  중국 PMI_60              2 non-null      float64
#  81  금 선물_60                2 non-null      float64
#  82  달러 인덱스_60              2 non-null      float64
#  83  중국 소매판매_60             2 non-null      float64
#  84  중국 산업 생산_60            2 non-null      float64
#  85  MSCI_EMER_60           2 non-null      float64
#  86  기계수주경상금액_60            2 non-null      float64
#  87  BSI 제조업경기실사지수_60       2 non-null      float64
# dtypes: float64(85), int64(2), object(1)
# memory usage: 1.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, 2010-04-01 to 2010-04-05
# Data columns (total 88 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   transport              2 non-null      object
#  1   WTI                    2 non-null      float64
#  2   DGS2                   2 non-null      float64
#  3   DGS10                  2 non-null      float64
#  4   TIPS                   2 non-null      float64
#  5   VIX                    2 non-null      float64
#  6   PPI                    2 non-null      float64
#  7   per                    2 non-null      float64
#  8   pbr                    2 non-null      float64
#  9   원달러                    2 non-null      float64
#  10  원엔                     2 non-null      float64
#  11  3년물                    2 non-null      float64
#  12  10년물                   2 non-null      float64
#  13  treasury_10_3_diff     2 non-null      float64
#  14  T10Y2Y                 2 non-null      float64
#  15  usa_cpi                2 non-null      float64
#  16  us_e_infla             2 non-null      float64
#  17  yield_gap(%)           2 non-null      float64
#  18  cpi                    2 non-null      float64
#  19  export                 2 non-null      float64
#  20  구리선물                   2 non-null      float64
#  21  중국고정자산투자(yoy%)         2 non-null      float64
#  22  중국 PMI                 2 non-null      float64
#  23  금 선물                   2 non-null      float64
#  24  달러 인덱스                 2 non-null      float64
#  25  중국 소매판매                2 non-null      float64
#  26  중국 산업 생산               2 non-null      float64
#  27  MSCI_EMER              2 non-null      float64
#  28  발틱운임                   2 non-null      int64
#  29  scfi                   2 non-null      float64
#  30  WTI_20                 2 non-null      float64
#  31  DGS2_20                2 non-null      float64
#  32  DGS10_20               2 non-null      float64
#  33  TIPS_20                2 non-null      float64
#  34  VIX_20                 2 non-null      float64
#  35  PPI_20                 2 non-null      float64
#  36  per_20                 2 non-null      float64
#  37  pbr_20                 2 non-null      float64
#  38  원달러_20                 2 non-null      float64
#  39  원엔_20                  2 non-null      float64
#  40  3년물 _20                2 non-null      float64
#  41  10년물 _20               2 non-null      float64
#  42  treasury_10_3_diff_20  2 non-null      float64
#  43  T10Y2Y_20              2 non-null      float64
#  44  usa_cpi_20             2 non-null      float64
#  45  us_e_infla_20          2 non-null      float64
#  46  yield_gap(%)_20        2 non-null      float64
#  47  cpi_20                 2 non-null      float64
#  48  export_20              2 non-null      float64
#  49  구리선물_20                2 non-null      float64
#  50  중국고정자산투자(yoy%)_20      2 non-null      float64
#  51  중국 PMI_20              2 non-null      float64
#  52  금 선물_20                2 non-null      float64
#  53  달러 인덱스_20              2 non-null      float64
#  54  중국 소매판매_20             2 non-null      float64
#  55  중국 산업 생산_20            2 non-null      float64
#  56  MSCI_EMER_20           2 non-null      float64
#  57  발틱운임_20                2 non-null      float64
#  58  scfi_20                2 non-null      float64
#  59  WTI_60                 2 non-null      float64
#  60  DGS2_60                2 non-null      float64
#  61  DGS10_60               2 non-null      float64
#  62  TIPS_60                2 non-null      float64
#  63  VIX_60                 2 non-null      float64
#  64  PPI_60                 2 non-null      float64
#  65  per_60                 2 non-null      float64
#  66  pbr_60                 2 non-null      float64
#  67  원달러_60                 2 non-null      float64
#  68  원엔_60                  2 non-null      float64
#  69  3년물 _60                2 non-null      float64
#  70  10년물 _60               2 non-null      float64
#  71  treasury_10_3_diff_60  2 non-null      float64
#  72  T10Y2Y_60              2 non-null      float64
#  73  usa_cpi_60             2 non-null      float64
#  74  us_e_infla_60          2 non-null      float64
#  75  yield_gap(%)_60        2 non-null      float64
#  76  cpi_60                 2 non-null      float64
#  77  export_60              2 non-null      float64
#  78  구리선물_60                2 non-null      float64
#  79  중국고정자산투자(yoy%)_60      2 non-null      float64
#  80  중국 PMI_60              2 non-null      float64
#  81  금 선물_60                2 non-null      float64
#  82  달러 인덱스_60              2 non-null      float64
#  83  중국 소매판매_60             2 non-null      float64
#  84  중국 산업 생산_60            2 non-null      float64
#  85  MSCI_EMER_60           2 non-null      float64
#  86  발틱운임_60                2 non-null      float64
#  87  scfi_60                2 non-null      float64
# dtypes: float64(86), int64(1), object(1)
# memory usage: 1.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, 2010-04-01 to 2010-04-05
# Data columns (total 88 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   semi                   2 non-null      object
#  1   WTI                    2 non-null      float64
#  2   DGS2                   2 non-null      float64
#  3   DGS10                  2 non-null      float64
#  4   TIPS                   2 non-null      float64
#  5   VIX                    2 non-null      float64
#  6   PPI                    2 non-null      float64
#  7   per                    2 non-null      float64
#  8   pbr                    2 non-null      float64
#  9   원달러                    2 non-null      float64
#  10  원엔                     2 non-null      float64
#  11  3년물                    2 non-null      float64
#  12  10년물                   2 non-null      float64
#  13  treasury_10_3_diff     2 non-null      float64
#  14  T10Y2Y                 2 non-null      float64
#  15  usa_cpi                2 non-null      float64
#  16  us_e_infla             2 non-null      float64
#  17  yield_gap(%)           2 non-null      float64
#  18  cpi                    2 non-null      float64
#  19  export                 2 non-null      float64
#  20  구리선물                   2 non-null      float64
#  21  중국고정자산투자(yoy%)         2 non-null      float64
#  22  중국 PMI                 2 non-null      float64
#  23  금 선물                   2 non-null      float64
#  24  달러 인덱스                 2 non-null      float64
#  25  중국 소매판매                2 non-null      float64
#  26  중국 산업 생산               2 non-null      float64
#  27  MSCI_EMER              2 non-null      float64
#  28  SOX                    2 non-null      float64
#  29  메모리 수출금액               2 non-null      int64
#  30  WTI_20                 2 non-null      float64
#  31  DGS2_20                2 non-null      float64
#  32  DGS10_20               2 non-null      float64
#  33  TIPS_20                2 non-null      float64
#  34  VIX_20                 2 non-null      float64
#  35  PPI_20                 2 non-null      float64
#  36  per_20                 2 non-null      float64
#  37  pbr_20                 2 non-null      float64
#  38  원달러_20                 2 non-null      float64
#  39  원엔_20                  2 non-null      float64
#  40  3년물 _20                2 non-null      float64
#  41  10년물 _20               2 non-null      float64
#  42  treasury_10_3_diff_20  2 non-null      float64
#  43  T10Y2Y_20              2 non-null      float64
#  44  usa_cpi_20             2 non-null      float64
#  45  us_e_infla_20          2 non-null      float64
#  46  yield_gap(%)_20        2 non-null      float64
#  47  cpi_20                 2 non-null      float64
#  48  export_20              2 non-null      float64
#  49  구리선물_20                2 non-null      float64
#  50  중국고정자산투자(yoy%)_20      2 non-null      float64
#  51  중국 PMI_20              2 non-null      float64
#  52  금 선물_20                2 non-null      float64
#  53  달러 인덱스_20              2 non-null      float64
#  54  중국 소매판매_20             2 non-null      float64
#  55  중국 산업 생산_20            2 non-null      float64
#  56  MSCI_EMER_20           2 non-null      float64
#  57  SOX_20                 2 non-null      float64
#  58  메모리 수출금액_20            2 non-null      float64
#  59  WTI_60                 2 non-null      float64
#  60  DGS2_60                2 non-null      float64
#  61  DGS10_60               2 non-null      float64
#  62  TIPS_60                2 non-null      float64
#  63  VIX_60                 2 non-null      float64
#  64  PPI_60                 2 non-null      float64
#  65  per_60                 2 non-null      float64
#  66  pbr_60                 2 non-null      float64
#  67  원달러_60                 2 non-null      float64
#  68  원엔_60                  2 non-null      float64
#  69  3년물 _60                2 non-null      float64
#  70  10년물 _60               2 non-null      float64
#  71  treasury_10_3_diff_60  2 non-null      float64
#  72  T10Y2Y_60              2 non-null      float64
#  73  usa_cpi_60             2 non-null      float64
#  74  us_e_infla_60          2 non-null      float64
#  75  yield_gap(%)_60        2 non-null      float64
#  76  cpi_60                 2 non-null      float64
#  77  export_60              2 non-null      float64
#  78  구리선물_60                2 non-null      float64
#  79  중국고정자산투자(yoy%)_60      2 non-null      float64
#  80  중국 PMI_60              2 non-null      float64
#  81  금 선물_60                2 non-null      float64
#  82  달러 인덱스_60              2 non-null      float64
#  83  중국 소매판매_60             2 non-null      float64
#  84  중국 산업 생산_60            2 non-null      float64
#  85  MSCI_EMER_60           2 non-null      float64
#  86  SOX_60                 2 non-null      float64
#  87  메모리 수출금액_60            2 non-null      float64
# dtypes: float64(86), int64(1), object(1)
# memory usage: 1.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, 2010-04-01 to 2010-04-05
# Data columns (total 88 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   bank                   2 non-null      object
#  1   WTI                    2 non-null      float64
#  2   DGS2                   2 non-null      float64
#  3   DGS10                  2 non-null      float64
#  4   TIPS                   2 non-null      float64
#  5   VIX                    2 non-null      float64
#  6   PPI                    2 non-null      float64
#  7   per                    2 non-null      float64
#  8   pbr                    2 non-null      float64
#  9   원달러                    2 non-null      float64
#  10  원엔                     2 non-null      float64
#  11  3년물                    2 non-null      float64
#  12  10년물                   2 non-null      float64
#  13  treasury_10_3_diff     2 non-null      float64
#  14  T10Y2Y                 2 non-null      float64
#  15  usa_cpi                2 non-null      float64
#  16  us_e_infla             2 non-null      float64
#  17  yield_gap(%)           2 non-null      float64
#  18  cpi                    2 non-null      float64
#  19  export                 2 non-null      float64
#  20  구리선물                   2 non-null      float64
#  21  중국고정자산투자(yoy%)         2 non-null      float64
#  22  중국 PMI                 2 non-null      float64
#  23  금 선물                   2 non-null      float64
#  24  달러 인덱스                 2 non-null      float64
#  25  중국 소매판매                2 non-null      float64
#  26  중국 산업 생산               2 non-null      float64
#  27  MSCI_EMER              2 non-null      float64
#  28  bank_dividend          2 non-null      float64
#  29  call_rate              2 non-null      float64
#  30  WTI_20                 2 non-null      float64
#  31  DGS2_20                2 non-null      float64
#  32  DGS10_20               2 non-null      float64
#  33  TIPS_20                2 non-null      float64
#  34  VIX_20                 2 non-null      float64
#  35  PPI_20                 2 non-null      float64
#  36  per_20                 2 non-null      float64
#  37  pbr_20                 2 non-null      float64
#  38  원달러_20                 2 non-null      float64
#  39  원엔_20                  2 non-null      float64
#  40  3년물 _20                2 non-null      float64
#  41  10년물 _20               2 non-null      float64
#  42  treasury_10_3_diff_20  2 non-null      float64
#  43  T10Y2Y_20              2 non-null      float64
#  44  usa_cpi_20             2 non-null      float64
#  45  us_e_infla_20          2 non-null      float64
#  46  yield_gap(%)_20        2 non-null      float64
#  47  cpi_20                 2 non-null      float64
#  48  export_20              2 non-null      float64
#  49  구리선물_20                2 non-null      float64
#  50  중국고정자산투자(yoy%)_20      2 non-null      float64
#  51  중국 PMI_20              2 non-null      float64
#  52  금 선물_20                2 non-null      float64
#  53  달러 인덱스_20              2 non-null      float64
#  54  중국 소매판매_20             2 non-null      float64
#  55  중국 산업 생산_20            2 non-null      float64
#  56  MSCI_EMER_20           2 non-null      float64
#  57  bank_dividend_20       2 non-null      float64
#  58  call_rate_20           2 non-null      float64
#  59  WTI_60                 2 non-null      float64
#  60  DGS2_60                2 non-null      float64
#  61  DGS10_60               2 non-null      float64
#  62  TIPS_60                2 non-null      float64
#  63  VIX_60                 2 non-null      float64
#  64  PPI_60                 2 non-null      float64
#  65  per_60                 2 non-null      float64
#  66  pbr_60                 2 non-null      float64
#  67  원달러_60                 2 non-null      float64
#  68  원엔_60                  2 non-null      float64
#  69  3년물 _60                2 non-null      float64
#  70  10년물 _60               2 non-null      float64
#  71  treasury_10_3_diff_60  2 non-null      float64
#  72  T10Y2Y_60              2 non-null      float64
#  73  usa_cpi_60             2 non-null      float64
#  74  us_e_infla_60          2 non-null      float64
#  75  yield_gap(%)_60        2 non-null      float64
#  76  cpi_60                 2 non-null      float64
#  77  export_60              2 non-null      float64
#  78  구리선물_60                2 non-null      float64
#  79  중국고정자산투자(yoy%)_60      2 non-null      float64
#  80  중국 PMI_60              2 non-null      float64
#  81  금 선물_60                2 non-null      float64
#  82  달러 인덱스_60              2 non-null      float64
#  83  중국 소매판매_60             2 non-null      float64
#  84  중국 산업 생산_60            2 non-null      float64
#  85  MSCI_EMER_60           2 non-null      float64
#  86  bank_dividend_60       2 non-null      float64
#  87  call_rate_60           2 non-null      float64
# dtypes: float64(87), object(1)
# memory usage: 1.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, 2010-04-01 to 2010-04-05
# Data columns (total 88 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   steel                  2 non-null      object
#  1   WTI                    2 non-null      float64
#  2   DGS2                   2 non-null      float64
#  3   DGS10                  2 non-null      float64
#  4   TIPS                   2 non-null      float64
#  5   VIX                    2 non-null      float64
#  6   PPI                    2 non-null      float64
#  7   per                    2 non-null      float64
#  8   pbr                    2 non-null      float64
#  9   원달러                    2 non-null      float64
#  10  원엔                     2 non-null      float64
#  11  3년물                    2 non-null      float64
#  12  10년물                   2 non-null      float64
#  13  treasury_10_3_diff     2 non-null      float64
#  14  T10Y2Y                 2 non-null      float64
#  15  usa_cpi                2 non-null      float64
#  16  us_e_infla             2 non-null      float64
#  17  yield_gap(%)           2 non-null      float64
#  18  cpi                    2 non-null      float64
#  19  export                 2 non-null      float64
#  20  구리선물                   2 non-null      float64
#  21  중국고정자산투자(yoy%)         2 non-null      float64
#  22  중국 PMI                 2 non-null      float64
#  23  금 선물                   2 non-null      float64
#  24  달러 인덱스                 2 non-null      float64
#  25  중국 소매판매                2 non-null      float64
#  26  중국 산업 생산               2 non-null      float64
#  27  MSCI_EMER              2 non-null      float64
#  28  철광석 가격                 2 non-null      float64
#  29  미국 철강 코일 선물            2 non-null      float64
#  30  WTI_20                 2 non-null      float64
#  31  DGS2_20                2 non-null      float64
#  32  DGS10_20               2 non-null      float64
#  33  TIPS_20                2 non-null      float64
#  34  VIX_20                 2 non-null      float64
#  35  PPI_20                 2 non-null      float64
#  36  per_20                 2 non-null      float64
#  37  pbr_20                 2 non-null      float64
#  38  원달러_20                 2 non-null      float64
#  39  원엔_20                  2 non-null      float64
#  40  3년물 _20                2 non-null      float64
#  41  10년물 _20               2 non-null      float64
#  42  treasury_10_3_diff_20  2 non-null      float64
#  43  T10Y2Y_20              2 non-null      float64
#  44  usa_cpi_20             2 non-null      float64
#  45  us_e_infla_20          2 non-null      float64
#  46  yield_gap(%)_20        2 non-null      float64
#  47  cpi_20                 2 non-null      float64
#  48  export_20              2 non-null      float64
#  49  구리선물_20                2 non-null      float64
#  50  중국고정자산투자(yoy%)_20      2 non-null      float64
#  51  중국 PMI_20              2 non-null      float64
#  52  금 선물_20                2 non-null      float64
#  53  달러 인덱스_20              2 non-null      float64
#  54  중국 소매판매_20             2 non-null      float64
#  55  중국 산업 생산_20            2 non-null      float64
#  56  MSCI_EMER_20           2 non-null      float64
#  57  철광석 가격_20              2 non-null      float64
#  58  미국 철강 코일 선물_20         2 non-null      float64
#  59  WTI_60                 2 non-null      float64
#  60  DGS2_60                2 non-null      float64
#  61  DGS10_60               2 non-null      float64
#  62  TIPS_60                2 non-null      float64
#  63  VIX_60                 2 non-null      float64
#  64  PPI_60                 2 non-null      float64
#  65  per_60                 2 non-null      float64
#  66  pbr_60                 2 non-null      float64
#  67  원달러_60                 2 non-null      float64
#  68  원엔_60                  2 non-null      float64
#  69  3년물 _60                2 non-null      float64
#  70  10년물 _60               2 non-null      float64
#  71  treasury_10_3_diff_60  2 non-null      float64
#  72  T10Y2Y_60              2 non-null      float64
#  73  usa_cpi_60             2 non-null      float64
#  74  us_e_infla_60          2 non-null      float64
#  75  yield_gap(%)_60        2 non-null      float64
#  76  cpi_60                 2 non-null      float64
#  77  export_60              2 non-null      float64
#  78  구리선물_60                2 non-null      float64
#  79  중국고정자산투자(yoy%)_60      2 non-null      float64
#  80  중국 PMI_60              2 non-null      float64
#  81  금 선물_60                2 non-null      float64
#  82  달러 인덱스_60              2 non-null      float64
#  83  중국 소매판매_60             2 non-null      float64
#  84  중국 산업 생산_60            2 non-null      float64
#  85  MSCI_EMER_60           2 non-null      float64
#  86  철광석 가격_60              2 non-null      float64
#  87  미국 철강 코일 선물_60         2 non-null      float64
# dtypes: float64(87), object(1)
# memory usage: 1.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, 2010-04-01 to 2010-04-05
# Data columns (total 88 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   telecom                      2 non-null      object
#  1   WTI                          2 non-null      float64
#  2   DGS2                         2 non-null      float64
#  3   DGS10                        2 non-null      float64
#  4   TIPS                         2 non-null      float64
#  5   VIX                          2 non-null      float64
#  6   PPI                          2 non-null      float64
#  7   per                          2 non-null      float64
#  8   pbr                          2 non-null      float64
#  9   원달러                          2 non-null      float64
#  10  원엔                           2 non-null      float64
#  11  3년물                          2 non-null      float64
#  12  10년물                         2 non-null      float64
#  13  treasury_10_3_diff           2 non-null      float64
#  14  T10Y2Y                       2 non-null      float64
#  15  usa_cpi                      2 non-null      float64
#  16  us_e_infla                   2 non-null      float64
#  17  yield_gap(%)                 2 non-null      float64
#  18  cpi                          2 non-null      float64
#  19  export                       2 non-null      float64
#  20  구리선물                         2 non-null      float64
#  21  중국고정자산투자(yoy%)               2 non-null      float64
#  22  중국 PMI                       2 non-null      float64
#  23  금 선물                         2 non-null      float64
#  24  달러 인덱스                       2 non-null      float64
#  25  중국 소매판매                      2 non-null      float64
#  26  중국 산업 생산                     2 non-null      float64
#  27  MSCI_EMER                    2 non-null      float64
#  28  통신배당                         2 non-null      float64
#  29  IT산업별/월별 수출 현황 중 통신기기 소계     2 non-null      int64
#  30  WTI_20                       2 non-null      float64
#  31  DGS2_20                      2 non-null      float64
#  32  DGS10_20                     2 non-null      float64
#  33  TIPS_20                      2 non-null      float64
#  34  VIX_20                       2 non-null      float64
#  35  PPI_20                       2 non-null      float64
#  36  per_20                       2 non-null      float64
#  37  pbr_20                       2 non-null      float64
#  38  원달러_20                       2 non-null      float64
#  39  원엔_20                        2 non-null      float64
#  40  3년물 _20                      2 non-null      float64
#  41  10년물 _20                     2 non-null      float64
#  42  treasury_10_3_diff_20        2 non-null      float64
#  43  T10Y2Y_20                    2 non-null      float64
#  44  usa_cpi_20                   2 non-null      float64
#  45  us_e_infla_20                2 non-null      float64
#  46  yield_gap(%)_20              2 non-null      float64
#  47  cpi_20                       2 non-null      float64
#  48  export_20                    2 non-null      float64
#  49  구리선물_20                      2 non-null      float64
#  50  중국고정자산투자(yoy%)_20            2 non-null      float64
#  51  중국 PMI_20                    2 non-null      float64
#  52  금 선물_20                      2 non-null      float64
#  53  달러 인덱스_20                    2 non-null      float64
#  54  중국 소매판매_20                   2 non-null      float64
#  55  중국 산업 생산_20                  2 non-null      float64
#  56  MSCI_EMER_20                 2 non-null      float64
#  57  통신배당_20                      2 non-null      float64
#  58  IT산업별/월별 수출 현황 중 통신기기 소계_20  2 non-null      float64
#  59  WTI_60                       2 non-null      float64
#  60  DGS2_60                      2 non-null      float64
#  61  DGS10_60                     2 non-null      float64
#  62  TIPS_60                      2 non-null      float64
#  63  VIX_60                       2 non-null      float64
#  64  PPI_60                       2 non-null      float64
#  65  per_60                       2 non-null      float64
#  66  pbr_60                       2 non-null      float64
#  67  원달러_60                       2 non-null      float64
#  68  원엔_60                        2 non-null      float64
#  69  3년물 _60                      2 non-null      float64
#  70  10년물 _60                     2 non-null      float64
#  71  treasury_10_3_diff_60        2 non-null      float64
#  72  T10Y2Y_60                    2 non-null      float64
#  73  usa_cpi_60                   2 non-null      float64
#  74  us_e_infla_60                2 non-null      float64
#  75  yield_gap(%)_60              2 non-null      float64
#  76  cpi_60                       2 non-null      float64
#  77  export_60                    2 non-null      float64
#  78  구리선물_60                      2 non-null      float64
#  79  중국고정자산투자(yoy%)_60            2 non-null      float64
#  80  중국 PMI_60                    2 non-null      float64
#  81  금 선물_60                      2 non-null      float64
#  82  달러 인덱스_60                    2 non-null      float64
#  83  중국 소매판매_60                   2 non-null      float64
#  84  중국 산업 생산_60                  2 non-null      float64
#  85  MSCI_EMER_60                 2 non-null      float64
#  86  통신배당_60                      2 non-null      float64
#  87  IT산업별/월별 수출 현황 중 통신기기 소계_60  2 non-null      float64
# dtypes: float64(86), int64(1), object(1)
# memory usage: 1.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, 2010-04-01 to 2010-04-05
# Data columns (total 88 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   staples                2 non-null      object
#  1   WTI                    2 non-null      float64
#  2   DGS2                   2 non-null      float64
#  3   DGS10                  2 non-null      float64
#  4   TIPS                   2 non-null      float64
#  5   VIX                    2 non-null      float64
#  6   PPI                    2 non-null      float64
#  7   per                    2 non-null      float64
#  8   pbr                    2 non-null      float64
#  9   원달러                    2 non-null      float64
#  10  원엔                     2 non-null      float64
#  11  3년물                    2 non-null      float64
#  12  10년물                   2 non-null      float64
#  13  treasury_10_3_diff     2 non-null      float64
#  14  T10Y2Y                 2 non-null      float64
#  15  usa_cpi                2 non-null      float64
#  16  us_e_infla             2 non-null      float64
#  17  yield_gap(%)           2 non-null      float64
#  18  cpi                    2 non-null      float64
#  19  export                 2 non-null      float64
#  20  구리선물                   2 non-null      float64
#  21  중국고정자산투자(yoy%)         2 non-null      float64
#  22  중국 PMI                 2 non-null      float64
#  23  금 선물                   2 non-null      float64
#  24  달러 인덱스                 2 non-null      float64
#  25  중국 소매판매                2 non-null      float64
#  26  중국 산업 생산               2 non-null      float64
#  27  MSCI_EMER              2 non-null      float64
#  28  미 소맥 선물                2 non-null      float64
#  29  미 대두 선물                2 non-null      float64
#  30  WTI_20                 2 non-null      float64
#  31  DGS2_20                2 non-null      float64
#  32  DGS10_20               2 non-null      float64
#  33  TIPS_20                2 non-null      float64
#  34  VIX_20                 2 non-null      float64
#  35  PPI_20                 2 non-null      float64
#  36  per_20                 2 non-null      float64
#  37  pbr_20                 2 non-null      float64
#  38  원달러_20                 2 non-null      float64
#  39  원엔_20                  2 non-null      float64
#  40  3년물 _20                2 non-null      float64
#  41  10년물 _20               2 non-null      float64
#  42  treasury_10_3_diff_20  2 non-null      float64
#  43  T10Y2Y_20              2 non-null      float64
#  44  usa_cpi_20             2 non-null      float64
#  45  us_e_infla_20          2 non-null      float64
#  46  yield_gap(%)_20        2 non-null      float64
#  47  cpi_20                 2 non-null      float64
#  48  export_20              2 non-null      float64
#  49  구리선물_20                2 non-null      float64
#  50  중국고정자산투자(yoy%)_20      2 non-null      float64
#  51  중국 PMI_20              2 non-null      float64
#  52  금 선물_20                2 non-null      float64
#  53  달러 인덱스_20              2 non-null      float64
#  54  중국 소매판매_20             2 non-null      float64
#  55  중국 산업 생산_20            2 non-null      float64
#  56  MSCI_EMER_20           2 non-null      float64
#  57  미 소맥 선물 _20            2 non-null      float64
#  58  미 대두 선물 _20            2 non-null      float64
#  59  WTI_60                 2 non-null      float64
#  60  DGS2_60                2 non-null      float64
#  61  DGS10_60               2 non-null      float64
#  62  TIPS_60                2 non-null      float64
#  63  VIX_60                 2 non-null      float64
#  64  PPI_60                 2 non-null      float64
#  65  per_60                 2 non-null      float64
#  66  pbr_60                 2 non-null      float64
#  67  원달러_60                 2 non-null      float64
#  68  원엔_60                  2 non-null      float64
#  69  3년물 _60                2 non-null      float64
#  70  10년물 _60               2 non-null      float64
#  71  treasury_10_3_diff_60  2 non-null      float64
#  72  T10Y2Y_60              2 non-null      float64
#  73  usa_cpi_60             2 non-null      float64
#  74  us_e_infla_60          2 non-null      float64
#  75  yield_gap(%)_60        2 non-null      float64
#  76  cpi_60                 2 non-null      float64
#  77  export_60              2 non-null      float64
#  78  구리선물_60                2 non-null      float64
#  79  중국고정자산투자(yoy%)_60      2 non-null      float64
#  80  중국 PMI_60              2 non-null      float64
#  81  금 선물_60                2 non-null      float64
#  82  달러 인덱스_60              2 non-null      float64
#  83  중국 소매판매_60             2 non-null      float64
#  84  중국 산업 생산_60            2 non-null      float64
#  85  MSCI_EMER_60           2 non-null      float64
#  86  미 소맥 선물 _60            2 non-null      float64
#  87  미 대두 선물 _60            2 non-null      float64
# dtypes: float64(87), object(1)
# memory usage: 1.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, 2010-04-01 to 2010-04-05
# Data columns (total 88 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   discretionary          2 non-null      object
#  1   WTI                    2 non-null      float64
#  2   DGS2                   2 non-null      float64
#  3   DGS10                  2 non-null      float64
#  4   TIPS                   2 non-null      float64
#  5   VIX                    2 non-null      float64
#  6   PPI                    2 non-null      float64
#  7   per                    2 non-null      float64
#  8   pbr                    2 non-null      float64
#  9   원달러                    2 non-null      float64
#  10  원엔                     2 non-null      float64
#  11  3년물                    2 non-null      float64
#  12  10년물                   2 non-null      float64
#  13  treasury_10_3_diff     2 non-null      float64
#  14  T10Y2Y                 2 non-null      float64
#  15  usa_cpi                2 non-null      float64
#  16  us_e_infla             2 non-null      float64
#  17  yield_gap(%)           2 non-null      float64
#  18  cpi                    2 non-null      float64
#  19  export                 2 non-null      float64
#  20  구리선물                   2 non-null      float64
#  21  중국고정자산투자(yoy%)         2 non-null      float64
#  22  중국 PMI                 2 non-null      float64
#  23  금 선물                   2 non-null      float64
#  24  달러 인덱스                 2 non-null      float64
#  25  중국 소매판매                2 non-null      float64
#  26  중국 산업 생산               2 non-null      float64
#  27  MSCI_EMER              2 non-null      float64
#  28  항공 여객                  2 non-null      int64
#  29  소비자심리지수                2 non-null      float64
#  30  WTI_20                 2 non-null      float64
#  31  DGS2_20                2 non-null      float64
#  32  DGS10_20               2 non-null      float64
#  33  TIPS_20                2 non-null      float64
#  34  VIX_20                 2 non-null      float64
#  35  PPI_20                 2 non-null      float64
#  36  per_20                 2 non-null      float64
#  37  pbr_20                 2 non-null      float64
#  38  원달러_20                 2 non-null      float64
#  39  원엔_20                  2 non-null      float64
#  40  3년물 _20                2 non-null      float64
#  41  10년물 _20               2 non-null      float64
#  42  treasury_10_3_diff_20  2 non-null      float64
#  43  T10Y2Y_20              2 non-null      float64
#  44  usa_cpi_20             2 non-null      float64
#  45  us_e_infla_20          2 non-null      float64
#  46  yield_gap(%)_20        2 non-null      float64
#  47  cpi_20                 2 non-null      float64
#  48  export_20              2 non-null      float64
#  49  구리선물_20                2 non-null      float64
#  50  중국고정자산투자(yoy%)_20      2 non-null      float64
#  51  중국 PMI_20              2 non-null      float64
#  52  금 선물_20                2 non-null      float64
#  53  달러 인덱스_20              2 non-null      float64
#  54  중국 소매판매_20             2 non-null      float64
#  55  중국 산업 생산_20            2 non-null      float64
#  56  MSCI_EMER_20           2 non-null      float64
#  57  항공 여객_20               2 non-null      float64
#  58  소비자심리지수_20             2 non-null      float64
#  59  WTI_60                 2 non-null      float64
#  60  DGS2_60                2 non-null      float64
#  61  DGS10_60               2 non-null      float64
#  62  TIPS_60                2 non-null      float64
#  63  VIX_60                 2 non-null      float64
#  64  PPI_60                 2 non-null      float64
#  65  per_60                 2 non-null      float64
#  66  pbr_60                 2 non-null      float64
#  67  원달러_60                 2 non-null      float64
#  68  원엔_60                  2 non-null      float64
#  69  3년물 _60                2 non-null      float64
#  70  10년물 _60               2 non-null      float64
#  71  treasury_10_3_diff_60  2 non-null      float64
#  72  T10Y2Y_60              2 non-null      float64
#  73  usa_cpi_60             2 non-null      float64
#  74  us_e_infla_60          2 non-null      float64
#  75  yield_gap(%)_60        2 non-null      float64
#  76  cpi_60                 2 non-null      float64
#  77  export_60              2 non-null      float64
#  78  구리선물_60                2 non-null      float64
#  79  중국고정자산투자(yoy%)_60      2 non-null      float64
#  80  중국 PMI_60              2 non-null      float64
#  81  금 선물_60                2 non-null      float64
#  82  달러 인덱스_60              2 non-null      float64
#  83  중국 소매판매_60             2 non-null      float64
#  84  중국 산업 생산_60            2 non-null      float64
#  85  MSCI_EMER_60           2 non-null      float64
#  86  항공 여객_60               2 non-null      float64
#  87  소비자심리지수_60             2 non-null      float64
# dtypes: float64(86), int64(1), object(1)
# memory usage: 1.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, 2010-04-01 to 2010-04-05
# Data columns (total 82 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   kospi                  2 non-null      object
#  1   WTI                    2 non-null      float64
#  2   DGS2                   2 non-null      float64
#  3   DGS10                  2 non-null      float64
#  4   TIPS                   2 non-null      float64
#  5   VIX                    2 non-null      float64
#  6   PPI                    2 non-null      float64
#  7   per                    2 non-null      float64
#  8   pbr                    2 non-null      float64
#  9   원달러                    2 non-null      float64
#  10  원엔                     2 non-null      float64
#  11  3년물                    2 non-null      float64
#  12  10년물                   2 non-null      float64
#  13  treasury_10_3_diff     2 non-null      float64
#  14  T10Y2Y                 2 non-null      float64
#  15  usa_cpi                2 non-null      float64
#  16  us_e_infla             2 non-null      float64
#  17  yield_gap(%)           2 non-null      float64
#  18  cpi                    2 non-null      float64
#  19  export                 2 non-null      float64
#  20  구리선물                   2 non-null      float64
#  21  중국고정자산투자(yoy%)         2 non-null      float64
#  22  중국 PMI                 2 non-null      float64
#  23  금 선물                   2 non-null      float64
#  24  달러 인덱스                 2 non-null      float64
#  25  중국 소매판매                2 non-null      float64
#  26  중국 산업 생산               2 non-null      float64
#  27  MSCI_EMER              2 non-null      float64
#  28  WTI_20                 2 non-null      float64
#  29  DGS2_20                2 non-null      float64
#  30  DGS10_20               2 non-null      float64
#  31  TIPS_20                2 non-null      float64
#  32  VIX_20                 2 non-null      float64
#  33  PPI_20                 2 non-null      float64
#  34  per_20                 2 non-null      float64
#  35  pbr_20                 2 non-null      float64
#  36  원달러_20                 2 non-null      float64
#  37  원엔_20                  2 non-null      float64
#  38  3년물 _20                2 non-null      float64
#  39  10년물 _20               2 non-null      float64
#  40  treasury_10_3_diff_20  2 non-null      float64
#  41  T10Y2Y_20              2 non-null      float64
#  42  usa_cpi_20             2 non-null      float64
#  43  us_e_infla_20          2 non-null      float64
#  44  yield_gap(%)_20        2 non-null      float64
#  45  cpi_20                 2 non-null      float64
#  46  export_20              2 non-null      float64
#  47  구리선물_20                2 non-null      float64
#  48  중국고정자산투자(yoy%)_20      2 non-null      float64
#  49  중국 PMI_20              2 non-null      float64
#  50  금 선물_20                2 non-null      float64
#  51  달러 인덱스_20              2 non-null      float64
#  52  중국 소매판매_20             2 non-null      float64
#  53  중국 산업 생산_20            2 non-null      float64
#  54  MSCI_EMER_20           2 non-null      float64
#  55  WTI_60                 2 non-null      float64
#  56  DGS2_60                2 non-null      float64
#  57  DGS10_60               2 non-null      float64
#  58  TIPS_60                2 non-null      float64
#  59  VIX_60                 2 non-null      float64
#  60  PPI_60                 2 non-null      float64
#  61  per_60                 2 non-null      float64
#  62  pbr_60                 2 non-null      float64
#  63  원달러_60                 2 non-null      float64
#  64  원엔_60                  2 non-null      float64
#  65  3년물 _60                2 non-null      float64
#  66  10년물 _60               2 non-null      float64
#  67  treasury_10_3_diff_60  2 non-null      float64
#  68  T10Y2Y_60              2 non-null      float64
#  69  usa_cpi_60             2 non-null      float64
#  70  us_e_infla_60          2 non-null      float64
#  71  yield_gap(%)_60        2 non-null      float64
#  72  cpi_60                 2 non-null      float64
#  73  export_60              2 non-null      float64
#  74  구리선물_60                2 non-null      float64
#  75  중국고정자산투자(yoy%)_60      2 non-null      float64
#  76  중국 PMI_60              2 non-null      float64
#  77  금 선물_60                2 non-null      float64
#  78  달러 인덱스_60              2 non-null      float64
#  79  중국 소매판매_60             2 non-null      float64
#  80  중국 산업 생산_60            2 non-null      float64
#  81  MSCI_EMER_60           2 non-null      float64
# dtypes: float64(81), object(1)
# memory usage: 1.3+ KB

# %%
data_splits = {}
last_rows = {}  # 각 키워드의 마지막 행을 저장할 딕셔너리

for keyword, df_index in dfs.items():
    # 각 키워드의 마지막 행 추출 및 저장
    last_row = df_index.iloc[-1]  # 마지막 행 저장
    last_rows[keyword] = last_row  # 추출된 마지막 행을 저장
    
    df_dropna = df_index.dropna()  # 결측치가 있는 행 제거
    
    if df_dropna.empty:
        print(f"Error: Dataframe for {keyword} is empty.")
    else:
        # 종속 변수(y) 및 독립 변수(X) 설정
        y_keyword = df_dropna[keyword]  # 현재 키워드에 해당하는 종속 변수
        X_keyword = df_dropna.drop(columns=[keyword])  # 현재 키워드를 제외한 나머지 열은 독립 변수로 사용

        # 데이터 분할
        X_train, X_test, y_train, y_test = train_test_split(X_keyword, y_keyword, test_size=0.2, random_state=0)
        
        # 데이터 정규화
        normalizer = StandardScaler()
        X_train_normalized = normalizer.fit_transform(X_train)
        X_test_normalized = normalizer.transform(X_test)

        # 데이터 저장
        data_splits[keyword] = {
            'X_train': X_train_normalized,
            'X_test': X_test_normalized,
            'y_train': y_train,
            'y_test': y_test
        }

        print(f'Train set dimension for {keyword} is {X_train_normalized.shape}')
        print(f'Test set dimension for {keyword} is {X_test_normalized.shape}')
        # 훈련 데이터와 테스트 데이터의 클래스 비율 확인
        train_class_counts = {label: sum(y_train == label) for label in set(y_keyword)}
        test_class_counts = {label: sum(y_test == label) for label in set(y_keyword)}

        print(f"훈련 데이터 클래스 비율 for {keyword}:", train_class_counts)
        print(f"테스트 데이터 클래스 비율 for {keyword}:", test_class_counts)

# 결측치 제거 이후의 데이터프레임의 마지막 행 출력
for keyword, last_row in last_rows.items():
    print(f"마지막 행 {keyword}: {last_row}")
    print(len(last_row))
# Out:
# Train set dimension for auto is (2640, 87)
# Test set dimension for auto is (660, 87)
# 훈련 데이터 클래스 비율 for auto: {'sell': 1289, 'S_buy': 854, 'buy': 497}
# 테스트 데이터 클래스 비율 for auto: {'sell': 310, 'S_buy': 222, 'buy': 128}
# Train set dimension for construct is (2639, 87)
# Test set dimension for construct is (660, 87)
# 훈련 데이터 클래스 비율 for construct: {'sell': 1319, 'S_buy': 936, 'buy': 384}
# 테스트 데이터 클래스 비율 for construct: {'sell': 316, 'S_buy': 239, 'buy': 105}
# Train set dimension for capital_market is (2640, 87)
# Test set dimension for capital_market is (660, 87)
# 훈련 데이터 클래스 비율 for capital_market: {'sell': 1340, 'S_buy': 857, 'buy': 443}
# 테스트 데이터 클래스 비율 for capital_market: {'sell': 318, 'S_buy': 227, 'buy': 115}
# Train set dimension for chemicals is (2640, 87)
# Test set dimension for chemicals is (660, 87)
# 훈련 데이터 클래스 비율 for chemicals: {'sell': 1264, 'S_buy': 910, 'buy': 466}
# 테스트 데이터 클래스 비율 for chemicals: {'sell': 299, 'S_buy': 216, 'buy': 145}
# Train set dimension for equipment is (2640, 87)
# Test set dimension for equipment is (660, 87)
# 훈련 데이터 클래스 비율 for equipment: {'sell': 1360, 'S_buy': 952, 'buy': 328}
# 테스트 데이터 클래스 비율 for equipment: {'sell': 330, 'S_buy': 249, 'buy': 81}
# Train set dimension for transport is (2640, 87)
# Test set dimension for transport is (660, 87)
# 훈련 데이터 클래스 비율 for transport: {'sell': 1376, 'S_buy': 812, 'buy': 452}
# 테스트 데이터 클래스 비율 for transport: {'sell': 331, 'S_buy': 206, 'buy': 123}
# Train set dimension for semi is (2640, 87)
# Test set dimension for semi is (660, 87)
# 훈련 데이터 클래스 비율 for semi: {'sell': 1183, 'S_buy': 924, 'buy': 533}
# 테스트 데이터 클래스 비율 for semi: {'sell': 274, 'S_buy': 238, 'buy': 148}
# Train set dimension for bank is (2640, 87)
# Test set dimension for bank is (660, 87)
# 훈련 데이터 클래스 비율 for bank: {'sell': 1290, 'S_buy': 793, 'buy': 557}
# 테스트 데이터 클래스 비율 for bank: {'sell': 320, 'S_buy': 192, 'buy': 148}
# Train set dimension for steel is (2640, 87)
# Test set dimension for steel is (660, 87)
# 훈련 데이터 클래스 비율 for steel: {'sell': 1318, 'S_buy': 868, 'buy': 454}
# 테스트 데이터 클래스 비율 for steel: {'sell': 309, 'S_buy': 240, 'buy': 111}
# Train set dimension for telecom is (2640, 87)
# Test set dimension for telecom is (660, 87)
# 훈련 데이터 클래스 비율 for telecom: {'sell': 1328, 'S_buy': 596, 'buy': 716}
# 테스트 데이터 클래스 비율 for telecom: {'sell': 308, 'S_buy': 165, 'buy': 187}
# Train set dimension for staples is (2640, 87)
# Test set dimension for staples is (660, 87)
# 훈련 데이터 클래스 비율 for staples: {'sell': 1262, 'S_buy': 711, 'buy': 667}
# 테스트 데이터 클래스 비율 for staples: {'sell': 281, 'S_buy': 207, 'buy': 172}
# Train set dimension for discretionary is (2640, 87)
# Test set dimension for discretionary is (660, 87)
# 훈련 데이터 클래스 비율 for discretionary: {'sell': 1266, 'S_buy': 685, 'buy': 689}
# 테스트 데이터 클래스 비율 for discretionary: {'sell': 298, 'S_buy': 172, 'buy': 190}
# Train set dimension for kospi is (2640, 81)
# Test set dimension for kospi is (660, 81)
# 훈련 데이터 클래스 비율 for kospi: {'sell': 1197, 'S_buy': 638, 'buy': 805}
# 테스트 데이터 클래스 비율 for kospi: {'sell': 292, 'S_buy': 180, 'buy': 188}
# 마지막 행 auto: auto                   NaN
# WTI                  84.54
# DGS2                  4.72
# DGS10                 1.98
# TIPS                  1.98
#                     ...
# 중국 소매판매_60       -0.008819
# 중국 산업 생산_60        0.00085
# MSCI_EMER_60       0.00112
# US_auto_60        0.000034
# export_auto_60    -0.00319
# Name: 2024-04-01, Length: 88, dtype: object
# 88
# 마지막 행 construct: construct            NaN
# WTI                84.54
# DGS2                4.72
# DGS10               1.98
# TIPS                1.98
#                   ...
# 중국 소매판매_60     -0.008819
# 중국 산업 생산_60      0.00085
# MSCI_EMER_60     0.00112
# 매매가격지수_60           -0.0
# 아파트매매거래량_60     0.003402
# Name: 2024-04-01, Length: 88, dtype: object
# 88
# 마지막 행 capital_market: capital_market         NaN
# WTI                  84.54
# DGS2                  4.72
# DGS10                 1.98
# TIPS                  1.98
#                     ...
# 중국 소매판매_60       -0.008819
# 중국 산업 생산_60        0.00085
# MSCI_EMER_60       0.00112
# 증권 배당 수익률_60      -0.00426
# 코스피+코스닥 거래량_60   -0.002124
# Name: 2024-04-01, Length: 88, dtype: object
# 88
# 마지막 행 chemicals: chemicals                NaN
# WTI                    84.54
# DGS2                    4.72
# DGS10                   1.98
# TIPS                    1.98
#                       ...
# 중국 소매판매_60         -0.008819
# 중국 산업 생산_60          0.00085
# MSCI_EMER_60         0.00112
# lc_price_60         0.004591
# naphtha_price_60    0.001271
# Name: 2024-04-01, Length: 88, dtype: object
# 88
# 마지막 행 equipment: equipment                NaN
# WTI                    84.54
# DGS2                    4.72
# DGS10                   1.98
# TIPS                    1.98
#                       ...
# 중국 소매판매_60         -0.008819
# 중국 산업 생산_60          0.00085
# MSCI_EMER_60         0.00112
# 기계수주경상금액_60         0.006044
# BSI 제조업경기실사지수_60    0.001215
# Name: 2024-04-01, Length: 88, dtype: object
# 88
# 마지막 행 transport: transport            NaN
# WTI                84.54
# DGS2                4.72
# DGS10               1.98
# TIPS                1.98
#                   ...
# 중국 소매판매_60     -0.008819
# 중국 산업 생산_60      0.00085
# MSCI_EMER_60     0.00112
# 발틱운임_60         0.005923
# scfi_60        -0.001796
# Name: 2024-04-01, Length: 88, dtype: object
# 88
# 마지막 행 semi: semi                 NaN
# WTI                84.54
# DGS2                4.72
# DGS10               1.98
# TIPS                1.98
#                   ...
# 중국 소매판매_60     -0.008819
# 중국 산업 생산_60      0.00085
# MSCI_EMER_60     0.00112
# SOX_60          0.003868
# 메모리 수출금액_60     0.000983
# Name: 2024-04-01, Length: 88, dtype: object
# 88
# 마지막 행 bank: bank                     NaN
# WTI                    84.54
# DGS2                    4.72
# DGS10                   1.98
# TIPS                    1.98
#                       ...
# 중국 소매판매_60         -0.008819
# 중국 산업 생산_60          0.00085
# MSCI_EMER_60         0.00112
# bank_dividend_60   -0.005329
# call_rate_60       -0.000017
# Name: 2024-04-01, Length: 88, dtype: object
# 88
# 마지막 행 steel: steel                  NaN
# WTI                  84.54
# DGS2                  4.72
# DGS10                 1.98
# TIPS                  1.98
#                     ...
# 중국 소매판매_60       -0.008819
# 중국 산업 생산_60        0.00085
# MSCI_EMER_60       0.00112
# 철광석 가격_60        -0.004466
# 미국 철강 코일 선물_60    -0.00693
# Name: 2024-04-01, Length: 88, dtype: object
# 88
# 마지막 행 telecom: telecom                             NaN
# WTI                               84.54
# DGS2                               4.72
# DGS10                              1.98
# TIPS                               1.98
#                                  ...
# 중국 소매판매_60                    -0.008819
# 중국 산업 생산_60                     0.00085
# MSCI_EMER_60                    0.00112
# 통신배당_60                       -0.005454
# IT산업별/월별 수출 현황 중 통신기기 소계_60   -0.007135
# Name: 2024-04-01, Length: 88, dtype: object
# 88
# 마지막 행 staples: staples              NaN
# WTI                84.54
# DGS2                4.72
# DGS10               1.98
# TIPS                1.98
#                   ...
# 중국 소매판매_60     -0.008819
# 중국 산업 생산_60      0.00085
# MSCI_EMER_60     0.00112
# 미 소맥 선물 _60    -0.002363
# 미 대두 선물 _60    -0.001115
# Name: 2024-04-01, Length: 88, dtype: object
# 88
# 마지막 행 discretionary: discretionary         NaN
# WTI                 84.54
# DGS2                 4.72
# DGS10                1.98
# TIPS                 1.98
#                    ...
# 중국 소매판매_60      -0.008819
# 중국 산업 생산_60       0.00085
# MSCI_EMER_60      0.00112
# 항공 여객_60        -0.000519
# 소비자심리지수_60      -0.000164
# Name: 2024-04-01, Length: 88, dtype: object
# 88
# 마지막 행 kospi: kospi                NaN
# WTI                84.54
# DGS2                4.72
# DGS10               1.98
# TIPS                1.98
#                   ...
# 금 선물_60         0.001513
# 달러 인덱스_60       0.000245
# 중국 소매판매_60     -0.008819
# 중국 산업 생산_60      0.00085
# MSCI_EMER_60     0.00112
# Name: 2024-04-01, Length: 82, dtype: object
# 82

# %%
y_keyword.head(3)
# Out:
# date
# 2010-04-01     buy
# 2010-04-05    sell
# 2010-04-06    sell
# Name: kospi, dtype: object

# %% [markdown]
# ### 여러가지 실험을 했다
# 1. logistic_regression
# 2. random_forest
# 3. gradient_boosting
# 4. svm
# 5. neural_network

# %%
# accuracies = {}

# # 각 키워드에 대한 분류기 및 Voting Classifier 생성
# for keyword, data_split in data_splits.items():
#     X_train = data_split['X_train']
#     X_test = data_split['X_test']
#     y_train = data_split['y_train']
#     y_test = data_split['y_test']
    
#     random_forest = RandomForestClassifier()
#     gradient_boosting = GradientBoostingClassifier()
#     svm = SVC()
#     knn = KNeighborsClassifier()
#     decision_tree = DecisionTreeClassifier()

#     # Voting Classifier 생성
#     voting_classifier = VotingClassifier(
#         estimators=[
#             ('rf', random_forest), 
#             ('gb', gradient_boosting), 
#             ('svm', svm), 
#             ('knn', knn),
#             ('dt', decision_tree)
#         ],
#         voting='hard'
#     )

#     models = {
#         'Random Forest': random_forest,
#         'Gradient Boosting': gradient_boosting,
#         'Support Vector Machine': svm,
#         'K-Nearest Neighbors': knn,
#         'Decision Tree': decision_tree,
#         'Voting Classifier': voting_classifier
#     }

#     # 각 분류기에 대해 학습하고 평가
#     for name, model in models.items():
#         model.fit(X_train, y_train)
#         y_pred = model.predict(X_test)
#         accuracy = accuracy_score(y_test, y_pred)
#         accuracies[f'{keyword}_{name}'] = accuracy
#         print(f"{keyword} 키워드로 학습한 {name}의 정확도: {accuracy}")

#     # 가장 높은 정확도를 가진 모델 찾기
#     best_model_name = max(accuracies, key=accuracies.get)
#     best_accuracy = accuracies[best_model_name]

#     print(f"최고의 성능을 보인 모델은 {best_model_name}로, 정확도는 {best_accuracy:.3f}입니다.")

# %%
# 각 키워드에 대한 최고 성능 모델과 정확도를 저장할 딕셔너리
best_models = {}
best_accuracies = {}

# 각 키워드에 대한 분류기 및 Voting Classifier 생성
for keyword, data_split in data_splits.items():
    X_train = data_split['X_train']
    X_test = data_split['X_test']
    y_train = data_split['y_train']
    y_test = data_split['y_test']
    
    accuracies = {}  # 키워드마다 새로운 accuracies 딕셔너리 생성

    random_forest = RandomForestClassifier()
    gradient_boosting = GradientBoostingClassifier()
    svm = SVC()
    knn = KNeighborsClassifier()
    decision_tree = DecisionTreeClassifier()

    # Voting Classifier 생성
    voting_classifier = VotingClassifier(
        estimators=[
            ('rf', random_forest), 
            ('gb', gradient_boosting), 
            ('svm', svm), 
            ('knn', knn),
            ('dt', decision_tree)
        ],
        voting='hard'
    )

    models = {
        'Random Forest': random_forest,
        'Gradient Boosting': gradient_boosting,
        'Support Vector Machine': svm,
        'K-Nearest Neighbors': knn,
        'Decision Tree': decision_tree,
        'Voting Classifier': voting_classifier
    }

    # 각 분류기에 대해 학습하고 평가
    for name, model in models.items():
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        accuracy = accuracy_score(y_test, y_pred)
        accuracies[name] = accuracy

    # 가장 높은 정확도를 가진 모델 찾기
    best_model_name = max(accuracies, key=accuracies.get)
    best_accuracy = accuracies[best_model_name]
    
    # 최고 성능 모델과 정확도를 저장
    best_models[keyword] = best_model_name
    best_accuracies[keyword] = best_accuracy
    print(f"{keyword}에서 최고의 성능을 보인 모델은 {best_model_name}로, 정확도는 {best_accuracy:.3f}입니다.")

def print_best_model(keyword):
    best_model_name = best_models.get(keyword)
    if best_model_name:
        accuracy = best_accuracies.get(keyword)

# 각 키워드별 최고 성능의 모델 출력
for keyword in data_splits.keys():
    print_best_model(keyword)
# Out:
# auto에서 최고의 성능을 보인 모델은 Random Forest로, 정확도는 0.820입니다.
# construct에서 최고의 성능을 보인 모델은 Voting Classifier로, 정확도는 0.829입니다.
# capital_market에서 최고의 성능을 보인 모델은 Voting Classifier로, 정확도는 0.820입니다.
# chemicals에서 최고의 성능을 보인 모델은 Random Forest로, 정확도는 0.794입니다.
# equipment에서 최고의 성능을 보인 모델은 Random Forest로, 정확도는 0.855입니다.
# transport에서 최고의 성능을 보인 모델은 Random Forest로, 정확도는 0.859입니다.
# semi에서 최고의 성능을 보인 모델은 Voting Classifier로, 정확도는 0.786입니다.
# bank에서 최고의 성능을 보인 모델은 Random Forest로, 정확도는 0.809입니다.
# steel에서 최고의 성능을 보인 모델은 Random Forest로, 정확도는 0.814입니다.
# telecom에서 최고의 성능을 보인 모델은 Random Forest로, 정확도는 0.812입니다.
# staples에서 최고의 성능을 보인 모델은 Random Forest로, 정확도는 0.845입니다.
# discretionary에서 최고의 성능을 보인 모델은 Random Forest로, 정확도는 0.798입니다.
# kospi에서 최고의 성능을 보인 모델은 Random Forest로, 정확도는 0.814입니다.

# %% [markdown]
# ### 최고의 성능 대부분은 Random Forest 모델로, 정확도는 대부분 0.8 이상

# %% [markdown]
# ### 따라서 randomforest 로 진행

# %% [markdown]
# ### 그러면은 렌덤 포레스트 단순 모델링을 해보자

# %%
# Train set 및 Test set에 대한 성능을 저장할 딕셔너리 생성
performance_results = {}

# Random Forest 모델 생성
rfc = RandomForestClassifier()

# 각 키워드에 대해 모델을 학습하고 Train set 및 Test set에 대한 성능을 측정
for keyword, data_split in data_splits.items():
    X_train = data_split['X_train']
    y_train = data_split['y_train']
    X_test = data_split['X_test']
    y_test = data_split['y_test']
    
    # 모델 학습
    rfc.fit(X_train, y_train)

    # Train set에 대한 성능 측정
    y_pred_train = rfc.predict(X_train)
    acc_train = accuracy_score(y_true=y_train, y_pred=y_pred_train)

    # Test set에 대한 성능 측정
    y_pred_test = rfc.predict(X_test)
    acc_test = accuracy_score(y_true=y_test, y_pred=y_pred_test)

    # 결과 저장
    performance_results[keyword] = {
        'Train 성능': acc_train,
        'Test 성능': acc_test
    }

# 각 키워드에 대한 Train set 및 Test set의 성능 출력
for keyword, performance in performance_results.items():
    print(f"{keyword} 키워드에 대한 성능: ",performance['Test 성능'])
    print()
# Out:
# auto 키워드에 대한 성능:  0.8257575757575758
#
# construct 키워드에 대한 성능:  0.8166666666666667
#
# capital_market 키워드에 대한 성능:  0.8166666666666667
#
# chemicals 키워드에 대한 성능:  0.8015151515151515
#
# equipment 키워드에 대한 성능:  0.843939393939394
#
# transport 키워드에 대한 성능:  0.8515151515151516
#
# semi 키워드에 대한 성능:  0.803030303030303
#
# bank 키워드에 대한 성능:  0.8
#
# steel 키워드에 대한 성능:  0.8257575757575758
#
# telecom 키워드에 대한 성능:  0.8045454545454546
#
# staples 키워드에 대한 성능:  0.8318181818181818
#
# discretionary 키워드에 대한 성능:  0.7984848484848485
#
# kospi 키워드에 대한 성능:  0.8090909090909091

# %% [markdown]
# ### test set에 대해서 성능이 한 80~87%정도 나온다 약간 상승!

# %% [markdown]
# ### 이러면 조금더 스케일링을 해서 정확도를 높이는 작업을 진행하자

# %%
estimator_list = list(range(1, 21))  # 1부터 20까지의 값을 가지는 리스트
depth_list = list(range(1, 21))  # 1부터 20까지의 값을 가지는 리스트
cv_scores_per_keyword = {}  # 각 키워드에 대한 교차 검증 점수를 저장할 딕셔너리
best_estimators_per_keyword = {}  # 각 키워드에 대한 최적의 트리 수를 저장할 딕셔너리
best_depths_per_keyword = {}  # 각 키워드에 대한 최적의 깊이를 저장할 딕셔너리
# 각 키워드에 대한 분류기 및 Voting Classifier 생성

for keyword, data_split in data_splits.items():
    X_train = data_split['X_train']
    y_train = data_split['y_train']
    
    cv_scores = []  # 교차 검증 점수를 저장할 리스트
    cv_scores_depth = []  # 교차 검증 점수를 저장할 리스트
    
    for i in tqdm(range(20)):
        rfc = RandomForestClassifier(n_estimators=i+1,
                                     max_leaf_nodes=300,
                                     n_jobs=-1,
                                     random_state=0)
        score = cross_val_score(rfc, X_train, y_train, cv=10, scoring='accuracy').mean()
        cv_scores.append(score)

    best_estimator = estimator_list[np.argmax(cv_scores)]
    best_estimators_per_keyword[keyword] = best_estimator
    
    for i in tqdm(range(20)):
        rfc = RandomForestClassifier(n_estimators=best_estimator,
                                     max_depth=i+1,
                                     max_leaf_nodes=300,
                                     n_jobs=-1,
                                     random_state=0)
        score = cross_val_score(rfc, X_train, y_train, cv=10, scoring='accuracy').mean()
        cv_scores_depth.append(score)

    best_depth = depth_list[np.argmax(cv_scores_depth)]
    best_depths_per_keyword[keyword] = best_depth
    
    # 교차 검증 점수를 딕셔너리에 저장
    cv_scores_per_keyword[keyword] = {'tree_scores': cv_scores, 'depth_scores': cv_scores_depth}

# 각 키워드에 대한 최적의 트리 수와 깊이 출력
for keyword in data_splits.keys():
    best_estimator = best_estimators_per_keyword[keyword]
    best_depth = best_depths_per_keyword[keyword]
    print(f"{keyword} 키워드에 대한 최적의 트리 수는 {best_estimator}, 최적의 깊이는 {best_depth} 입니다.")

# 각 키워드에 대한 교차 검증 점수 시각화
plt.figure(figsize=(20, 10))
for keyword, scores in cv_scores_per_keyword.items():
    plt.plot(estimator_list, scores['tree_scores'], marker='o', linestyle='dashed', label=f"{keyword} Keyword - Tree")
    plt.plot(depth_list, scores['depth_scores'], marker='o', linestyle='dashed', label=f"{keyword} Keyword - Depth")
plt.legend(fontsize=20)
plt.xlabel("Number of Trees / Max Depth", fontsize=20)
plt.ylabel("Accuracy", fontsize=20)
plt.title("Accuracy Score", fontsize=25)
for keyword in data_splits.keys():
    best_estimator = best_estimators_per_keyword[keyword]
    best_depth = best_depths_per_keyword[keyword]
    plt.axvline(best_estimator, color='r', linestyle='--', linewidth=2)
    plt.axvline(best_depth, color='g', linestyle='--', linewidth=2)
plt.show()
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# 100%|██████████| 20/20 [00:32<00:00,  1.61s/it]
# 100%|██████████| 20/20 [00:35<00:00,  1.78s/it]
# 100%|██████████| 20/20 [00:30<00:00,  1.54s/it]
# 100%|██████████| 20/20 [00:34<00:00,  1.70s/it]
# 100%|██████████| 20/20 [00:30<00:00,  1.51s/it]
# 100%|██████████| 20/20 [00:44<00:00,  2.21s/it]
# 100%|██████████| 20/20 [00:31<00:00,  1.56s/it]
# 100%|██████████| 20/20 [00:40<00:00,  2.01s/it]
# 100%|██████████| 20/20 [00:36<00:00,  1.84s/it]
# 100%|██████████| 20/20 [00:37<00:00,  1.85s/it]
# 100%|██████████| 20/20 [00:31<00:00,  1.60s/it]
# 100%|██████████| 20/20 [00:37<00:00,  1.85s/it]
# 100%|██████████| 20/20 [00:27<00:00,  1.39s/it]
# 100%|██████████| 20/20 [00:37<00:00,  1.87s/it]
# 100%|██████████| 20/20 [00:35<00:00,  1.78s/it]
# 100%|██████████| 20/20 [00:38<00:00,  1.90s/it]
# 100%|██████████| 20/20 [00:36<00:00,  1.81s/it]
# 100%|██████████| 20/20 [00:33<00:00,  1.67s/it]
# 100%|██████████| 20/20 [00:33<00:00,  1.69s/it]
# 100%|██████████| 20/20 [00:42<00:00,  2.11s/it]
# 100%|██████████| 20/20 [00:35<00:00,  1.77s/it]
# 100%|██████████| 20/20 [00:44<00:00,  2.24s/it]
# 100%|██████████| 20/20 [00:33<00:00,  1.69s/it]
# 100%|██████████| 20/20 [00:47<00:00,  2.40s/it]
# 100%|██████████| 20/20 [00:42<00:00,  2.12s/it]
# 100%|██████████| 20/20 [00:45<00:00,  2.26s/it]
# auto 키워드에 대한 최적의 트리 수는 16, 최적의 깊이는 19 입니다.
# construct 키워드에 대한 최적의 트리 수는 16, 최적의 깊이는 17 입니다.
# capital_market 키워드에 대한 최적의 트리 수는 20, 최적의 깊이는 15 입니다.
# chemicals 키워드에 대한 최적의 트리 수는 20, 최적의 깊이는 17 입니다.
# equipment 키워드에 대한 최적의 트리 수는 17, 최적의 깊이는 20 입니다.
# transport 키워드에 대한 최적의 트리 수는 19, 최적의 깊이는 18 입니다.
# semi 키워드에 대한 최적의 트리 수는 20, 최적의 깊이는 19 입니다.
# bank 키워드에 대한 최적의 트리 수는 19, 최적의 깊이는 18 입니다.
# steel 키워드에 대한 최적의 트리 수는 14, 최적의 깊이는 18 입니다.
# telecom 키워드에 대한 최적의 트리 수는 18, 최적의 깊이는 20 입니다.
# staples 키워드에 대한 최적의 트리 수는 20, 최적의 깊이는 17 입니다.
# discretionary 키워드에 대한 최적의 트리 수는 20, 최적의 깊이는 14 입니다.
# kospi 키워드에 대한 최적의 트리 수는 20, 최적의 깊이는 20 입니다.

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# 각 키워드별 최적의 트리 개수와 최적의 깊이 출력
for keyword in data_splits.keys():
    best_estimator = best_estimators_per_keyword[keyword]
    best_depth = best_depths_per_keyword[keyword]

    
    # 최적의 트리 개수와 깊이를 사용하여 RandomForestClassifier 초기화
    rfc = RandomForestClassifier(n_estimators=best_estimator, 
                                 max_depth=best_depth, 
                                 max_leaf_nodes=300,
                                 n_jobs=-1,
                                 random_state=0)
    
    # 교차 검증을 통한 정확도 측정
    cv_scores = cross_val_score(rfc, X_train, y_train, cv=10, scoring='accuracy')
    
    # 평균 정확도 출력
    print(f"{keyword} 키워드에 대한 Train set에 대한 성능 (10 fold cross validation)")
    print(f"평균 정확도: {cv_scores.mean():.4f}")
    
    # Train set에 대한 최적의 모델 학습
    rfc.fit(X_train, y_train)
    
    # Test set에 대한 예측값 생성
    y_pred = rfc.predict(X_test)
    
    # Test set에 대한 정확도 계산 및 출력
    acc_test = accuracy_score(y_true=y_test, y_pred=y_pred)
    print(f"{keyword} 키워드에 대한 Test set에 대한 성능")
    print(f"정확도: {acc_test:.4f}\n")
    
    # Test set에 대한 민감도와 정밀도 계산
    recall = recall_score(y_true=y_test, y_pred=y_pred, average='macro')
    precision = precision_score(y_true=y_test, y_pred=y_pred, average='macro')

    # 민감도와 정밀도 출력
    
    # 혼동 행렬 생성
    cm = confusion_matrix(y_test, y_pred)
# Out:
# auto 키워드에 대한 Train set에 대한 성능 (10 fold cross validation)
# 평균 정확도: 0.8091
# auto 키워드에 대한 Test set에 대한 성능
# 정확도: 0.8152
#
# construct 키워드에 대한 Train set에 대한 성능 (10 fold cross validation)
# 평균 정확도: 0.8102
# construct 키워드에 대한 Test set에 대한 성능
# 정확도: 0.8091
#
# capital_market 키워드에 대한 Train set에 대한 성능 (10 fold cross validation)
# 평균 정확도: 0.8114
# capital_market 키워드에 대한 Test set에 대한 성능
# 정확도: 0.8182
#
# chemicals 키워드에 대한 Train set에 대한 성능 (10 fold cross validation)
# 평균 정확도: 0.8163
# chemicals 키워드에 대한 Test set에 대한 성능
# 정확도: 0.8106
#
# equipment 키워드에 대한 Train set에 대한 성능 (10 fold cross validation)
# 평균 정확도: 0.8117
# equipment 키워드에 대한 Test set에 대한 성능
# 정확도: 0.8045
#
# transport 키워드에 대한 Train set에 대한 성능 (10 fold cross validation)
# 평균 정확도: 0.8125
# transport 키워드에 대한 Test set에 대한 성능
# 정확도: 0.7985
#
# semi 키워드에 대한 Train set에 대한 성능 (10 fold cross validation)
# 평균 정확도: 0.8140
# semi 키워드에 대한 Test set에 대한 성능
# 정확도: 0.8091
#
# bank 키워드에 대한 Train set에 대한 성능 (10 fold cross validation)
# 평균 정확도: 0.8125
# bank 키워드에 대한 Test set에 대한 성능
# 정확도: 0.7985
#
# steel 키워드에 대한 Train set에 대한 성능 (10 fold cross validation)
# 평균 정확도: 0.8068
# steel 키워드에 대한 Test set에 대한 성능
# 정확도: 0.7879
#
# telecom 키워드에 대한 Train set에 대한 성능 (10 fold cross validation)
# 평균 정확도: 0.8117
# telecom 키워드에 대한 Test set에 대한 성능
# 정확도: 0.8061
#
# staples 키워드에 대한 Train set에 대한 성능 (10 fold cross validation)
# 평균 정확도: 0.8163
# staples 키워드에 대한 Test set에 대한 성능
# 정확도: 0.8106
#
# discretionary 키워드에 대한 Train set에 대한 성능 (10 fold cross validation)
# 평균 정확도: 0.8061
# discretionary 키워드에 대한 Test set에 대한 성능
# 정확도: 0.8136
#
# kospi 키워드에 대한 Train set에 대한 성능 (10 fold cross validation)
# 평균 정확도: 0.8167
# kospi 키워드에 대한 Test set에 대한 성능
# 정확도: 0.8152

# %% [markdown]
# ### 그 이전에 나온 값과 비교 해 보았을때 더 우수한 데이터 결과가 나옴

# %% [markdown]
# ### 따라서 최종적으로 뽑아본다면은 이런식으로 나온다

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# 각 키워드별 최적의 트리 개수와 최적의 깊이 출력
for keyword in data_splits.keys():
    best_estimator = best_estimators_per_keyword[keyword]
    best_depth = best_depths_per_keyword[keyword]
    print(f"{keyword} 키워드에 대한 최적의 트리 개수: {best_estimator}")
    print(f"{keyword} 키워드에 대한 최적의 깊이 개수: {best_depth}")
    
    # 최적의 트리 개수와 깊이를 사용하여 RandomForestClassifier 초기화
    rfc = RandomForestClassifier(n_estimators=best_estimator, 
                                 max_depth=best_depth, 
                                 max_leaf_nodes=300,
                                 n_jobs=-1,
                                 random_state=0)
    
    # 교차 검증을 통한 정확도 측정
    cv_scores = cross_val_score(rfc, X_train, y_train, cv=10, scoring='accuracy')
    
    # 평균 정확도 출력
    print(f"{keyword} 키워드에 대한 Train set에 대한 성능 (10 fold cross validation)")
    print(f"평균 정확도: {cv_scores.mean():.4f}")
    
    # Train set에 대한 최적의 모델 학습
    rfc.fit(X_train, y_train)
    
    # Test set에 대한 예측값 생성
    y_pred = rfc.predict(X_test)
    
    # Test set에 대한 정확도 계산 및 출력
    acc_test = accuracy_score(y_true=y_test, y_pred=y_pred)
    print(f"{keyword} 키워드에 대한 Test set에 대한 성능")
    print(f"정확도: {acc_test:.4f}\n")
    
    # Test set에 대한 민감도와 정밀도 계산
    recall = recall_score(y_true=y_test, y_pred=y_pred, average='macro')
    precision = precision_score(y_true=y_test, y_pred=y_pred, average='macro')

    # 민감도와 정밀도 출력
    print(f"{keyword} 키워드에 대한 Test set에 대한 민감도와 정밀도")
    print(f"민감도: {recall:.4f}, 정밀도: {precision:.4f}\n")
    
    # 혼동 행렬 생성
    cm = confusion_matrix(y_test, y_pred)

    # 혼동 행렬 시각화
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, cmap=plt.cm.Blues, fmt='d', cbar=False)
    plt.xlabel('Predicted labels')
    plt.ylabel('True labels')
    plt.title(f'Confusion Matrix - {keyword}')
    plt.show()
# Out:
# auto 키워드에 대한 최적의 트리 개수: 16
# auto 키워드에 대한 최적의 깊이 개수: 19
# auto 키워드에 대한 Train set에 대한 성능 (10 fold cross validation)
# 평균 정확도: 0.8091
# auto 키워드에 대한 Test set에 대한 성능
# 정확도: 0.8152
#
# auto 키워드에 대한 Test set에 대한 민감도와 정밀도
# 민감도: 0.7981, 정밀도: 0.8100
# construct 키워드에 대한 최적의 트리 개수: 16
# construct 키워드에 대한 최적의 깊이 개수: 17
# construct 키워드에 대한 Train set에 대한 성능 (10 fold cross validation)
# 평균 정확도: 0.8102
# construct 키워드에 대한 Test set에 대한 성능
# 정확도: 0.8091
#
# construct 키워드에 대한 Test set에 대한 민감도와 정밀도
# 민감도: 0.7914, 정밀도: 0.8039
# capital_market 키워드에 대한 최적의 트리 개수: 20
# capital_market 키워드에 대한 최적의 깊이 개수: 15
# capital_market 키워드에 대한 Train set에 대한 성능 (10 fold cross validation)
# 평균 정확도: 0.8114
# capital_market 키워드에 대한 Test set에 대한 성능
# 정확도: 0.8182
#
# capital_market 키워드에 대한 Test set에 대한 민감도와 정밀도
# 민감도: 0.8002, 정밀도: 0.8153
# chemicals 키워드에 대한 최적의 트리 개수: 20
# chemicals 키워드에 대한 최적의 깊이 개수: 17
# chemicals 키워드에 대한 Train set에 대한 성능 (10 fold cross validation)
# 평균 정확도: 0.8163
# chemicals 키워드에 대한 Test set에 대한 성능
# 정확도: 0.8106
#
# chemicals 키워드에 대한 Test set에 대한 민감도와 정밀도
# 민감도: 0.7940, 정밀도: 0.8020
# equipment 키워드에 대한 최적의 트리 개수: 17
# equipment 키워드에 대한 최적의 깊이 개수: 20
# equipment 키워드에 대한 Train set에 대한 성능 (10 fold cross validation)
# 평균 정확도: 0.8117
# equipment 키워드에 대한 Test set에 대한 성능
# 정확도: 0.8045
#
# equipment 키워드에 대한 Test set에 대한 민감도와 정밀도
# 민감도: 0.7854, 정밀도: 0.7981
# transport 키워드에 대한 최적의 트리 개수: 19
# transport 키워드에 대한 최적의 깊이 개수: 18
# transport 키워드에 대한 Train set에 대한 성능 (10 fold cross validation)
# 평균 정확도: 0.8125
# transport 키워드에 대한 Test set에 대한 성능
# 정확도: 0.7985
#
# transport 키워드에 대한 Test set에 대한 민감도와 정밀도
# 민감도: 0.7795, 정밀도: 0.7912
# semi 키워드에 대한 최적의 트리 개수: 20
# semi 키워드에 대한 최적의 깊이 개수: 19
# semi 키워드에 대한 Train set에 대한 성능 (10 fold cross validation)
# 평균 정확도: 0.8140
# semi 키워드에 대한 Test set에 대한 성능
# 정확도: 0.8091
#
# semi 키워드에 대한 Test set에 대한 민감도와 정밀도
# 민감도: 0.7924, 정밀도: 0.8016
# bank 키워드에 대한 최적의 트리 개수: 19
# bank 키워드에 대한 최적의 깊이 개수: 18
# bank 키워드에 대한 Train set에 대한 성능 (10 fold cross validation)
# 평균 정확도: 0.8125
# bank 키워드에 대한 Test set에 대한 성능
# 정확도: 0.7985
#
# bank 키워드에 대한 Test set에 대한 민감도와 정밀도
# 민감도: 0.7795, 정밀도: 0.7912
# steel 키워드에 대한 최적의 트리 개수: 14
# steel 키워드에 대한 최적의 깊이 개수: 18
# steel 키워드에 대한 Train set에 대한 성능 (10 fold cross validation)
# 평균 정확도: 0.8068
# steel 키워드에 대한 Test set에 대한 성능
# 정확도: 0.7879
#
# steel 키워드에 대한 Test set에 대한 민감도와 정밀도
# 민감도: 0.7681, 정밀도: 0.7791
# telecom 키워드에 대한 최적의 트리 개수: 18
# telecom 키워드에 대한 최적의 깊이 개수: 20
# telecom 키워드에 대한 Train set에 대한 성능 (10 fold cross validation)
# 평균 정확도: 0.8117
# telecom 키워드에 대한 Test set에 대한 성능
# 정확도: 0.8061
#
# telecom 키워드에 대한 Test set에 대한 민감도와 정밀도
# 민감도: 0.7873, 정밀도: 0.8006
# staples 키워드에 대한 최적의 트리 개수: 20
# staples 키워드에 대한 최적의 깊이 개수: 17
# staples 키워드에 대한 Train set에 대한 성능 (10 fold cross validation)
# 평균 정확도: 0.8163
# staples 키워드에 대한 Test set에 대한 성능
# 정확도: 0.8106
#
# staples 키워드에 대한 Test set에 대한 민감도와 정밀도
# 민감도: 0.7940, 정밀도: 0.8020
# discretionary 키워드에 대한 최적의 트리 개수: 20
# discretionary 키워드에 대한 최적의 깊이 개수: 14
# discretionary 키워드에 대한 Train set에 대한 성능 (10 fold cross validation)
# 평균 정확도: 0.8061
# discretionary 키워드에 대한 Test set에 대한 성능
# 정확도: 0.8136
#
# discretionary 키워드에 대한 Test set에 대한 민감도와 정밀도
# 민감도: 0.7934, 정밀도: 0.8058
# kospi 키워드에 대한 최적의 트리 개수: 20
# kospi 키워드에 대한 최적의 깊이 개수: 20
# kospi 키워드에 대한 Train set에 대한 성능 (10 fold cross validation)
# 평균 정확도: 0.8167
# kospi 키워드에 대한 Test set에 대한 성능
# 정확도: 0.8152
#
# kospi 키워드에 대한 Test set에 대한 민감도와 정밀도
# 민감도: 0.7990, 정밀도: 0.8076

# %% [markdown]
# ### 이후 피처별 중요한 것들을 출력하고 싶었고 키워드별 상위 5개만 출력했다

# %%
# 각 키워드별 상위 5개와 하위 5개 특성의 인덱스와 중요도 출력
for keyword, data_split in data_splits.items():
    X_train = data_split['X_train']
    y_train = data_split['y_train']

    best_estimator = best_estimators_per_keyword[keyword]
    best_depth = best_depths_per_keyword[keyword]

    # RandomForestClassifier 초기화 및 학습
    rfc = RandomForestClassifier(n_estimators=best_estimator, 
                                 max_depth=best_depth, 
                                 max_leaf_nodes=300,
                                 n_jobs=-1,
                                 random_state=0)
    rfc.fit(X_train, y_train)

    # Feature Importance 계산
    feats = {}
    for feature, importance in zip(range(X_train.shape[1]), rfc.feature_importances_):
        feats[feature] = importance

    # 중요도 순으로 정렬하여 상위 5개와 하위 5개 선택
    sorted_feats = sorted(feats.items(), key=lambda x: x[1], reverse=True)
    top_5_importances = sorted_feats[:5]
    bottom_5_importances = sorted_feats[-5:]

    # 결과 출력
    print(f"{keyword} 키워드의 상위 5개 특성:")
    for feature_index, importance in top_5_importances:
        feature_name = column_names_per_keyword[keyword][feature_index]  # 열 이름 가져오기
        print(f"Feature Name: {feature_name}, Importance: {importance:.4f}")
    print()

    print(f"{keyword} 키워드의 하위 5개 특성:")
    for feature_index, importance in bottom_5_importances:
        feature_name = column_names_per_keyword[keyword][feature_index]  # 열 이름 가져오기
        print(f"Feature Name: {feature_name}, Importance: {importance:.4f}")
    print()
# Out:
# auto 키워드의 상위 5개 특성:
# Feature Name: export_60, Importance: 0.0224
# Feature Name: us_e_infla, Importance: 0.0205
# Feature Name: 중국 산업 생산_60, Importance: 0.0196
# Feature Name: 달러 인덱스_60, Importance: 0.0185
# Feature Name: yield_gap(%)_60, Importance: 0.0184
#
# auto 키워드의 하위 5개 특성:
# Feature Name: 구리선물, Importance: 0.0063
# Feature Name: VIX, Importance: 0.0061
# Feature Name: US_auto, Importance: 0.0059
# Feature Name: T10Y2Y, Importance: 0.0051
# Feature Name: yield_gap(%), Importance: 0.0049
#
# construct 키워드의 상위 5개 특성:
# Feature Name: TIPS, Importance: 0.0288
# Feature Name: 중국 산업 생산, Importance: 0.0227
# Feature Name: usa_cpi_60, Importance: 0.0191
# Feature Name: export_60, Importance: 0.0188
# Feature Name: 원달러_60, Importance: 0.0182
#
# construct 키워드의 하위 5개 특성:
# Feature Name: yield_gap(%), Importance: 0.0060
# Feature Name: 구리선물, Importance: 0.0054
# Feature Name: MSCI_EMER, Importance: 0.0000
# Feature Name: MSCI_EMER_20, Importance: 0.0000
# Feature Name: MSCI_EMER_60, Importance: 0.0000
#
# capital_market 키워드의 상위 5개 특성:
# Feature Name: 구리선물_60, Importance: 0.0247
# Feature Name: 중국 산업 생산, Importance: 0.0244
# Feature Name: 금 선물_60, Importance: 0.0232
# Feature Name: 코스피+코스닥 거래량_20, Importance: 0.0201
# Feature Name: export, Importance: 0.0186
#
# capital_market 키워드의 하위 5개 특성:
# Feature Name: VIX, Importance: 0.0072
# Feature Name: cpi_20, Importance: 0.0069
# Feature Name: treasury_10_3_diff, Importance: 0.0056
# Feature Name: 달러 인덱스, Importance: 0.0023
# Feature Name: 중국 소매판매, Importance: 0.0023
#
# chemicals 키워드의 상위 5개 특성:
# Feature Name: usa_cpi_60, Importance: 0.0279
# Feature Name: VIX, Importance: 0.0252
# Feature Name: VIX_60, Importance: 0.0218
# Feature Name: naphtha_price_20, Importance: 0.0212
# Feature Name: 중국 산업 생산, Importance: 0.0207
#
# chemicals 키워드의 하위 5개 특성:
# Feature Name: 원달러, Importance: 0.0064
# Feature Name: pbr_20, Importance: 0.0060
# Feature Name: MSCI_EMER, Importance: 0.0059
# Feature Name: 중국 소매판매, Importance: 0.0051
# Feature Name: yield_gap(%), Importance: 0.0040
#
# equipment 키워드의 상위 5개 특성:
# Feature Name: TIPS, Importance: 0.0270
# Feature Name: 구리선물_60, Importance: 0.0262
# Feature Name: 원달러_60, Importance: 0.0260
# Feature Name: 중국 산업 생산, Importance: 0.0241
# Feature Name: 달러 인덱스_60, Importance: 0.0225
#
# equipment 키워드의 하위 5개 특성:
# Feature Name: 구리선물, Importance: 0.0056
# Feature Name: T10Y2Y, Importance: 0.0056
# Feature Name: 3년물 , Importance: 0.0056
# Feature Name: 원엔_20, Importance: 0.0045
# Feature Name: 기계수주경상금액, Importance: 0.0043
#
# transport 키워드의 상위 5개 특성:
# Feature Name: 중국 산업 생산, Importance: 0.0292
# Feature Name: 구리선물_60, Importance: 0.0213
# Feature Name: PPI, Importance: 0.0202
# Feature Name: DGS2, Importance: 0.0196
# Feature Name: treasury_10_3_diff_60, Importance: 0.0184
#
# transport 키워드의 하위 5개 특성:
# Feature Name: 중국 소매판매_20, Importance: 0.0072
# Feature Name: 3년물 _20, Importance: 0.0064
# Feature Name: 중국 소매판매, Importance: 0.0060
# Feature Name: 중국고정자산투자(yoy%), Importance: 0.0051
# Feature Name: yield_gap(%), Importance: 0.0045
#
# semi 키워드의 상위 5개 특성:
# Feature Name: 10년물 _60, Importance: 0.0207
# Feature Name: treasury_10_3_diff_60, Importance: 0.0197
# Feature Name: WTI_60, Importance: 0.0167
# Feature Name: semi, Importance: 0.0164
# Feature Name: 구리선물_60, Importance: 0.0164
#
# semi 키워드의 하위 5개 특성:
# Feature Name: T10Y2Y, Importance: 0.0078
# Feature Name: SOX_20, Importance: 0.0076
# Feature Name: TIPS, Importance: 0.0073
# Feature Name: 중국고정자산투자(yoy%), Importance: 0.0065
# Feature Name: 달러 인덱스, Importance: 0.0064
#
# bank 키워드의 상위 5개 특성:
# Feature Name: 중국 산업 생산, Importance: 0.0238
# Feature Name: 중국 소매판매_60, Importance: 0.0174
# Feature Name: 달러 인덱스_60, Importance: 0.0169
# Feature Name: yield_gap(%)_60, Importance: 0.0168
# Feature Name: pbr_60, Importance: 0.0166
#
# bank 키워드의 하위 5개 특성:
# Feature Name: 중국 소매판매_20, Importance: 0.0069
# Feature Name: 달러 인덱스, Importance: 0.0061
# Feature Name: T10Y2Y, Importance: 0.0061
# Feature Name: 구리선물, Importance: 0.0053
# Feature Name: yield_gap(%), Importance: 0.0039
#
# steel 키워드의 상위 5개 특성:
# Feature Name: TIPS, Importance: 0.0290
# Feature Name: 중국 산업 생산, Importance: 0.0209
# Feature Name: 원달러_60, Importance: 0.0202
# Feature Name: steel, Importance: 0.0189
# Feature Name: 구리선물_20, Importance: 0.0188
#
# steel 키워드의 하위 5개 특성:
# Feature Name: 중국고정자산투자(yoy%), Importance: 0.0064
# Feature Name: 3년물 _20, Importance: 0.0058
# Feature Name: 중국 소매판매, Importance: 0.0047
# Feature Name: yield_gap(%), Importance: 0.0037
# Feature Name: 구리선물, Importance: 0.0029
#
# telecom 키워드의 상위 5개 특성:
# Feature Name: MSCI_EMER_60, Importance: 0.0276
# Feature Name: yield_gap(%)_60, Importance: 0.0187
# Feature Name: 구리선물_60, Importance: 0.0178
# Feature Name: PPI, Importance: 0.0175
# Feature Name: 달러 인덱스_60, Importance: 0.0174
#
# telecom 키워드의 하위 5개 특성:
# Feature Name: VIX_20, Importance: 0.0072
# Feature Name: VIX, Importance: 0.0070
# Feature Name: yield_gap(%), Importance: 0.0062
# Feature Name: 중국 소매판매, Importance: 0.0060
# Feature Name: 구리선물, Importance: 0.0032
#
# staples 키워드의 상위 5개 특성:
# Feature Name: 구리선물_60, Importance: 0.0260
# Feature Name: 미 대두 선물 _20, Importance: 0.0191
# Feature Name: 금 선물_60, Importance: 0.0171
# Feature Name: 10년물 , Importance: 0.0170
# Feature Name: 중국 PMI_60, Importance: 0.0160
#
# staples 키워드의 하위 5개 특성:
# Feature Name: 원엔_20, Importance: 0.0066
# Feature Name: pbr_20, Importance: 0.0066
# Feature Name: T10Y2Y, Importance: 0.0062
# Feature Name: 중국 PMI_20, Importance: 0.0059
# Feature Name: 중국고정자산투자(yoy%), Importance: 0.0033
#
# discretionary 키워드의 상위 5개 특성:
# Feature Name: 달러 인덱스_60, Importance: 0.0215
# Feature Name: VIX, Importance: 0.0197
# Feature Name: TIPS_60, Importance: 0.0195
# Feature Name: DGS10_60, Importance: 0.0193
# Feature Name: 중국 PMI_60, Importance: 0.0192
#
# discretionary 키워드의 하위 5개 특성:
# Feature Name: yield_gap(%), Importance: 0.0070
# Feature Name: 달러 인덱스, Importance: 0.0068
# Feature Name: 3년물 _20, Importance: 0.0064
# Feature Name: cpi_20, Importance: 0.0063
# Feature Name: 중국 PMI_20, Importance: 0.0062
#
# kospi 키워드의 상위 5개 특성:
# Feature Name: 중국 산업 생산, Importance: 0.0243
# Feature Name: 구리선물_60, Importance: 0.0224
# Feature Name: DGS2, Importance: 0.0190
# Feature Name: DGS10_60, Importance: 0.0189
# Feature Name: 구리선물, Importance: 0.0186
#
# kospi 키워드의 하위 5개 특성:
# Feature Name: 중국고정자산투자(yoy%), Importance: 0.0072
# Feature Name: WTI, Importance: 0.0070
# Feature Name: VIX, Importance: 0.0067
# Feature Name: 중국 소매판매, Importance: 0.0067
# Feature Name: T10Y2Y, Importance: 0.0052

# %% [markdown]
# ### 이후 이것을 그래프로 변환해서 출력
# ### 생각보다 자동차지수와 중국 지표 금 구리 이런게 영향을 많이 미치는구마잉!

# %%
# 상위 5개 특성의 이름과 중요도 분리하여 그래프 출력
import matplotlib.pyplot as plt
import seaborn as sns

# 한글 폰트 설정
from matplotlib import font_manager, rc
path = f'C:/Windows/Fonts/gulim.ttc'
font_name = font_manager.FontProperties(fname=path).get_name()
rc('font', family=font_name)
for keyword, data_split in data_splits.items():
    X_train = data_split['X_train']
    y_train = data_split['y_train']

    best_estimator = best_estimators_per_keyword[keyword]
    best_depth = best_depths_per_keyword[keyword]

    # RandomForestClassifier 초기화 및 학습
    rfc = RandomForestClassifier(n_estimators=best_estimator, 
                                 max_depth=best_depth, 
                                 max_leaf_nodes=300,
                                 n_jobs=-1,
                                 random_state=0)
    rfc.fit(X_train, y_train)

    # Feature Importance 계산
    feats = {}
    for feature, importance in zip(range(X_train.shape[1]), rfc.feature_importances_):
        feats[feature] = importance

    # 중요도 순으로 정렬하여 상위 5개 선택
    sorted_feats = sorted(feats.items(), key=lambda x: x[1], reverse=True)
    top_5_importances = sorted_feats[:5]

    # 상위 5개 특성의 이름과 중요도 분리
    top_5_features = [column_names_per_keyword[keyword][feature_index] for feature_index, _ in top_5_importances]
    top_5_importance_values = [importance for _, importance in top_5_importances]

    # 그래프 출력
    plt.figure(figsize=(12, 8))
    sns.barplot(x=top_5_importance_values, y=top_5_features, color='skyblue')
    plt.title(f'Top 5 Feature Importance - {keyword}')
    plt.xlabel('Importance')
    plt.ylabel('Feature Label')
    plt.gca().invert_yaxis()  # y축 라벨 역순으로 표시
    plt.show()

# %% [markdown]
# ### 모델을 저장하고 다시 불러옴

# %% [markdown]
# ### 모델을 통해서 다음날이 어떨지에 대해서 예측해봄

# %% [markdown]
# ### 모델 저장은 성공적!

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from joblib import dump, load
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier

# 디렉토리가 없다면 생성
if not os.path.exists('plk_folder_03'):
    os.makedirs('plk_folder_03')

# 각 키워드별로 최종 모델 학습 및 모델 저장
for keyword, data_split in data_splits.items():
    X_train = data_split['X_train']
    y_train = data_split['y_train']

    # RandomForestClassifier 초기화
    rfc = RandomForestClassifier(n_estimators=best_estimators_per_keyword[keyword], 
                                 max_depth=best_depths_per_keyword[keyword], 
                                 max_leaf_nodes=300,
                                 n_jobs=-1,
                                 random_state=0)

    # 최종 모델 학습
    rfc.fit(X_train, y_train)

    # 모델 저장
    filename = f"plk_folder_03/{keyword}_model.pkl"
    dump(rfc, filename)
    print(f"Model for {keyword} keyword saved as {filename}")

print("\n< AI model: save >")

# 모델 로드
loaded_models = {}

# 각 키워드별로 모델 로드
for keyword in keywords:
    filename = f"plk_folder_03/{keyword}_model.pkl"
    if os.path.exists(filename):
        loaded_models[keyword] = load(filename)
        print(f"Model for {keyword} keyword loaded from {filename}")
    else:
        print(f"Model file for {keyword} keyword does not exist: {filename}")

print("\n< AI model: load >")


# Train set 및 Test set에 대한 성능을 저장할 딕셔너리 생성

# Random Forest 모델 생성


# 각 키워드에 대해 모델을 학습하고 Train set 및 Test set에 대한 성능을 측정
for keyword, data_split in data_splits.items():
    X_train = data_split['X_train']
    y_train = data_split['y_train']
    X_test = data_split['X_test']
    y_test = data_split['y_test']
    
    # 모델 학습
    rfc.fit(X_train, y_train)

    # Train set에 대한 성능 측정
    y_pred_train = rfc.predict(X_train)
    acc_train = accuracy_score(y_true=y_train, y_pred=y_pred_train)

    # Test set에 대한 성능 측정
    y_pred_test = rfc.predict(X_test)
    acc_test = accuracy_score(y_true=y_test, y_pred=y_pred_test)

    # 결과 저장
    loaded_models[keyword] = {
        'Train 성능': acc_train,
        'Test 성능': acc_test
    }

# 각 키워드에 대한 Train set 및 Test set의 성능 출력
for keyword, performance in loaded_models.items():
    print(f"{keyword} 키워드에 대한 성능: ",performance['Test 성능'])
    print()
# Out:
# Model for auto keyword saved as plk_folder_03/auto_model.pkl
# Model for construct keyword saved as plk_folder_03/construct_model.pkl
# Model for capital_market keyword saved as plk_folder_03/capital_market_model.pkl
# Model for chemicals keyword saved as plk_folder_03/chemicals_model.pkl
# Model for equipment keyword saved as plk_folder_03/equipment_model.pkl
# Model for transport keyword saved as plk_folder_03/transport_model.pkl
# Model for semi keyword saved as plk_folder_03/semi_model.pkl
# Model for bank keyword saved as plk_folder_03/bank_model.pkl
# Model for steel keyword saved as plk_folder_03/steel_model.pkl
# Model for telecom keyword saved as plk_folder_03/telecom_model.pkl
# Model for staples keyword saved as plk_folder_03/staples_model.pkl
# Model for discretionary keyword saved as plk_folder_03/discretionary_model.pkl
# Model for kospi keyword saved as plk_folder_03/kospi_model.pkl
#
# < AI model: save >
# Model for auto keyword loaded from plk_folder_03/auto_model.pkl
# Model for construct keyword loaded from plk_folder_03/construct_model.pkl
# Model for capital_market keyword loaded from plk_folder_03/capital_market_model.pkl
# Model for chemicals keyword loaded from plk_folder_03/chemicals_model.pkl
# Model for equipment keyword loaded from plk_folder_03/equipment_model.pkl
# Model for transport keyword loaded from plk_folder_03/transport_model.pkl
# Model for semi keyword loaded from plk_folder_03/semi_model.pkl
# Model for bank keyword loaded from plk_folder_03/bank_model.pkl
# Model for steel keyword loaded from plk_folder_03/steel_model.pkl
# Model for telecom keyword loaded from plk_folder_03/telecom_model.pkl
# Model for staples keyword loaded from plk_folder_03/staples_model.pkl
# Model for discretionary keyword loaded from plk_folder_03/discretionary_model.pkl
# Model for kospi keyword loaded from plk_folder_03/kospi_model.pkl
#
# < AI model: load >
# auto 키워드에 대한 성능:  0.8136363636363636
#
# construct 키워드에 대한 성능:  0.8181818181818182
#
# capital_market 키워드에 대한 성능:  0.8181818181818182
#
# chemicals 키워드에 대한 성능:  0.8196969696969697
#
# equipment 키워드에 대한 성능:  0.8454545454545455
#
# transport 키워드에 대한 성능:  0.8484848484848485
#
# semi 키워드에 대한 성능:  0.7924242424242425
#
# bank 키워드에 대한 성능:  0.8045454545454546
#
# steel 키워드에 대한 성능:  0.8166666666666667
#
# telecom 키워드에 대한 성능:  0.796969696969697
#
# staples 키워드에 대한 성능:  0.8378787878787879
#
# discretionary 키워드에 대한 성능:  0.7924242424242425
#
# kospi 키워드에 대한 성능:  0.8151515151515152

# %%
# 결측치 제거 이후의 데이터프레임의 마지막 행 출력
for keyword, last_row in last_rows.items():
    print(f"마지막 행 {keyword}: {last_row}")
    print(len(last_row))
# Out:
# 마지막 행 auto: auto                   NaN
# WTI                  84.54
# DGS2                  4.72
# DGS10                 1.98
# TIPS                  1.98
#                     ...
# 중국 소매판매_60       -0.008819
# 중국 산업 생산_60        0.00085
# MSCI_EMER_60       0.00112
# US_auto_60        0.000034
# export_auto_60    -0.00319
# Name: 2024-04-01, Length: 88, dtype: object
# 88
# 마지막 행 construct: construct            NaN
# WTI                84.54
# DGS2                4.72
# DGS10               1.98
# TIPS                1.98
#                   ...
# 중국 소매판매_60     -0.008819
# 중국 산업 생산_60      0.00085
# MSCI_EMER_60     0.00112
# 매매가격지수_60           -0.0
# 아파트매매거래량_60     0.003402
# Name: 2024-04-01, Length: 88, dtype: object
# 88
# 마지막 행 capital_market: capital_market         NaN
# WTI                  84.54
# DGS2                  4.72
# DGS10                 1.98
# TIPS                  1.98
#                     ...
# 중국 소매판매_60       -0.008819
# 중국 산업 생산_60        0.00085
# MSCI_EMER_60       0.00112
# 증권 배당 수익률_60      -0.00426
# 코스피+코스닥 거래량_60   -0.002124
# Name: 2024-04-01, Length: 88, dtype: object
# 88
# 마지막 행 chemicals: chemicals                NaN
# WTI                    84.54
# DGS2                    4.72
# DGS10                   1.98
# TIPS                    1.98
#                       ...
# 중국 소매판매_60         -0.008819
# 중국 산업 생산_60          0.00085
# MSCI_EMER_60         0.00112
# lc_price_60         0.004591
# naphtha_price_60    0.001271
# Name: 2024-04-01, Length: 88, dtype: object
# 88
# 마지막 행 equipment: equipment                NaN
# WTI                    84.54
# DGS2                    4.72
# DGS10                   1.98
# TIPS                    1.98
#                       ...
# 중국 소매판매_60         -0.008819
# 중국 산업 생산_60          0.00085
# MSCI_EMER_60         0.00112
# 기계수주경상금액_60         0.006044
# BSI 제조업경기실사지수_60    0.001215
# Name: 2024-04-01, Length: 88, dtype: object
# 88
# 마지막 행 transport: transport            NaN
# WTI                84.54
# DGS2                4.72
# DGS10               1.98
# TIPS                1.98
#                   ...
# 중국 소매판매_60     -0.008819
# 중국 산업 생산_60      0.00085
# MSCI_EMER_60     0.00112
# 발틱운임_60         0.005923
# scfi_60        -0.001796
# Name: 2024-04-01, Length: 88, dtype: object
# 88
# 마지막 행 semi: semi                 NaN
# WTI                84.54
# DGS2                4.72
# DGS10               1.98
# TIPS                1.98
#                   ...
# 중국 소매판매_60     -0.008819
# 중국 산업 생산_60      0.00085
# MSCI_EMER_60     0.00112
# SOX_60          0.003868
# 메모리 수출금액_60     0.000983
# Name: 2024-04-01, Length: 88, dtype: object
# 88
# 마지막 행 bank: bank                     NaN
# WTI                    84.54
# DGS2                    4.72
# DGS10                   1.98
# TIPS                    1.98
#                       ...
# 중국 소매판매_60         -0.008819
# 중국 산업 생산_60          0.00085
# MSCI_EMER_60         0.00112
# bank_dividend_60   -0.005329
# call_rate_60       -0.000017
# Name: 2024-04-01, Length: 88, dtype: object
# 88
# 마지막 행 steel: steel                  NaN
# WTI                  84.54
# DGS2                  4.72
# DGS10                 1.98
# TIPS                  1.98
#                     ...
# 중국 소매판매_60       -0.008819
# 중국 산업 생산_60        0.00085
# MSCI_EMER_60       0.00112
# 철광석 가격_60        -0.004466
# 미국 철강 코일 선물_60    -0.00693
# Name: 2024-04-01, Length: 88, dtype: object
# 88
# 마지막 행 telecom: telecom                             NaN
# WTI                               84.54
# DGS2                               4.72
# DGS10                              1.98
# TIPS                               1.98
#                                  ...
# 중국 소매판매_60                    -0.008819
# 중국 산업 생산_60                     0.00085
# MSCI_EMER_60                    0.00112
# 통신배당_60                       -0.005454
# IT산업별/월별 수출 현황 중 통신기기 소계_60   -0.007135
# Name: 2024-04-01, Length: 88, dtype: object
# 88
# 마지막 행 staples: staples              NaN
# WTI                84.54
# DGS2                4.72
# DGS10               1.98
# TIPS                1.98
#                   ...
# 중국 소매판매_60     -0.008819
# 중국 산업 생산_60      0.00085
# MSCI_EMER_60     0.00112
# 미 소맥 선물 _60    -0.002363
# 미 대두 선물 _60    -0.001115
# Name: 2024-04-01, Length: 88, dtype: object
# 88
# 마지막 행 discretionary: discretionary         NaN
# WTI                 84.54
# DGS2                 4.72
# DGS10                1.98
# TIPS                 1.98
#                    ...
# 중국 소매판매_60      -0.008819
# 중국 산업 생산_60       0.00085
# MSCI_EMER_60      0.00112
# 항공 여객_60        -0.000519
# 소비자심리지수_60      -0.000164
# Name: 2024-04-01, Length: 88, dtype: object
# 88
# 마지막 행 kospi: kospi                NaN
# WTI                84.54
# DGS2                4.72
# DGS10               1.98
# TIPS                1.98
#                   ...
# 금 선물_60         0.001513
# 달러 인덱스_60       0.000245
# 중국 소매판매_60     -0.008819
# 중국 산업 생산_60      0.00085
# MSCI_EMER_60     0.00112
# Name: 2024-04-01, Length: 82, dtype: object
# 82

# %%
loaded_models = {}

# 각 키워드별로 모델 로드
for keyword in keywords:
    filename = f"plk_folder_03/{keyword}_model.pkl"
    if os.path.exists(filename):
        # 모델을 로드하고 loaded_models 딕셔너리에 저장
        loaded_models[keyword] = load(filename)
        print(f"Model for {keyword} keyword loaded from {filename}")
    else:
        print(f"Model file for {keyword} keyword does not exist: {filename}")

# 각 키워드별로 S_buy, buy, sell의 확률 예측
probabilities = {}
for keyword, model in loaded_models.items():
    # 마지막 행 데이터를 가져와서 예측에 사용
    X_test_last_row_keyword = last_rows[keyword].values.reshape(1, -1)
    # 첫 번째 열(해당 키워드)을 제외하고 예측에 사용
    X_test_last_row_keyword = X_test_last_row_keyword[:, 1:]
    # 각 클래스의 확률 예측
    prob_current = model.predict_proba(X_test_last_row_keyword)
    # 클래스 이름 가져오기
    y_names = model.classes_
    # 결과 저장
    probabilities[keyword] = {'S_buy': prob_current[0][0], 'buy': prob_current[0][1], 'sell': prob_current[0][2]}

# 출력
for keyword, probs in probabilities.items():
    print(keyword)
    for action, prob in probs.items():
        print(f'{action}: {prob:.4f}')
    print()
# Out:
# Model for auto keyword loaded from plk_folder_03/auto_model.pkl
# Model for construct keyword loaded from plk_folder_03/construct_model.pkl
# Model for capital_market keyword loaded from plk_folder_03/capital_market_model.pkl
# Model for chemicals keyword loaded from plk_folder_03/chemicals_model.pkl
# Model for equipment keyword loaded from plk_folder_03/equipment_model.pkl
# Model for transport keyword loaded from plk_folder_03/transport_model.pkl
# Model for semi keyword loaded from plk_folder_03/semi_model.pkl
# Model for bank keyword loaded from plk_folder_03/bank_model.pkl
# Model for steel keyword loaded from plk_folder_03/steel_model.pkl
# Model for telecom keyword loaded from plk_folder_03/telecom_model.pkl
# Model for staples keyword loaded from plk_folder_03/staples_model.pkl
# Model for discretionary keyword loaded from plk_folder_03/discretionary_model.pkl
# Model for kospi keyword loaded from plk_folder_03/kospi_model.pkl
# auto
# S_buy: 0.2495
# buy: 0.5019
# sell: 0.2486
#
# construct
# S_buy: 0.5000
# buy: 0.3125
# sell: 0.1875
#
# capital_market
# S_buy: 0.3562
# buy: 0.2599
# sell: 0.3840
#
# chemicals
# S_buy: 0.1505
# buy: 0.3252
# sell: 0.5243
#
# equipment
# S_buy: 0.2142
# buy: 0.1889
# sell: 0.5968
#
# transport
# S_buy: 0.3149
# buy: 0.3720
# sell: 0.3131
#
# semi
# S_buy: 0.2014
# buy: 0.1060
# sell: 0.6926
#
# bank
# S_buy: 0.3443
# buy: 0.3669
# sell: 0.2887
#
# steel
# S_buy: 0.5000
# buy: 0.2898
# sell: 0.2102
#
# telecom
# S_buy: 0.5556
# buy: 0.1696
# sell: 0.2749
#
# staples
# S_buy: 0.3158
# buy: 0.3962
# sell: 0.2880
#
# discretionary
# S_buy: 0.2504
# buy: 0.2538
# sell: 0.4958
#
# kospi
# S_buy: 0.2502
# buy: 0.1562
# sell: 0.5935

# %%
# 그래프로 출력
num_keywords = len(probabilities)
num_rows = (num_keywords + 2) // 3
num_cols = min(num_keywords, 3)
plt.figure(figsize=(6 * num_cols, 4 * num_rows))

for i, (keyword, probs) in enumerate(probabilities.items(), start=1):
    plt.subplot(num_rows, num_cols, i)
    plt.bar(probs.keys(), probs.values(), color=['skyblue', 'salmon', 'lightgreen'])
    plt.title(f'{keyword} Keyword')
    plt.xlabel('Action')
    plt.ylabel('Probability')
    plt.ylim(0, 1)  # Set y-axis limit from 0 to 1
    print(f'{keyword}')
    for j, prob in enumerate(probs.values()):
        plt.text(j, prob, f'{prob:.4f}', ha='center', va='bottom')
        print(f'{prob:.4f}',end="   ")
    print()
plt.tight_layout()
plt.show()
# Out:
# auto
# 0.2495   0.5019   0.2486
# construct
# 0.5000   0.3125   0.1875
# capital_market
# 0.3562   0.2599   0.3840
# chemicals
# 0.1505   0.3252   0.5243
# equipment
# 0.2142   0.1889   0.5968
# transport
# 0.3149   0.3720   0.3131
# semi
# 0.2014   0.1060   0.6926
# bank
# 0.3443   0.3669   0.2887
# steel
# 0.5000   0.2898   0.2102
# telecom
# 0.5556   0.1696   0.2749
# staples
# 0.3158   0.3962   0.2880
# discretionary
# 0.2504   0.2538   0.4958
# kospi
# 0.2502   0.1562   0.5935
